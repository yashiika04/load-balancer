# %%
# %pip install tf-agents --no-deps
# Out:
# Requirement already satisfied: tf-agents in .\venv\lib\site-packages (0.19.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
# %pip install tf-keras
# %pip install tensorflow-probability
# Out:
# Requirement already satisfied: tf-keras in .\venv\lib\site-packages (2.20.1)Note: you may need to restart the kernel to use updated packages.
#
# Collecting tensorflow<2.21,>=2.20 (from tf-keras)
#   Using cached tensorflow-2.20.0-cp310-cp310-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: absl-py>=1.0.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (26.0)
# Requirement already satisfied: protobuf>=5.28.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.31.0)
# Requirement already satisfied: setuptools in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.14.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.1)
# Requirement already satisfied: numpy>=1.26.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in .\venv\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in .\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10.2)
# Requirement already satisfied: pillow in .\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in .\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in .\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in .\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.46.3)
# Requirement already satisfied: rich in .\venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.9.4)
# Requirement already satisfied: namex in .\venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in .\venv\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in .\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# Using cached tensorflow-2.20.0-cp310-cp310-win_amd64.whl (331.7 MB)
# Installing collected packages: tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# Successfully installed tensorflow-2.20.0
# Requirement already satisfied: tensorflow-probability in .\venv\lib\site-packages (0.23.0)
# Requirement already satisfied: absl-py in .\venv\lib\site-packages (from tensorflow-probability) (2.4.0)
# Requirement already satisfied: six>=1.10.0 in .\venv\lib\site-packages (from tensorflow-probability) (1.17.0)
# Requirement already satisfied: numpy>=1.13.3 in .\venv\lib\site-packages (from tensorflow-probability) (1.26.4)
# Requirement already satisfied: decorator in .\venv\lib\site-packages (from tensorflow-probability) (5.2.1)
# Requirement already satisfied: cloudpickle>=1.3 in .\venv\lib\site-packages (from tensorflow-probability) (3.1.2)
# Requirement already satisfied: gast>=0.3.2 in .\venv\lib\site-packages (from tensorflow-probability) (0.7.0)
# Requirement already satisfied: dm-tree in .\venv\lib\site-packages (from tensorflow-probability) (0.1.9)
# Requirement already satisfied: attrs>=18.2.0 in .\venv\lib\site-packages (from dm-tree->tensorflow-probability) (25.4.0)
# Requirement already satisfied: wrapt>=1.11.2 in .\venv\lib\site-packages (from dm-tree->tensorflow-probability) (1.14.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gin-config
# %pip install tensorflow-probability
# %pip install absl-py
# %pip install gym==0.23.0
# %pip install matplot
# Out:
# Requirement already satisfied: gin-config in e:\loadbalancer\venv\lib\site-packages (0.5.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: tensorflow-probability in e:\loadbalancer\venv\lib\site-packages (0.23.0)
# Requirement already satisfied: cloudpickle>=1.3 in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (3.1.2)
# Requirement already satisfied: dm-tree in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (0.1.9)
# Requirement already satisfied: absl-py in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (2.4.0)
# Requirement already satisfied: numpy>=1.13.3 in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (1.26.4)
# Requirement already satisfied: decorator in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (5.2.1)
# Requirement already satisfied: gast>=0.3.2 in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (0.7.0)
# Requirement already satisfied: six>=1.10.0 in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (1.17.0)
# Requirement already satisfied: wrapt>=1.11.2 in e:\loadbalancer\venv\lib\site-packages (from dm-tree->tensorflow-probability) (1.14.2)
# Requirement already satisfied: attrs>=18.2.0 in e:\loadbalancer\venv\lib\site-packages (from dm-tree->tensorflow-probability) (26.1.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: absl-py in e:\loadbalancer\venv\lib\site-packages (2.4.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: gym==0.23.0 in e:\loadbalancer\venv\lib\site-packages (0.23.0)
# Requirement already satisfied: numpy>=1.18.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (1.26.4)
# Requirement already satisfied: gym_notices>=0.0.4 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (0.1.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: matplot in e:\loadbalancer\venv\lib\site-packages (0.1.9)
# Requirement already satisfied: pyloco>=0.0.134 in e:\loadbalancer\venv\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: matplotlib>=3.1.1 in e:\loadbalancer\venv\lib\site-packages (from matplot) (3.10.8)
# Requirement already satisfied: pillow>=8 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.3.2)
# Requirement already satisfied: numpy>=1.23 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (26.0)
# Requirement already satisfied: cycler>=0.10 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.62.1)
# Requirement already satisfied: ushlex in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: twine in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (6.2.0)
# Requirement already satisfied: SimpleWebSocketServer in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: typing in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: websocket-client in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (1.9.0)
# Requirement already satisfied: six>=1.5 in e:\loadbalancer\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.17.0)
# Requirement already satisfied: readme-renderer>=35.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (44.0)
# Requirement already satisfied: id in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.6.1)
# Requirement already satisfied: requests>=2.20 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.6.3)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: rich>=12.0.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.9.4)
# Requirement already satisfied: keyring>=21.2.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (25.7.0)
# Requirement already satisfied: rfc3986>=1.4.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: jaraco.classes in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: jaraco.context in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (6.1.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (0.2.3)
# Requirement already satisfied: importlib_metadata>=4.11.4 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (9.0.0)
# Requirement already satisfied: jaraco.functools in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (4.4.0)
# Requirement already satisfied: nh3>=0.2.14 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.3.3)
# Requirement already satisfied: Pygments>=2.5.1 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.19.2)
# Requirement already satisfied: docutils>=0.21.2 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.22.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.0.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in e:\loadbalancer\venv\lib\site-packages (from importlib_metadata>=4.11.4->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in e:\loadbalancer\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: more-itertools in e:\loadbalancer\venv\lib\site-packages (from jaraco.classes->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (10.8.0)
# Requirement already satisfied: backports.tarfile in e:\loadbalancer\venv\lib\site-packages (from jaraco.context->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import re
from concurrent.futures import ThreadPoolExecutor, as_completed
import tensorflow as tf
import numpy as np 
import numpy as np
import requests 

# TF‑Agents imports  
from tf_agents.environments import tf_py_environment  
from tf_agents.trajectories import trajectory
from tf_agents.networks import q_network
from tf_agents.agents.dqn import dqn_agent
from tf_agents.utils import common
from tf_agents.replay_buffers import tf_uniform_replay_buffer 
from tf_agents.policies import epsilon_greedy_policy

from tf_agents.environments import py_environment
from tf_agents.specs import array_spec
from tf_agents.trajectories import time_step as ts
# Out:
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_agents\typing\types.py:114: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# $env:RL_POLICY_DIR="loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1"
# $env:RL_REWARD_MODE="full"
# python loadBalancer.py

# %%
def getResponseFromServer():
    url = 'http://localhost:8005'

    try:
        response = requests.get(url)

        if response.status_code == 200:
            print("Successfully received response from load balancer")
            return
        else:
            print('Error:', response.status_code)
            return None
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
getResponseFromServer()
# Out:
# Successfully received response from load balancer

# %%
SERVER_METRICS_URL = "http://localhost:8005" + "/server-metrics"

# %%
def generate_state(serverUrl):
    latency = []
    requests_handled = []
    failed_to_success_ratio = []

    for server in SERVERS:
        try:
            response = requests.get(f"{server}/metrics", timeout=2)
            response.raise_for_status()
            backend_metrics = _parse_prometheus_metrics(response.text)

            print(f"{server}: {backend_metrics}")

            raw_latency = backend_metrics.get("avg_successful_response_time", 1.0)
            latency.append(min(raw_latency / 5.0, 1.0))
            raw_requests = backend_metrics.get("total_requests", 0.0)
            requests_handled.append(min(raw_requests / 10000, 1.0))
            failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
        except requests.RequestException as e:
            print(f"Error fetching metrics from {server}: {e}")
            latency.append(2.0)
            requests_handled.append(0.0)
            failed_to_success_ratio.append(0.5)
      
    state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
    return state.astype(np.float32)

# %%
state = generate_state(SERVER_METRICS_URL)
print("Generated state:\n", state)
# Out:
# Generated state:
#  [[1.  0.  0.5]
#  [1.  0.  0.5]
#  [1.  0.  0.5]]

# %%
def compute_reward_from_state(state_row, alpha=1.0, beta=1.0, gamma=1.0):
    """
    Compute a reward from a state row (NumPy array) representing a server's metrics.
    
    Args:
      state_row (numpy.array): Array with [latency, total_requests, failed_to_success_ratio].
      alpha (float): Weight for latency penalty.
      beta (float): Weight for failure ratio penalty.
      gamma (float): Weight for throughput reward.
      
    Returns:
      float: Computed reward.
    """
    latency = state_row[0]
    total_requests = state_row[1]
    failure_ratio = state_row[2]
    
    # Compute throughput as an example: the effective successful request ratio times total requests.
    throughput = total_requests * (1 - failure_ratio)
    
    # Reward: latency-only.
    reward = - (alpha * latency )
    
    return reward

# %%
class LoadBalancerEnv(py_environment.PyEnvironment):
    MAX_LATENCY   = 5.0     # seconds
    MAX_REQUESTS  = 10000.0
    def __init__(self, serverMetricsUrl, servers):
        """
        Args:
          serverMetricsUrl: URL that returns aggregated server metrics in JSON format.
          servers: List of server URLs 
        """
        super(LoadBalancerEnv, self).__init__()
        self._servers = servers
        self._num_servers = len(servers)
        self._serverMetricsUrl = serverMetricsUrl

        # Observation: For each server, we consider 3 metrics:
        # [avg_successful_response_time (latency), total_requests, failed_to_success_ratio]
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(self._num_servers, 3),
            dtype=np.float32,
            minimum=0.0,
            maximum=1.0,
            name='observation'
        )

        # Action: A single discrete action representing the server index (0 to num_servers-1).
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(),
            dtype=np.int32,
            minimum=0,
            maximum=self._num_servers - 1,
            name='action'
        )

        self._episode_ended = False
        self._step_count = 0
        self._max_steps = 100  # defines the episode length

        # Initialize state by fetching the metrics
        self._state = self._generate_state()

    def _generate_state(self):
        """
        Fetch performance metrics from the aggregated metrics endpoint.
        For each server, extract:
          - avg_successful_response_time (latency)
          - total_requests
          - failed_to_success_ratio
        Returns a (num_servers, 3) numpy array.
        """
        latency = []
        requests_handled = []
        failed_to_success_ratio = []
        
        try:
            response = requests.get(self._serverMetricsUrl)
            response.raise_for_status()
            server_metrics = response.json()
             
            for server in self._servers:
                data = server_metrics.get(server, {})
                if "metrics" in data and data["metrics"] is not None:
                    metrics = data["metrics"] 
                    raw_latency = metrics.get("avg_successful_response_time", 1.0)
                    latency.append(min(raw_latency / self.MAX_LATENCY, 1.0))
                    raw_requests = metrics.get("total_requests", 0.0)
                    requests_handled.append(min(raw_requests / self.MAX_REQUESTS, 1.0))
                    failed_to_success_ratio.append(metrics.get("failed_to_success_ratio", 0.5))
                else:
                    print(f"No valid metrics for {server}")
                    latency.append(1.0)
                    requests_handled.append(0.0)
                    failed_to_success_ratio.append(0.5)
        except requests.RequestException as e:
            print(f"Error fetching server metrics: {e}")
            latency = [1.0] * self._num_servers
            requests_handled = [0.0] * self._num_servers
            failed_to_success_ratio = [0.5] * self._num_servers
        
        state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
        return state.astype(np.float32)

    def action_spec(self):
        return self._action_spec

    def observation_spec(self):
        return self._observation_spec

    def _reset(self):
        self._episode_ended = False
        self._step_count = 0
        self._state = self._generate_state()
        return ts.restart(self._state)

    def _step(self, action):
        if self._episode_ended:
            return self.reset()

        self._step_count += 1

        # Discrete action: chosen server index (0, 1, or 2)
        chosen_index = int(action)
        chosen_server = self._servers[chosen_index]
        print(f"Routing new traffic to chosen server: {chosen_server}")

        # Define total number of simulated requests
        total_requests = 50
        chosen_requests = int(total_requests * 0.7)  # 70% to chosen server
        remaining_requests = total_requests - chosen_requests  # 30% to others

        # Determine indices of other servers
        other_indices = [i for i in range(self._num_servers) if i != chosen_index]
         
        request_targets = [f"{chosen_server}/heavy-task"] * chosen_requests
         
        for _ in range(remaining_requests):
            random_index = np.random.choice(other_indices)
            request_targets.append(f"{self._servers[random_index]}/heavy-task")
        
        # Send the requests concurrently using ThreadPoolExecutor
        responses = []
        with ThreadPoolExecutor(max_workers=total_requests) as executor:
            futures = [executor.submit(requests.get, target, timeout=5) for target in request_targets]
            for future in as_completed(futures):
                try:
                    resp = future.result()
                    responses.append(resp.status_code)
                except Exception as e:
                    responses.append(None)

 
        success_count = sum(1 for r in responses if r == 200)
        failure_count = sum(1 for r in responses if r is None or r != 200)

        print(f"Simulated traffic: {success_count} successes, {failure_count} failures.")
 
        new_state = self._generate_state() 
         
        reward = compute_reward_from_state(new_state[chosen_index])

        print(f"Reward: {reward}")
 
        self._state = new_state

        if self._step_count >= self._max_steps:
            self._episode_ended = True
            return ts.termination(self._state, reward)
        else:
            return ts.transition(self._state, reward=reward, discount=0.99)

# %%
SERVERS = ["http://127.0.0.1:8000", "http://127.0.0.1:8001", "http://127.0.0.1:8002"]
 
loadBalancerEnv = LoadBalancerEnv(SERVER_METRICS_URL, SERVERS)
    
# Reset the environment and print the initial state 
initial_time_step = loadBalancerEnv.reset()
print("Initial state:\n", initial_time_step.observation)
    
# Simulate one step with an example action (e.g., choose server 1)
time_step = loadBalancerEnv._step(1)
print("New state:\n", time_step.observation)
print("Reward:", time_step.reward)
# Out:
# Initial state:
#  [[0.2 0.  0.5]
#  [0.2 0.  0.5]
#  [0.2 0.  0.5]]
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.08514577150344849
# New state:
#  [[7.1270406e-02 1.0000000e-03 0.0000000e+00]
#  [8.5145772e-02 3.5000001e-03 2.5000000e+00]
#  [7.2120570e-02 5.0000002e-04 0.0000000e+00]]
# Reward: -0.08514577

# %%
GAMMA = 0.99
NEURAL_NETWORK_HIDDEN_UNITS = (64,64)
MAX_BUFFER_SIZE = 10000
LEARNING_RATE = 5e-5

# %%
# -----------------------------------------------------------------------------
# 2. Create the TF-Agents Environment and the DQN Agent
# ----------------------------------------------------------------------------- 

# sim = LoadBalancingSim(num_servers=3)
# py_env = TFAgentsEnv(sim)
train_env = tf_py_environment.TFPyEnvironment(loadBalancerEnv)
 
fc_layer_params = NEURAL_NETWORK_HIDDEN_UNITS
q_net = q_network.QNetwork(
    train_env.observation_spec(),
    train_env.action_spec(),
    fc_layer_params=fc_layer_params)
 
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5, clipnorm=1.0)

# Creating a counter to keep track of the training steps.
train_step_counter = tf.Variable(0)
  
agent = dqn_agent.DqnAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    q_network=q_net,
    optimizer=optimizer,
    gamma = GAMMA,
    target_update_tau = 1,
    target_update_period=100,
    td_errors_loss_fn = common.element_wise_huber_loss,
    train_step_counter=train_step_counter)

agent.initialize()

# %%
# ---------------------------------------------------------------------------
# 3. Setup the Replay Buffer and Data Collection for Training
# ---------------------------------------------------------------------------

replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec=agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=MAX_BUFFER_SIZE
)

EPSILON_GREEDY_START = 1.0
EPSILON_GREEDY_END   = 0.1
EPSILON_DECAY_STEPS  = 1000

epsilon = tf.compat.v1.train.polynomial_decay(
    learning_rate=EPSILON_GREEDY_START,
    global_step=train_step_counter,
    decay_steps=EPSILON_DECAY_STEPS,
    end_learning_rate=EPSILON_GREEDY_END
)

collect_policy = epsilon_greedy_policy.EpsilonGreedyPolicy(
    agent.policy, epsilon=epsilon
)

def collect_step(environment, policy, buffer):
    """Collects a single transition and stores it in the replay buffer."""
    time_step = environment.current_time_step()  
    action_step = policy.action(time_step)  
    next_time_step = environment.step(action_step.action)  
    traj = trajectory.from_transition(time_step, action_step, next_time_step)  
    buffer.add_batch(traj)

# Collect initial experience for the agent to learn from
initial_collect_steps = 500   
print(f"Collecting {initial_collect_steps} initial experience steps...")

for _ in range(initial_collect_steps):
    collect_step(train_env, collect_policy, replay_buffer)

# Create a dataset from the replay buffer for training
batch_size = 64 
num_steps = 2   

dataset = replay_buffer.as_dataset(
    sample_batch_size=batch_size,
    num_steps=num_steps
).prefetch(3)

iterator = iter(dataset)
# Out:
# Collecting 500 initial experience steps...
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.08093985915184021
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07665597647428513
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07327532768249512
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 23 successes, 27 failures.
# Reward: -0.0732923373579979
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07193868607282639
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 24 successes, 26 failures.
# Reward: -0.07271938771009445
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07232111692428589
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07521694153547287
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07364135980606079
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07223527878522873
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07238475978374481
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07345661520957947
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 23 successes, 27 failures.
# Reward: -0.0729137510061264
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07194037735462189
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 26 successes, 24 failures.
# Reward: -0.07202976197004318
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 26 successes, 24 failures.
# Reward: -0.07192327082157135
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07129398733377457
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07241110503673553
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07070191949605942
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07271424680948257
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 26 successes, 24 failures.
# Reward: -0.07053063064813614
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07245489954948425
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 26 successes, 24 failures.
# Reward: -0.07024198770523071
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 26 successes, 24 failures.
# Reward: -0.07068799436092377
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07202083617448807
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07254644483327866
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07217346131801605
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07301515340805054
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07218080013990402
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07049685716629028
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07071221619844437
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07244217395782471
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 30 successes, 20 failures.
# Reward: -0.0709909200668335
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07264921069145203
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 23 successes, 27 failures.
# Reward: -0.07246951758861542
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07258662581443787
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07309234142303467
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 19 successes, 31 failures.
# Reward: -0.0724741518497467
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.0713721290230751
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.0714624747633934
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07152649760246277
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07289818674325943
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 24 successes, 26 failures.
# Reward: -0.07213681191205978
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.07189720869064331
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07290907204151154
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07155866920948029
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 24 successes, 26 failures.
# Reward: -0.07227254658937454
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07286333292722702
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07172537595033646
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 23 successes, 27 failures.
# Reward: -0.07220535725355148
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07328607887029648
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 17 successes, 33 failures.
# Reward: -0.07301655411720276
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.07224266976118088
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07192173600196838
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07185225188732147
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.07214877754449844
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 19 successes, 31 failures.
# Reward: -0.07205476611852646
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.07189968973398209
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 24 successes, 26 failures.
# Reward: -0.07189536839723587
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07256113737821579
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07183670997619629
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07267753779888153
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07201637327671051
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07252320647239685
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07202255725860596
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07241173088550568
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 19 successes, 31 failures.
# Reward: -0.0722661092877388
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07197247445583344
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 30 successes, 20 failures.
# Reward: -0.07196363061666489
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07236482203006744
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.0720936730504036
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07229132950305939
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07203083485364914
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07275217026472092
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07258050888776779
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07271753996610641
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07211726158857346
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 26 successes, 24 failures.
# Reward: -0.07214588671922684
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07285021990537643
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0726403221487999
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.0720757246017456
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07268460839986801
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07269833236932755
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07255490869283676
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07277503609657288
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07268312573432922
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 19 successes, 31 failures.
# Reward: -0.07228323817253113
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07233700156211853
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07261696457862854
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07284493744373322
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07280833274126053
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07295846939086914
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 23 successes, 27 failures.
# Reward: -0.07213851064443588
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 35 successes, 15 failures.
# Reward: -0.07283991575241089
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.07240660488605499
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.07241535931825638
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07312098890542984
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.0724555030465126
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07320612668991089
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0731678456068039
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07353009283542633
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07330837845802307
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 23 successes, 27 failures.
# Reward: -0.07331149280071259
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07318732887506485
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07319962978363037
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07337793707847595
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 23 successes, 27 failures.
# Reward: -0.0733918696641922
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07361900806427002
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07324299961328506
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07363826036453247
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07325154542922974
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07324869930744171
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 28 failures.
# Reward: -0.07332151383161545
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07363799959421158
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.0736260935664177
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07328300178050995
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07364498823881149
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07365148514509201
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 24 successes, 26 failures.
# Reward: -0.07333436608314514
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 36 successes, 14 failures.
# Reward: -0.07373776286840439
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07337067276239395
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 39 successes, 11 failures.
# Reward: -0.0737558975815773
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 26 successes, 24 failures.
# Reward: -0.07376542687416077
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07378105819225311
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07377424836158752
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 26 successes, 24 failures.
# Reward: -0.07377807796001434
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07337861508131027
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07339568436145782
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 29 successes, 21 failures.
# Reward: -0.07379577308893204
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07337508350610733
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07337949424982071

# %%
import matplotlib.pyplot as plt
import os
from IPython.display import clear_output

plot_dir = "training_plots"
os.makedirs(plot_dir, exist_ok=True)

# ---------------------------------------------------------------------------
# 4. Training the Agent with Visualization
# ---------------------------------------------------------------------------

num_iterations = 1000
train_loss_history = []
consecutive_increase_count = 0 
max_consecutive_increases = 5 # Stop training if loss increases 5 times in a row

plt.ion() # for live plotting

for step in range(num_iterations): 
    collect_step(train_env, collect_policy, replay_buffer)

    # Sample a batch of experiences from the replay buffer.
    experience, unused_info = next(iterator)
    train_loss = agent.train(experience).loss.numpy()

    train_loss_history.append(train_loss)
    train_step_counter.assign_add(1)

    # Check for consecutive increases in loss
    if len(train_loss_history) > 1 and train_loss > train_loss_history[-2]:
        consecutive_increase_count += 1
    else:
        consecutive_increase_count = 0 # Reset if loss decreases or stays the same

    # Stop training if loss increases for more than 5 iterations in a row
    # if step > 200 and consecutive_increase_count > max_consecutive_increases:
    #     print(f"Stopping early: Loss increased consecutively for {max_consecutive_increases} steps.")
    #     break  
    # Safer check for divergence
    if np.isnan(train_loss) or train_loss > 100.0:
        print("Stopping: Loss has diverged.")
        break

    if train_step_counter.numpy() % 100 == 0:
        print(f'Step = {train_step_counter.numpy()}: Loss = {train_loss}')

        clear_output(wait=True) # Clears previous output for smooth animation
        plt.figure(figsize=(10, 5))
        plt.plot(train_loss_history, label="Training Loss", color="blue")
        plt.xlabel("Training Steps")
        plt.ylabel("Loss")
        plt.title("Training Loss Over Time")
        plt.legend()
        plt.grid(True)
        plt.show() 
        # Save plots in the training_plots directory
        step_num = int(train_step_counter.numpy() // 10) 
        plt.savefig(os.path.join(plot_dir, f"Output_{step_num}.png"))
        plt.close()

plt.ioff() # Turn off interactive mode after training completes

print("Training completed successfully.")
# Out:
# Training completed successfully.

# %%
# -----------------------------------------------------------------------------
# 5. Evaluate the Trained Agent and Plot Returns
# -----------------------------------------------------------------------------
num_eval_episodes = 2
eval_returns = []  # To store returns for each evaluation episode

for episode in range(num_eval_episodes):
    time_step = train_env.reset()
    episode_return = 0.0

    while not time_step.is_last():
        # Use the agent's (greedy) policy for evaluation.
        action_step = collect_policy.action(time_step)
        time_step = train_env.step(action_step.action) 

        # time_step.reward is a tf.Tensor with shape [batch_size] (here, batch_size == 1)
        episode_return += time_step.reward.numpy()[0]

    eval_returns.append(episode_return)
    print('Evaluation Episode {}: Return = {}'.format(episode + 1, episode_return))

# Plot the evaluation returns
plt.figure(figsize=(8, 5))
plt.plot(range(1, num_eval_episodes+1), eval_returns, marker='o', linestyle='-')
plt.title('Evaluation Returns per Episode')
plt.xlabel('Episode')
plt.ylabel('Return')
plt.grid(True)
plt.show()
# Out:
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07386888563632965
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07386831939220428
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07387299835681915
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07387249171733856
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07387396693229675
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07386941462755203
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07387717068195343
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07387516647577286
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0738757997751236
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07387776672840118
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.073877714574337
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07387605309486389
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07387695461511612
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07389231026172638
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07389853149652481
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07389748096466064
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07390028238296509
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 24 successes, 26 failures.
# Reward: -0.07390671968460083
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07351158559322357
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07391125708818436
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0739157572388649
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07391780614852905
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07391608506441116
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07391896098852158
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07391609251499176
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07392358779907227
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07392413169145584
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07392750680446625
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 21 successes, 29 failures.
# Reward: -0.07392968982458115
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07392865419387817
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07352297008037567
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07393604516983032
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07394176721572876
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07393907010555267
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07394060492515564
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07394903898239136
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07399270683526993
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07400208711624146
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0740000382065773
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07399926334619522
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07399944216012955
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0739961490035057
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07399720698595047
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07399887591600418
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07401049137115479
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07400651276111603
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07400284707546234
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07400909811258316
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07401512563228607
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0740203857421875
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07401488721370697
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07400677353143692
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07401227205991745
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07400710880756378
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07400649040937424
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07401073724031448
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07401174306869507
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07404060661792755
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 18 successes, 32 failures.
# Reward: -0.07404482364654541
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07407069206237793
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07407299429178238
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07409163564443588
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409316301345825
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07358567416667938
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.074092335999012
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409746944904327
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410115003585815
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410401850938797
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409808039665222
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410050183534622
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410109043121338
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410094887018204
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0741034746170044
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 19 successes, 31 failures.
# Reward: -0.07410489767789841
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410909980535507
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410792261362076
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410798966884613
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 28 successes, 22 failures.
# Reward: -0.07359053939580917
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410978525876999
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07411151379346848
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 24 successes, 26 failures.
# Reward: -0.07358899712562561
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410892844200134
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07410584390163422
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 24 successes, 26 failures.
# Reward: -0.07411184906959534
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0741100087761879
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 43 successes, 7 failures.
# Reward: -0.07362277060747147
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07411418855190277
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07411698997020721
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07411704957485199
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07411506026983261
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410985231399536
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07410481572151184
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 25 successes, 25 failures.
# Reward: -0.07360128313302994
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409872859716415
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409538328647614
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 27 successes, 23 failures.
# Reward: -0.07362128794193268
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0740949884057045
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409322261810303
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409079372882843
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 19 successes, 31 failures.
# Reward: -0.07409238070249557
# Evaluation Episode 1: Return = -7.3971037119627
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07408532500267029
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 30 successes, 20 failures.
# Reward: -0.07362829893827438
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409218698740005
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409403473138809
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409153133630753
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.0740918219089508
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.
# Reward: -0.07409529387950897
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 20 successes, 30 failures.

# %%
import tensorflow as tf
from tf_agents.trajectories import time_step as ts
import os

policy_dir = "loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1"
os.makedirs(policy_dir, exist_ok=True)

class ExportablePolicy(tf.Module):
    def __init__(self, policy):
        super().__init__()
        self.policy = policy

    @tf.function(input_signature=[
        ts.TimeStep(
            step_type=tf.TensorSpec(shape=(1,), dtype=tf.int32, name="step_type"),
            reward=tf.TensorSpec(shape=(1,), dtype=tf.float32, name="reward"),
            discount=tf.TensorSpec(shape=(1,), dtype=tf.float32, name="discount"),
            observation=tf.TensorSpec(shape=(1, 3, 3), dtype=tf.float32, name="observation")
        )
    ])
    def action(self, time_step):
        action_step = self.policy.action(time_step)
        return action_step.action  # returns tensor of shape (1,), dtype int32

exportable = ExportablePolicy(agent.policy)
tf.saved_model.save(exportable, policy_dir)

# Verify
loaded = tf.saved_model.load(policy_dir)
print("Signatures:", list(loaded.signatures.keys()))
print("Success!" if loaded.signatures else "FAILED - still empty")
# Out:
# C:\Users\hp\AppData\Local\Temp\__autograph_generated_file56aj5jnn.py:14: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   retval_ = ag__.and_(lambda : ag__.ld(state) is not None, lambda : ag__.and_(lambda : ag__.ld(state) is not (), lambda : ag__.ld(state) is not []))
# C:\Users\hp\AppData\Local\Temp\__autograph_generated_file86sgbq8c.py:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ag__.if_stmt(ag__.ld(policy_state) is (), if_body_2, else_body_2, get_state_2, set_state_2, ('do_return', 'retval_'), 2)
# INFO:tensorflow:Assets written to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1\assets
# INFO:tensorflow:Assets written to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1\assets
# Signatures: ['serving_default']
# Success!

# %%
# Test loading
loaded_policy = tf.compat.v2.saved_model.load(policy_dir)
print("Policy loaded successfully")
# Out:
# Policy loaded successfully

# %%
policy_dir = "loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model2"

for root, dirs, files in os.walk(policy_dir):
    for file in files:
        print(os.path.join(root, file))
# Out:
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1\fingerprint.pb
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1\policy_specs.pbtxt
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1\saved_model.pb
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1\variables\variables.data-00000-of-00001
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy1\variables\variables.index
