# %%
# %pip install gin-config
# %pip install absl-py
# %pip install gym==0.23.0
# %pip install matplot
# Out:
# Requirement already satisfied: gin-config in e:\loadbalancer\venv\lib\site-packages (0.5.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: absl-py in e:\loadbalancer\venv\lib\site-packages (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: gym==0.23.0 in e:\loadbalancer\venv\lib\site-packages (0.23.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (3.1.2)
# Requirement already satisfied: gym_notices>=0.0.4 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (0.1.0)
# Requirement already satisfied: numpy>=1.18.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: matplot in e:\loadbalancer\venv\lib\site-packages (0.1.9)
# Requirement already satisfied: pyloco>=0.0.134 in e:\loadbalancer\venv\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: matplotlib>=3.1.1 in e:\loadbalancer\venv\lib\site-packages (from matplot) (3.10.8)
# Requirement already satisfied: packaging>=20.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (26.0)
# Requirement already satisfied: pyparsing>=3 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.62.1)
# Requirement already satisfied: cycler>=0.10 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (12.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.3.2)
# Requirement already satisfied: SimpleWebSocketServer in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: twine in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (6.2.0)
# Requirement already satisfied: websocket-client in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (1.9.0)
# Requirement already satisfied: ushlex in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: typing in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in e:\loadbalancer\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.17.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: keyring>=21.2.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (25.7.0)
# Requirement already satisfied: requests>=2.20 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Requirement already satisfied: id in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.6.1)
# Requirement already satisfied: urllib3>=1.26.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.6.3)
# Requirement already satisfied: rfc3986>=1.4.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.9.4)
# Requirement already satisfied: readme-renderer>=35.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (44.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (0.2.3)
# Requirement already satisfied: jaraco.context in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (6.1.1)
# Requirement already satisfied: jaraco.functools in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (4.4.0)
# Requirement already satisfied: jaraco.classes in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: importlib_metadata>=4.11.4 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (9.0.0)
# Requirement already satisfied: nh3>=0.2.14 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.3.3)
# Requirement already satisfied: docutils>=0.21.2 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.22.4)
# Requirement already satisfied: Pygments>=2.5.1 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.19.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2026.2.25)
# Requirement already satisfied: idna<4,>=2.5 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4.6)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.0.0)
# Requirement already satisfied: zipp>=3.20 in e:\loadbalancer\venv\lib\site-packages (from importlib_metadata>=4.11.4->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in e:\loadbalancer\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: more-itertools in e:\loadbalancer\venv\lib\site-packages (from jaraco.classes->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (10.8.0)
# Requirement already satisfied: backports.tarfile in e:\loadbalancer\venv\lib\site-packages (from jaraco.context->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import re
from concurrent.futures import ThreadPoolExecutor, as_completed
import tensorflow as tf
import numpy as np 
import numpy as np
import requests 
import time

# TF‑Agents imports  
from tf_agents.environments import tf_py_environment  
from tf_agents.trajectories import trajectory
from tf_agents.networks import q_network
from tf_agents.agents.dqn import dqn_agent
from tf_agents.utils import common
from tf_agents.replay_buffers import tf_uniform_replay_buffer 
from tf_agents.policies import epsilon_greedy_policy

from tf_agents.environments import py_environment
from tf_agents.specs import array_spec
from tf_agents.trajectories import time_step as ts
# Out:
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_agents\typing\types.py:114: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
SERVER_METRICS_URL = "http://localhost:8005/server-metrics"
SERVERS = [
    "http://127.0.0.1:8000",
    "http://127.0.0.1:8001",
    "http://127.0.0.1:8002",
]

# %%
def _parse_prometheus_metrics(metrics_text: str) -> dict:
    """Extract aggregated metrics from Prometheus text format."""
    failed_count_match = re.search(
        r'flask_http_request_total\{method="GET",status="429"\}\s+([\d.]+)', metrics_text)
    failed_count = float(failed_count_match.group(1)) if failed_count_match else 0.0

    success_count_match = re.search(
        r'flask_http_request_total\{method="GET",status="200"\}\s+([\d.]+)', metrics_text)
    success_count = float(success_count_match.group(1)) if success_count_match else 0.0

    total_requests = failed_count + success_count

    success_sum_match = re.search(
        r'flask_http_request_duration_seconds_sum\{method="GET",path="/heavy-task",status="200"\}\s+([\d.]+)', metrics_text)
    success_sum = float(success_sum_match.group(1)) if success_sum_match else 0.0

    success_time_count_match = re.search(
        r'flask_http_request_duration_seconds_count\{method="GET",path="/heavy-task",status="200"\}\s+([\d.]+)', metrics_text)
    success_time_count = float(success_time_count_match.group(1)) if success_time_count_match else 0.0

    avg_success_response = success_sum / success_time_count if success_time_count > 0 else 0.0

    failed_to_success_ratio = failed_count / success_count if success_count > 0 else (float('inf') if total_requests > 0 else 0.5)

    return {
        "avg_successful_response_time": avg_success_response,
        "total_requests": total_requests,
        "failed_to_success_ratio": failed_to_success_ratio
    }

# %%
def generate_state(serverUrl):
    latency = []
    requests_handled = []
    failed_to_success_ratio = []

    for server in SERVERS:
        try:
            response = requests.get(f"{server}/metrics", timeout=2)
            response.raise_for_status()
            backend_metrics = _parse_prometheus_metrics(response.text)

            print(f"{server}: {backend_metrics}")

            raw_latency = backend_metrics.get("avg_successful_response_time", 0.0)
            latency.append(min(raw_latency / 5.0, 1.0))
            raw_requests = backend_metrics.get("total_requests", 0.0)
            requests_handled.append(min(raw_requests / 10000, 1.0))
            failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
        except requests.RequestException as e:
            print(f"Error fetching metrics from {server}: {e}")
            latency.append(1.0)
            requests_handled.append(0.0)
            failed_to_success_ratio.append(0.5)
      
    state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
    return state.astype(np.float32)

# %%
state = generate_state(SERVER_METRICS_URL)
print("Generated state:\n", state)
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# Generated state:
#  [[0.  0.  0.5]
#  [0.  0.  0.5]
#  [0.  0.  0.5]]

# %%
_action_history = []   # module-level rolling window, reset each episode

def reset_action_history():
    global _action_history
    _action_history = []

def compute_reward4(state_row,
                    chosen_index,
                    alpha=0.5,
                    beta=0.3,
                    lam=0.7,
                    sla_norm=0.1,
                    n_servers=3,
                    history_window=20):
    

    global _action_history

    latency_norm  = float(state_row[0])
    failure_ratio = float(state_row[2])

    # ── Quadratic SLA-violation penalty ─────────────────────────────────────
    violation   = max(0.0, latency_norm - sla_norm)
    latency_pen = alpha * (violation ** 2)

    # ── Failure-ratio penalty ────────────────────────────────────────────────
    failure_pen = beta * failure_ratio

    # ── Entropy fairness bonus ───────────────────────────────────────────────
    _action_history.append(chosen_index)
    if len(_action_history) > history_window:
        _action_history.pop(0)

    counts = np.bincount(_action_history, minlength=n_servers).astype(np.float32)
    probs  = counts / counts.sum()
    eps    = 1e-8
    H      = -np.sum(probs * np.log(probs + eps))          # raw Shannon entropy
    H_max  = np.log(n_servers)                             # maximum possible entropy
    fairness_bon = lam * (H / H_max)                       # normalized to [0, lam]

    reward = -latency_pen - failure_pen + fairness_bon
    return float(reward)

# %%
class LoadBalancerEnvModel4(py_environment.PyEnvironment):
    """
    RL environment for REWARD-4.
    Identical structure to model2 LoadBalancerEnv but uses compute_reward4().
    State normalization is applied inside _generate_state() so the Q-network
    always receives values in [0, 1] matching the BoundedArraySpec.
    """

    MAX_LATENCY  = 5.0      # seconds  — normalization cap
    MAX_REQUESTS = 10000.0  # requests — normalization cap

    def __init__(self, server_metrics_url, servers):
        super(LoadBalancerEnvModel4, self).__init__()
        self._servers            = servers
        self._num_servers        = len(servers)
        self._server_metrics_url = server_metrics_url

        # All 3 features normalized to [0, 1]
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(self._num_servers, 3),
            dtype=np.float32,
            minimum=0.0,
            maximum=1.0,
            name='observation'
        )
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(),
            dtype=np.int32,
            minimum=0,
            maximum=self._num_servers - 1,
            name='action'
        )

        self._episode_ended = False
        self._step_count    = 0
        self._max_steps     = 100

        reset_action_history()
        self._state = self._generate_state()

    # ── specs ─────────────────────────────────────────────────────────────────
    def action_spec(self):      return self._action_spec
    def observation_spec(self): return self._observation_spec

    # ── state ─────────────────────────────────────────────────────────────────
    def _generate_state(self):
        """
        Fetch metrics and normalize to [0, 1]:
          latency_norm  = raw_latency  / MAX_LATENCY   (clamped)
          requests_norm = total_reqs   / MAX_REQUESTS  (clamped)
          failure_ratio already in [0, 1]
        """
        latency = []
        requests_handled = []
        failed_to_success_ratio = []

        for server in SERVERS:
            try:
                response = requests.get(f"{server}/metrics", timeout=2)
                response.raise_for_status()
                backend_metrics = _parse_prometheus_metrics(response.text)

                print(f"{server}: {backend_metrics}")

                raw_latency = backend_metrics.get("avg_successful_response_time", 1.0)
                latency.append(min(raw_latency / 5.0, 1.0))
                raw_requests = backend_metrics.get("total_requests", 0.0)
                requests_handled.append(min(raw_requests / 10000, 1.0))
                failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
            except requests.RequestException as e:
                print(f"Error fetching metrics from {server}: {e}")
                latency.append(1.0)
                requests_handled.append(0.0)
                failed_to_success_ratio.append(0.5)

        return np.column_stack([latency, requests_handled, failed_to_success_ratio]).astype(np.float32)

    # ── reset ─────────────────────────────────────────────────────────────────
    def _reset(self):
        self._episode_ended = False
        self._step_count    = 0
        reset_action_history()          # clear entropy window each episode
        self._state = self._generate_state()
        return ts.restart(self._state)

    # ── step ──────────────────────────────────────────────────────────────────
    def _step(self, action):
        if self._episode_ended:
            return self.reset()

        self._step_count += 1
        chosen_index  = int(action)
        chosen_server = self._servers[chosen_index]
        print(f"[Model4] Routing → {chosen_server}")

        # Send 50 requests: 70% to chosen, 30% spread across others
        total_requests      = 30
        chosen_requests     = int(total_requests * 0.7)

        # Instead of all at once, send in small batches
        batch_size = 10
        delay_between_batches = 0.1  # 100ms

        other_indices  = [i for i in range(self._num_servers) if i != chosen_index]
        request_targets        = [f"{chosen_server}/heavy-task"] * chosen_requests
        for _ in range(total_requests - chosen_requests):
            request_targets.append(f"{self._servers[np.random.choice(other_indices)]}/heavy-task")

        # Send the requests concurrently using ThreadPoolExecutor
        responses = []
        for i in range(0, len(request_targets), batch_size):
            batch = request_targets[i:i + batch_size]
            with ThreadPoolExecutor(max_workers=batch_size) as executor:
                futures = [executor.submit(requests.get, target, timeout=5) for target in batch]
                for future in as_completed(futures):
                    try:
                        resp = future.result()
                        responses.append(resp.status_code)
                    except Exception as e:
                        responses.append(None)
            time.sleep(delay_between_batches)

        ok  = sum(1 for r in responses if r == 200)
        bad = len(responses) - ok
        print(f"  traffic: {ok} ok, {bad} failed")

        new_state = self._generate_state()

        # REWARD-4 — uses normalized state + entropy over rolling action window
        reward = compute_reward4(
            state_row    = new_state[chosen_index],
            chosen_index = chosen_index,
            alpha        = 0.5,   # quadratic SLA violation weight
            beta         = 0.3,   # failure ratio weight
            lam          = 0.7,   # entropy fairness bonus weight
            sla_norm     = 0.1,   # 0.5 s / 5.0 s MAX_LATENCY
            n_servers    = self._num_servers,
            history_window = 20,
        )
        print(f"  reward4: {reward:.4f}")

        self._state = new_state

        if self._step_count >= self._max_steps:
            self._episode_ended = True
            return ts.termination(self._state, reward)
        return ts.transition(self._state, reward=reward, discount=0.99)

# %%
# Quick sanity check — run this with your servers live
env4 = LoadBalancerEnvModel4(SERVER_METRICS_URL, SERVERS)
init_ts = env4.reset()
print("Initial state (normalized):\n", init_ts.observation)

test_ts = env4._step(0)
print("After step 0 — state:\n", test_ts.observation)
print("After step 0 — reward4:", test_ts.reward)
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# Initial state (normalized):
#  [[0.  0.  0.5]
#  [0.  0.  0.5]
#  [0.  0.  0.5]]
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3410777499375399, 'total_requests': 21.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35694622504524887, 'total_requests': 4.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3290803200565279, 'total_requests': 5.0, 'failed_to_success_ratio': 0.0}
#   reward4: -0.0938
# After step 0 — state:
#  [[0.06821555 0.0021     0.3125    ]
#  [0.07138924 0.0004     0.        ]
#  [0.06581607 0.0005     0.        ]]
# After step 0 — reward4: -0.09375

# %%
# ---------------------------------------------------------------------------
# Hyperparameters — identical to model2 for fair comparison
# ---------------------------------------------------------------------------
GAMMA                    = 0.99
NEURAL_NETWORK_HIDDEN_UNITS = (64, 64)
MAX_BUFFER_SIZE          = 10000
LEARNING_RATE            = 5e-5

# %%
# ---------------------------------------------------------------------------
# Build TF-Agents environment and DQN agent
# ---------------------------------------------------------------------------
train_env4 = tf_py_environment.TFPyEnvironment(env4)

q_net4 = q_network.QNetwork(
    train_env4.observation_spec(),
    train_env4.action_spec(),
    fc_layer_params=NEURAL_NETWORK_HIDDEN_UNITS
)

optimizer4 = tf.keras.optimizers.Adam(learning_rate=5e-5, clipnorm=1.0)
train_step_counter4 = tf.Variable(0)

agent4 = dqn_agent.DqnAgent(
    env4.time_step_spec(),
    env4.action_spec(),
    q_network=q_net4,
    optimizer=optimizer4,
    gamma=GAMMA,
    target_update_tau = 1,
    target_update_period=100,
    td_errors_loss_fn=common.element_wise_huber_loss,
    train_step_counter=train_step_counter4
)
agent4.initialize()
print("Agent4 initialized.")
# Out:
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Agent4 initialized.

# %%
EPSILON_GREEDY_START = 1.0
EPSILON_GREEDY_END   = 0.1
EPSILON_DECAY_STEPS  = 1000

# %%
# ---------------------------------------------------------------------------
# Replay buffer and initial data collection
# ---------------------------------------------------------------------------
replay_buffer4 = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec  = agent4.collect_data_spec,
    batch_size = train_env4.batch_size,
    max_length = MAX_BUFFER_SIZE
)


epsilon = tf.compat.v1.train.polynomial_decay(
    learning_rate=EPSILON_GREEDY_START,
    global_step=train_step_counter4,
    decay_steps=EPSILON_DECAY_STEPS,
    end_learning_rate=EPSILON_GREEDY_END
)

collect_policy = epsilon_greedy_policy.EpsilonGreedyPolicy(
    agent4.policy, epsilon=epsilon
)

def collect_step(environment, policy, buffer):
    time_step   = environment.current_time_step()
    action_step = policy.action(time_step)
    next_ts     = environment.step(action_step.action)
    traj        = trajectory.from_transition(time_step, action_step, next_ts)
    buffer.add_batch(traj)

INITIAL_COLLECT_STEPS = 500
print(f"Collecting {INITIAL_COLLECT_STEPS} initial steps...")
for _ in range(INITIAL_COLLECT_STEPS):
    collect_step(train_env4, collect_policy, replay_buffer4)

BATCH_SIZE = 64
dataset4   = replay_buffer4.as_dataset(
    sample_batch_size = BATCH_SIZE,
    num_steps         = 2
).prefetch(3)
iterator4 = iter(dataset4)
print("Replay buffer ready.")
# Out:
# Collecting 500 initial steps...
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3410777499375399, 'total_requests': 21.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35694622504524887, 'total_requests': 4.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3290803200565279, 'total_requests': 5.0, 'failed_to_success_ratio': 0.0}
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3686956090386957, 'total_requests': 27.0, 'failed_to_success_ratio': 0.22727272727272727}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3803983143464263, 'total_requests': 7.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.34791577006690205, 'total_requests': 26.0, 'failed_to_success_ratio': 1.6}
#   reward4: -0.4800
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3703723466411854, 'total_requests': 35.0, 'failed_to_success_ratio': 0.16666666666666666}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3911776000459213, 'total_requests': 8.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36125392670122286, 'total_requests': 47.0, 'failed_to_success_ratio': 2.1333333333333333}
#   reward4: -0.6400
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3692028514176075, 'total_requests': 40.0, 'failed_to_success_ratio': 0.14285714285714285}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3697430083605771, 'total_requests': 12.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3601998950121924, 'total_requests': 68.0, 'failed_to_success_ratio': 2.4}
#   reward4: -0.7200
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3576347414438227, 'total_requests': 46.0, 'failed_to_success_ratio': 0.12195121951219512}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.37896368668104213, 'total_requests': 15.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35623861202038826, 'total_requests': 89.0, 'failed_to_success_ratio': 2.56}
#   reward4: -0.7680
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36010165452766657, 'total_requests': 49.0, 'failed_to_success_ratio': 0.11363636363636363}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3529774437629385, 'total_requests': 36.0, 'failed_to_success_ratio': 0.125}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3643128433575233, 'total_requests': 95.0, 'failed_to_success_ratio': 2.1666666666666665}
#   reward4: 0.2813
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3582320707671058, 'total_requests': 70.0, 'failed_to_success_ratio': 0.07692307692307693}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.34924502501315957, 'total_requests': 40.0, 'failed_to_success_ratio': 0.1111111111111111}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36294989715596393, 'total_requests': 100.0, 'failed_to_success_ratio': 1.8571428571428572}
#   reward4: 0.5297
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 23 ok, 7 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3569603283549033, 'total_requests': 72.0, 'failed_to_success_ratio': 0.07462686567164178}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3483511634762041, 'total_requests': 61.0, 'failed_to_success_ratio': 0.17307692307692307}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3608403800055385, 'total_requests': 107.0, 'failed_to_success_ratio': 1.675}
#   reward4: 0.5570
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 10 ok, 20 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3512160342429088, 'total_requests': 78.0, 'failed_to_success_ratio': 0.0684931506849315}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3464598691048609, 'total_requests': 64.0, 'failed_to_success_ratio': 0.16363636363636364}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.362452180493941, 'total_requests': 128.0, 'failed_to_success_ratio': 2.1219512195121952}
#   reward4: -0.0630
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36194176666728994, 'total_requests': 99.0, 'failed_to_success_ratio': 0.06451612903225806}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.347204940013277, 'total_requests': 69.0, 'failed_to_success_ratio': 0.15}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.367732368895991, 'total_requests': 132.0, 'failed_to_success_ratio': 1.9333333333333333}
#   reward4: 0.6146
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3603393762881301, 'total_requests': 103.0, 'failed_to_success_ratio': 0.061855670103092786}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.34728911232131604, 'total_requests': 74.0, 'failed_to_success_ratio': 0.13846153846153847}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36795050196130485, 'total_requests': 153.0, 'failed_to_success_ratio': 2.0}
#   reward4: 0.0055
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3636750144039486, 'total_requests': 124.0, 'failed_to_success_ratio': 0.05084745762711865}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.34984312207191526, 'total_requests': 77.0, 'failed_to_success_ratio': 0.1323529411764706}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3677069875079074, 'total_requests': 159.0, 'failed_to_success_ratio': 1.8392857142857142}
#   reward4: 0.6187
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36135406193754344, 'total_requests': 145.0, 'failed_to_success_ratio': 0.08208955223880597}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3542122712473653, 'total_requests': 82.0, 'failed_to_success_ratio': 0.1232876712328767}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36472490000693747, 'total_requests': 163.0, 'failed_to_success_ratio': 1.7166666666666666}
#   reward4: 0.6198
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3631148856072921, 'total_requests': 150.0, 'failed_to_success_ratio': 0.07913669064748201}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3504577441709479, 'total_requests': 86.0, 'failed_to_success_ratio': 0.11688311688311688}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36008386667394504, 'total_requests': 184.0, 'failed_to_success_ratio': 1.7878787878787878}
#   reward4: 0.0906
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3616686806228245, 'total_requests': 171.0, 'failed_to_success_ratio': 0.06875}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3487273250153521, 'total_requests': 89.0, 'failed_to_success_ratio': 0.1125}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3565405225446841, 'total_requests': 190.0, 'failed_to_success_ratio': 1.676056338028169}
#   reward4: 0.6116
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 26 ok, 4 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3611077993938869, 'total_requests': 176.0, 'failed_to_success_ratio': 0.06666666666666667}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35041604846111046, 'total_requests': 110.0, 'failed_to_success_ratio': 0.13402061855670103}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3570180533453822, 'total_requests': 194.0, 'failed_to_success_ratio': 1.5866666666666667}
#   reward4: 0.6248
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3616524653205099, 'total_requests': 184.0, 'failed_to_success_ratio': 0.06358381502890173}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35211640468006516, 'total_requests': 131.0, 'failed_to_success_ratio': 0.22429906542056074}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3570288671180606, 'total_requests': 195.0, 'failed_to_success_ratio': 1.5657894736842106}
#   reward4: 0.6156
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 18 ok, 12 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36068716424637, 'total_requests': 190.0, 'failed_to_success_ratio': 0.061452513966480445}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35213052728001704, 'total_requests': 134.0, 'failed_to_success_ratio': 0.21818181818181817}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.359274954132407, 'total_requests': 216.0, 'failed_to_success_ratio': 1.5411764705882354}
#   reward4: 0.2099
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362777727131905, 'total_requests': 211.0, 'failed_to_success_ratio': 0.06030150753768844}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35385094696412916, 'total_requests': 139.0, 'failed_to_success_ratio': 0.20869565217391303}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3602634179929083, 'total_requests': 220.0, 'failed_to_success_ratio': 1.4719101123595506}
#   reward4: 0.6579
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3626319316785211, 'total_requests': 214.0, 'failed_to_success_ratio': 0.0594059405940594}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35355967108337283, 'total_requests': 145.0, 'failed_to_success_ratio': 0.19834710743801653}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3642603284360743, 'total_requests': 241.0, 'failed_to_success_ratio': 1.5368421052631578}
#   reward4: 0.2054
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3620062277948843, 'total_requests': 235.0, 'failed_to_success_ratio': 0.053811659192825115}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3535531830744848, 'total_requests': 148.0, 'failed_to_success_ratio': 0.1935483870967742}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3643265610164963, 'total_requests': 247.0, 'failed_to_success_ratio': 1.47}
#   reward4: 0.6520
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 9 ok, 21 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3607816770847165, 'total_requests': 239.0, 'failed_to_success_ratio': 0.05286343612334802}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3558147046588679, 'total_requests': 153.0, 'failed_to_success_ratio': 0.18604651162790697}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3643265610164963, 'total_requests': 268.0, 'failed_to_success_ratio': 1.68}
#   reward4: 0.1642
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3603630973957479, 'total_requests': 243.0, 'failed_to_success_ratio': 0.05194805194805195}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35334607612849006, 'total_requests': 158.0, 'failed_to_success_ratio': 0.1791044776119403}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3626987743014026, 'total_requests': 289.0, 'failed_to_success_ratio': 1.7523809523809524}
#   reward4: 0.1425
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3602546055009983, 'total_requests': 248.0, 'failed_to_success_ratio': 0.05084745762711865}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35158083769087883, 'total_requests': 162.0, 'failed_to_success_ratio': 0.17391304347826086}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3618747463746166, 'total_requests': 310.0, 'failed_to_success_ratio': 1.8181818181818181}
#   reward4: 0.1227
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36036094466556384, 'total_requests': 256.0, 'failed_to_success_ratio': 0.04918032786885246}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35257063957815654, 'total_requests': 163.0, 'failed_to_success_ratio': 0.17266187050359713}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3590005574019059, 'total_requests': 331.0, 'failed_to_success_ratio': 1.8782608695652174}
#   reward4: 0.1047
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 28 ok, 2 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3601072879936546, 'total_requests': 262.0, 'failed_to_success_ratio': 0.048}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35003789747723296, 'total_requests': 184.0, 'failed_to_success_ratio': 0.16455696202531644}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35781461102651213, 'total_requests': 334.0, 'failed_to_success_ratio': 1.8305084745762712}
#   reward4: 0.6188
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3615989486221224, 'total_requests': 267.0, 'failed_to_success_ratio': 0.047058823529411764}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.34958374703308526, 'total_requests': 205.0, 'failed_to_success_ratio': 0.22023809523809523}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35708275574572446, 'total_requests': 338.0, 'failed_to_success_ratio': 1.7704918032786885}
#   reward4: 0.6138
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36106825869132264, 'total_requests': 288.0, 'failed_to_success_ratio': 0.043478260869565216}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3492782655260365, 'total_requests': 211.0, 'failed_to_success_ratio': 0.21264367816091953}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3560949208084494, 'total_requests': 341.0, 'failed_to_success_ratio': 1.728}
#   reward4: 0.6551
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 16 ok, 14 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36143554663927335, 'total_requests': 295.0, 'failed_to_success_ratio': 0.04240282685512368}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3495885943279559, 'total_requests': 213.0, 'failed_to_success_ratio': 0.21022727272727273}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35684647197679925, 'total_requests': 362.0, 'failed_to_success_ratio': 1.7424242424242424}
#   reward4: 0.1454
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3605312520788478, 'total_requests': 300.0, 'failed_to_success_ratio': 0.041666666666666664}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.34991183834305656, 'total_requests': 217.0, 'failed_to_success_ratio': 0.20555555555555555}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3568021292002858, 'total_requests': 383.0, 'failed_to_success_ratio': 1.7956204379562044}
#   reward4: 0.1174
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36083759827686546, 'total_requests': 303.0, 'failed_to_success_ratio': 0.041237113402061855}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35100438119217714, 'total_requests': 223.0, 'failed_to_success_ratio': 0.1989247311827957}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3577104718358794, 'total_requests': 404.0, 'failed_to_success_ratio': 1.8450704225352113}
#   reward4: 0.1025
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3608510310855658, 'total_requests': 324.0, 'failed_to_success_ratio': 0.038461538461538464}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3529393110620348, 'total_requests': 227.0, 'failed_to_success_ratio': 0.19473684210526315}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35708723946151383, 'total_requests': 409.0, 'failed_to_success_ratio': 1.782312925170068}
#   reward4: 0.6445
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3610648112747784, 'total_requests': 345.0, 'failed_to_success_ratio': 0.051829268292682924}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35193169846189853, 'total_requests': 231.0, 'failed_to_success_ratio': 0.19072164948453607}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.355605276980082, 'total_requests': 414.0, 'failed_to_success_ratio': 1.7236842105263157}
#   reward4: 0.6405
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36091786786262225, 'total_requests': 350.0, 'failed_to_success_ratio': 0.05105105105105105}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3542269114349481, 'total_requests': 252.0, 'failed_to_success_ratio': 0.2}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3562633685964661, 'total_requests': 418.0, 'failed_to_success_ratio': 1.6794871794871795}
#   reward4: 0.6199
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36085717089929337, 'total_requests': 371.0, 'failed_to_success_ratio': 0.0480225988700565}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35447411033425463, 'total_requests': 255.0, 'failed_to_success_ratio': 0.19718309859154928}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3558585646024309, 'total_requests': 424.0, 'failed_to_success_ratio': 1.6335403726708075}
#   reward4: 0.6655
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 9 ok, 21 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36115954916264553, 'total_requests': 377.0, 'failed_to_success_ratio': 0.04722222222222222}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3560608666717868, 'total_requests': 258.0, 'failed_to_success_ratio': 0.19444444444444445}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3558585646024309, 'total_requests': 445.0, 'failed_to_success_ratio': 1.763975155279503}
#   reward4: 0.1269
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3605987416395331, 'total_requests': 382.0, 'failed_to_success_ratio': 0.04657534246575343}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3551389177039315, 'total_requests': 279.0, 'failed_to_success_ratio': 0.2345132743362832}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3563561521272993, 'total_requests': 449.0, 'failed_to_success_ratio': 1.7212121212121212}
#   reward4: 0.5857
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 18 ok, 12 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3611262766258417, 'total_requests': 385.0, 'failed_to_success_ratio': 0.04619565217391304}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35707876568174746, 'total_requests': 300.0, 'failed_to_success_ratio': 0.2711864406779661}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3547665588297498, 'total_requests': 455.0, 'failed_to_success_ratio': 1.6764705882352942}
#   reward4: 0.5986
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36173703252170136, 'total_requests': 389.0, 'failed_to_success_ratio': 0.0456989247311828}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35607019065485557, 'total_requests': 321.0, 'failed_to_success_ratio': 0.3048780487804878}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3552726937205132, 'total_requests': 460.0, 'failed_to_success_ratio': 1.6285714285714286}
#   reward4: 0.5885
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 17 ok, 13 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3618515644329575, 'total_requests': 391.0, 'failed_to_success_ratio': 0.045454545454545456}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35572976211733476, 'total_requests': 342.0, 'failed_to_success_ratio': 0.3359375}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35447112056168, 'total_requests': 467.0, 'failed_to_success_ratio': 1.5944444444444446}
#   reward4: 0.5877
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3614699031687071, 'total_requests': 395.0, 'failed_to_success_ratio': 0.04497354497354497}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3553116657960236, 'total_requests': 363.0, 'failed_to_success_ratio': 0.36466165413533835}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35546162811460325, 'total_requests': 472.0, 'failed_to_success_ratio': 1.5513513513513513}
#   reward4: 0.5628
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 10 ok, 20 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36108016874338017, 'total_requests': 401.0, 'failed_to_success_ratio': 0.044270833333333336}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3552419323479362, 'total_requests': 366.0, 'failed_to_success_ratio': 0.36059479553903345}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3559438349523892, 'total_requests': 493.0, 'failed_to_success_ratio': 1.6505376344086022}
#   reward4: 0.1770
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 26 ok, 4 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36227757083740364, 'total_requests': 408.0, 'failed_to_success_ratio': 0.043478260869565216}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3578918108438187, 'total_requests': 387.0, 'failed_to_success_ratio': 0.3531468531468531}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35466453351669924, 'total_requests': 495.0, 'failed_to_success_ratio': 1.6329787234042554}
#   reward4: 0.5622
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3616830469632399, 'total_requests': 413.0, 'failed_to_success_ratio': 0.04292929292929293}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35886251419307535, 'total_requests': 408.0, 'failed_to_success_ratio': 0.3783783783783784}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35553838333847426, 'total_requests': 499.0, 'failed_to_success_ratio': 1.5989583333333333}
#   reward4: 0.5425
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36142962974321563, 'total_requests': 417.0, 'failed_to_success_ratio': 0.0425}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35859324651587743, 'total_requests': 413.0, 'failed_to_success_ratio': 0.37209302325581395}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35582469848826564, 'total_requests': 520.0, 'failed_to_success_ratio': 1.6262626262626263}
#   reward4: 0.1682
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36402717125303424, 'total_requests': 438.0, 'failed_to_success_ratio': 0.040380047505938245}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35895992712851227, 'total_requests': 418.0, 'failed_to_success_ratio': 0.3660130718954248}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3544520950521167, 'total_requests': 524.0, 'failed_to_success_ratio': 1.5940594059405941}
#   reward4: 0.6678
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36422804201255715, 'total_requests': 443.0, 'failed_to_success_ratio': 0.03990610328638498}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3587188761335828, 'total_requests': 422.0, 'failed_to_success_ratio': 0.36129032258064514}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3539287389453071, 'total_requests': 545.0, 'failed_to_success_ratio': 1.6201923076923077}
#   reward4: 0.2024
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 28 ok, 2 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3648753339983106, 'total_requests': 464.0, 'failed_to_success_ratio': 0.03803131991051454}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3583840833385833, 'total_requests': 424.0, 'failed_to_success_ratio': 0.358974358974359}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35402572864312415, 'total_requests': 552.0, 'failed_to_success_ratio': 1.591549295774648}
#   reward4: 0.6771
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 9 ok, 21 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3650976310359178, 'total_requests': 468.0, 'failed_to_success_ratio': 0.037694013303769404}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3586781419606509, 'total_requests': 429.0, 'failed_to_success_ratio': 0.35331230283911674}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35402572864312415, 'total_requests': 573.0, 'failed_to_success_ratio': 1.6901408450704225}
#   reward4: 0.1814
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 17 ok, 13 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3645785664399432, 'total_requests': 470.0, 'failed_to_success_ratio': 0.037527593818984545}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3582499434307092, 'total_requests': 450.0, 'failed_to_success_ratio': 0.3761467889908257}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35488194404191276, 'total_requests': 580.0, 'failed_to_success_ratio': 1.6605504587155964}
#   reward4: 0.5671
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 10 ok, 20 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3644248312853758, 'total_requests': 474.0, 'failed_to_success_ratio': 0.037199124726477024}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3577096340413407, 'total_requests': 455.0, 'failed_to_success_ratio': 0.3704819277108434}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35496578447958754, 'total_requests': 601.0, 'failed_to_success_ratio': 1.7442922374429224}
#   reward4: 0.1566
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 18 ok, 12 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3647720837598723, 'total_requests': 479.0, 'failed_to_success_ratio': 0.0367965367965368}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35774856637484237, 'total_requests': 459.0, 'failed_to_success_ratio': 0.36607142857142855}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35719110175615926, 'total_requests': 622.0, 'failed_to_success_ratio': 1.7280701754385965}
#   reward4: 0.1497
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3636308476120604, 'total_requests': 500.0, 'failed_to_success_ratio': 0.035196687370600416}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3584146579474156, 'total_requests': 463.0, 'failed_to_success_ratio': 0.36176470588235293}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3584764197432784, 'total_requests': 627.0, 'failed_to_success_ratio': 1.6909871244635193}
#   reward4: 0.6576
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 10 ok, 20 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3636200145719806, 'total_requests': 504.0, 'failed_to_success_ratio': 0.03490759753593429}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3575655756578983, 'total_requests': 468.0, 'failed_to_success_ratio': 0.3565217391304348}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3585612799148433, 'total_requests': 648.0, 'failed_to_success_ratio': 1.7692307692307692}
#   reward4: 0.1414
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 24 ok, 6 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36370961320524037, 'total_requests': 509.0, 'failed_to_success_ratio': 0.034552845528455285}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35791555945050074, 'total_requests': 489.0, 'failed_to_success_ratio': 0.35833333333333334}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3596997126064287, 'total_requests': 652.0, 'failed_to_success_ratio': 1.7394957983193278}
#   reward4: 0.5363
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36393950463060454, 'total_requests': 513.0, 'failed_to_success_ratio': 0.034274193548387094}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3582466791836826, 'total_requests': 494.0, 'failed_to_success_ratio': 0.35342465753424657}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3602659241821174, 'total_requests': 673.0, 'failed_to_success_ratio': 1.7581967213114753}
#   reward4: 0.1163
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36415393771090304, 'total_requests': 534.0, 'failed_to_success_ratio': 0.03288201160541586}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3582612465114473, 'total_requests': 501.0, 'failed_to_success_ratio': 0.3467741935483871}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36121432317186114, 'total_requests': 675.0, 'failed_to_success_ratio': 1.7439024390243902}
#   reward4: 0.6623
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 17 ok, 13 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3642368911128153, 'total_requests': 535.0, 'failed_to_success_ratio': 0.032818532818532815}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35916169447959156, 'total_requests': 509.0, 'failed_to_success_ratio': 0.3394736842105263}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35938281574979514, 'total_requests': 696.0, 'failed_to_success_ratio': 1.7401574803149606}
#   reward4: 0.1461
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 21 ok, 9 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3640494881156775, 'total_requests': 539.0, 'failed_to_success_ratio': 0.032567049808429116}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36001073342287077, 'total_requests': 530.0, 'failed_to_success_ratio': 0.3520408163265306}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35932640463444604, 'total_requests': 701.0, 'failed_to_success_ratio': 1.7065637065637065}
#   reward4: 0.5626
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36391327813039304, 'total_requests': 543.0, 'failed_to_success_ratio': 0.03231939163498099}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35996737637191045, 'total_requests': 551.0, 'failed_to_success_ratio': 0.3706467661691542}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35979734204628394, 'total_requests': 706.0, 'failed_to_success_ratio': 1.6742424242424243}
#   reward4: 0.5570
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3643399202873525, 'total_requests': 564.0, 'failed_to_success_ratio': 0.031078610603290677}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36044854840666457, 'total_requests': 556.0, 'failed_to_success_ratio': 0.36609336609336607}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35926596567281455, 'total_requests': 710.0, 'failed_to_success_ratio': 1.6492537313432836}
#   reward4: 0.6706
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3637371929294929, 'total_requests': 569.0, 'failed_to_success_ratio': 0.030797101449275364}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36060321800877543, 'total_requests': 560.0, 'failed_to_success_ratio': 0.36253041362530414}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35823203941864934, 'total_requests': 731.0, 'failed_to_success_ratio': 1.667883211678832}
#   reward4: 0.1796
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3629872533976284, 'total_requests': 590.0, 'failed_to_success_ratio': 0.029668411867364748}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3602409318106316, 'total_requests': 564.0, 'failed_to_success_ratio': 0.35903614457831323}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.358442713265344, 'total_requests': 736.0, 'failed_to_success_ratio': 1.6379928315412187}
#   reward4: 0.6710
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 10 ok, 20 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3629065505172149, 'total_requests': 591.0, 'failed_to_success_ratio': 0.029616724738675958}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3599349576864286, 'total_requests': 572.0, 'failed_to_success_ratio': 0.35224586288416077}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3583412257172833, 'total_requests': 757.0, 'failed_to_success_ratio': 1.7035714285714285}
#   reward4: 0.1450
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 21 ok, 9 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36316532378751337, 'total_requests': 597.0, 'failed_to_success_ratio': 0.029310344827586206}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36095626529027847, 'total_requests': 593.0, 'failed_to_success_ratio': 0.3632183908045977}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35906733816420466, 'total_requests': 760.0, 'failed_to_success_ratio': 1.685512367491166}
#   reward4: 0.5710
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 16 ok, 14 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36338416625955583, 'total_requests': 598.0, 'failed_to_success_ratio': 0.029259896729776247}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3606140534869615, 'total_requests': 614.0, 'failed_to_success_ratio': 0.3797752808988764}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3580988364604612, 'total_requests': 768.0, 'failed_to_success_ratio': 1.6666666666666667}
#   reward4: 0.5660
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36332441415834804, 'total_requests': 603.0, 'failed_to_success_ratio': 0.02901023890784983}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36110770220172356, 'total_requests': 635.0, 'failed_to_success_ratio': 0.3956043956043956}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3576166167829747, 'total_requests': 772.0, 'failed_to_success_ratio': 1.643835616438356}
#   reward4: 0.5698
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36369384365245283, 'total_requests': 624.0, 'failed_to_success_ratio': 0.02800658978583196}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3610645962922781, 'total_requests': 638.0, 'failed_to_success_ratio': 0.3930131004366812}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3571032717195261, 'total_requests': 778.0, 'failed_to_success_ratio': 1.6195286195286196}
#   reward4: 0.6801
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 26 ok, 4 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3637974006501095, 'total_requests': 628.0, 'failed_to_success_ratio': 0.027823240589198037}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.361223860424208, 'total_requests': 659.0, 'failed_to_success_ratio': 0.3873684210526316}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3566839099362098, 'total_requests': 783.0, 'failed_to_success_ratio': 1.5927152317880795}
#   reward4: 0.5723
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3639220605969806, 'total_requests': 649.0, 'failed_to_success_ratio': 0.02689873417721519}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36140085177813, 'total_requests': 663.0, 'failed_to_success_ratio': 0.38413361169102295}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.356559184042385, 'total_requests': 788.0, 'failed_to_success_ratio': 1.5667752442996743}
#   reward4: 0.6903
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36396084212659235, 'total_requests': 670.0, 'failed_to_success_ratio': 0.033950617283950615}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3610744739700809, 'total_requests': 668.0, 'failed_to_success_ratio': 0.38016528925619836}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35563071350824577, 'total_requests': 792.0, 'failed_to_success_ratio': 1.5466237942122187}
#   reward4: 0.6882
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36400470673463164, 'total_requests': 675.0, 'failed_to_success_ratio': 0.033690658499234305}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.361016614552488, 'total_requests': 672.0, 'failed_to_success_ratio': 0.3770491803278688}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3566586157771221, 'total_requests': 813.0, 'failed_to_success_ratio': 1.5646687697160884}
#   reward4: 0.2290
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36431681067863814, 'total_requests': 696.0, 'failed_to_success_ratio': 0.032640949554896145}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36113417485131905, 'total_requests': 677.0, 'failed_to_success_ratio': 0.37322515212981744}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3574299352059309, 'total_requests': 817.0, 'failed_to_success_ratio': 1.5451713395638629}
#   reward4: 0.6886
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3644386583175208, 'total_requests': 701.0, 'failed_to_success_ratio': 0.03240058910162003}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36118193702553014, 'total_requests': 681.0, 'failed_to_success_ratio': 0.3702213279678068}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3583010593301044, 'total_requests': 838.0, 'failed_to_success_ratio': 1.562691131498471}
#   reward4: 0.2296
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36393150219238346, 'total_requests': 705.0, 'failed_to_success_ratio': 0.032210834553440704}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3610424685289163, 'total_requests': 686.0, 'failed_to_success_ratio': 0.3665338645418327}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3576813560275148, 'total_requests': 859.0, 'failed_to_success_ratio': 1.5873493975903614}
#   reward4: 0.2222
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 24 ok, 6 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36429978494516235, 'total_requests': 713.0, 'failed_to_success_ratio': 0.03183791606367583}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3609074096738521, 'total_requests': 707.0, 'failed_to_success_ratio': 0.36750483558994196}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3572678849885559, 'total_requests': 860.0, 'failed_to_success_ratio': 1.5825825825825826}
#   reward4: 0.5881
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 18 ok, 12 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3644309992749668, 'total_requests': 716.0, 'failed_to_success_ratio': 0.03170028818443804}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3607294880484621, 'total_requests': 728.0, 'failed_to_success_ratio': 0.38140417457305503}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35705213432307714, 'total_requests': 866.0, 'failed_to_success_ratio': 1.5621301775147929}
#   reward4: 0.5794
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 9 ok, 21 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36433323003812684, 'total_requests': 721.0, 'failed_to_success_ratio': 0.031473533619456366}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3611964500967848, 'total_requests': 732.0, 'failed_to_success_ratio': 0.3785310734463277}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35705213432307714, 'total_requests': 887.0, 'failed_to_success_ratio': 1.6242603550295858}
#   reward4: 0.2065
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36341058444005386, 'total_requests': 742.0, 'failed_to_success_ratio': 0.030555555555555555}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3611947932983861, 'total_requests': 738.0, 'failed_to_success_ratio': 0.3743016759776536}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3566742903270275, 'total_requests': 890.0, 'failed_to_success_ratio': 1.6099706744868034}
#   reward4: 0.6892
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 16 ok, 14 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.363335381125064, 'total_requests': 748.0, 'failed_to_success_ratio': 0.030303030303030304}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3612485744464384, 'total_requests': 741.0, 'failed_to_success_ratio': 0.37222222222222223}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35578113850928716, 'total_requests': 911.0, 'failed_to_success_ratio': 1.617816091954023}
#   reward4: 0.2130
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3632367934111189, 'total_requests': 751.0, 'failed_to_success_ratio': 0.03017832647462277}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3605332084387186, 'total_requests': 762.0, 'failed_to_success_ratio': 0.36804308797127466}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3551684603432758, 'total_requests': 917.0, 'failed_to_success_ratio': 1.5977337110481586}
#   reward4: 0.5880
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36323250736278895, 'total_requests': 755.0, 'failed_to_success_ratio': 0.030013642564802184}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3609183945338286, 'total_requests': 783.0, 'failed_to_success_ratio': 0.38095238095238093}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3551437438565811, 'total_requests': 922.0, 'failed_to_success_ratio': 1.5754189944134078}
#   reward4: 0.5795
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3625809075567125, 'total_requests': 776.0, 'failed_to_success_ratio': 0.029177718832891247}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3605302671946814, 'total_requests': 786.0, 'failed_to_success_ratio': 0.37894736842105264}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35449833443744966, 'total_requests': 928.0, 'failed_to_success_ratio': 1.556473829201102}
#   reward4: 0.6851
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 9 ok, 21 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36299546697186835, 'total_requests': 779.0, 'failed_to_success_ratio': 0.02906208718626156}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3606262753483962, 'total_requests': 792.0, 'failed_to_success_ratio': 0.375}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35449833443744966, 'total_requests': 949.0, 'failed_to_success_ratio': 1.6143250688705235}
#   reward4: 0.2095
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3629794896428924, 'total_requests': 785.0, 'failed_to_success_ratio': 0.028833551769331587}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36068627046741264, 'total_requests': 795.0, 'failed_to_success_ratio': 0.37305699481865284}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35431926195831137, 'total_requests': 970.0, 'failed_to_success_ratio': 1.6358695652173914}
#   reward4: 0.2076
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 28 ok, 2 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627924689625201, 'total_requests': 806.0, 'failed_to_success_ratio': 0.02937420178799489}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3607423599666189, 'total_requests': 798.0, 'failed_to_success_ratio': 0.3711340206185567}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35465162761519403, 'total_requests': 976.0, 'failed_to_success_ratio': 1.616621983914209}
#   reward4: 0.6896
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 10 ok, 20 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36265131812105933, 'total_requests': 812.0, 'failed_to_success_ratio': 0.029150823827629912}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36081346119714214, 'total_requests': 801.0, 'failed_to_success_ratio': 0.36923076923076925}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3542732435837637, 'total_requests': 997.0, 'failed_to_success_ratio': 1.6657754010695187}
#   reward4: 0.1887
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 18 ok, 12 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627142905393289, 'total_requests': 816.0, 'failed_to_success_ratio': 0.029003783102143757}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3603653103401253, 'total_requests': 806.0, 'failed_to_success_ratio': 0.36610169491525424}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35497453655408057, 'total_requests': 1018.0, 'failed_to_success_ratio': 1.6579634464751958}
#   reward4: 0.1825
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36293663588174885, 'total_requests': 820.0, 'failed_to_success_ratio': 0.028858218318695106}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.360314959833915, 'total_requests': 811.0, 'failed_to_success_ratio': 0.3630252100840336}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35593614304142995, 'total_requests': 1039.0, 'failed_to_success_ratio': 1.6778350515463918}
#   reward4: 0.1527
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3624320578215471, 'total_requests': 841.0, 'failed_to_success_ratio': 0.028117359413202935}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3605185168634366, 'total_requests': 815.0, 'failed_to_success_ratio': 0.3606010016694491}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3560263083971629, 'total_requests': 1044.0, 'failed_to_success_ratio': 1.6564885496183206}
#   reward4: 0.6476
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 23 ok, 7 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36242980219270443, 'total_requests': 843.0, 'failed_to_success_ratio': 0.02804878048780488}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3604596414648723, 'total_requests': 836.0, 'failed_to_success_ratio': 0.359349593495935}
# ...
#   reward4: 0.5681
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621460721161872, 'total_requests': 4386.0, 'failed_to_success_ratio': 0.05154639175257732}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3598401690995695, 'total_requests': 4760.0, 'failed_to_success_ratio': 0.37215335831651775}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35800762886676457, 'total_requests': 4924.0, 'failed_to_success_ratio': 1.4806045340050378}
#   reward4: 0.6645
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621234749691438, 'total_requests': 4390.0, 'failed_to_success_ratio': 0.05149700598802395}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35987410028892675, 'total_requests': 4781.0, 'failed_to_success_ratio': 0.37187948350071737}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3579505311058432, 'total_requests': 4929.0, 'failed_to_success_ratio': 1.4768844221105528}
#   reward4: 0.5769
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 17 ok, 13 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621247171884528, 'total_requests': 4392.0, 'failed_to_success_ratio': 0.05147234857553268}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3598902539934334, 'total_requests': 4802.0, 'failed_to_success_ratio': 0.37396280400572246}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578729991983146, 'total_requests': 4936.0, 'failed_to_success_ratio': 1.4741854636591478}
#   reward4: 0.5600
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621931554643467, 'total_requests': 4396.0, 'failed_to_success_ratio': 0.05142310452044965}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35993036861835676, 'total_requests': 4823.0, 'failed_to_success_ratio': 0.3760342368045649}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578612485501217, 'total_requests': 4941.0, 'failed_to_success_ratio': 1.4705}
#   reward4: 0.5554
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36216473553086026, 'total_requests': 4400.0, 'failed_to_success_ratio': 0.05137395459976105}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35989530896363914, 'total_requests': 4844.0, 'failed_to_success_ratio': 0.37809388335704125}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35794879715713185, 'total_requests': 4946.0, 'failed_to_success_ratio': 1.4668329177057358}
#   reward4: 0.5426
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3619643238222973, 'total_requests': 4421.0, 'failed_to_success_ratio': 0.05111745126010461}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35987807721157355, 'total_requests': 4848.0, 'failed_to_success_ratio': 0.3776641091219096}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35797938402969187, 'total_requests': 4951.0, 'failed_to_success_ratio': 1.4631840796019902}
#   reward4: 0.6528
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.361970147338802, 'total_requests': 4425.0, 'failed_to_success_ratio': 0.0510688836104513}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35983581148737404, 'total_requests': 4869.0, 'failed_to_success_ratio': 0.3773691654879774}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35796730709666613, 'total_requests': 4956.0, 'failed_to_success_ratio': 1.4595533498759306}
#   reward4: 0.5429
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3619894423716495, 'total_requests': 4430.0, 'failed_to_success_ratio': 0.051008303677342826}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35980469001626547, 'total_requests': 4890.0, 'failed_to_success_ratio': 0.37940761636107195}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35794143902920667, 'total_requests': 4960.0, 'failed_to_success_ratio': 1.4566617137196631}
#   reward4: 0.5216
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 18 ok, 12 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3619670456843013, 'total_requests': 4433.0, 'failed_to_success_ratio': 0.05097202465623518}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35975494880658876, 'total_requests': 4911.0, 'failed_to_success_ratio': 0.38143459915611816}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578650161066956, 'total_requests': 4966.0, 'failed_to_success_ratio': 1.4535573122529644}
#   reward4: 0.4911
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3620262817401895, 'total_requests': 4454.0, 'failed_to_success_ratio': 0.050719509318235434}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3597173507042815, 'total_requests': 4916.0, 'failed_to_success_ratio': 0.3808988764044944}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35774284896451825, 'total_requests': 4970.0, 'failed_to_success_ratio': 1.45069033530572}
#   reward4: 0.5903
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 23 ok, 7 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3620929922670335, 'total_requests': 4457.0, 'failed_to_success_ratio': 0.05068363979255068}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35959414573633797, 'total_requests': 4937.0, 'failed_to_success_ratio': 0.380979020979021}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35777123275946365, 'total_requests': 4976.0, 'failed_to_success_ratio': 1.4476143630103295}
#   reward4: 0.4505
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 10 ok, 20 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362108660597434, 'total_requests': 4461.0, 'failed_to_success_ratio': 0.05063589260480452}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3595658606445084, 'total_requests': 4942.0, 'failed_to_success_ratio': 0.3804469273743017}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578206064405502, 'total_requests': 4997.0, 'failed_to_success_ratio': 1.4567354965585053}
#   reward4: 0.1685
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621373752979786, 'total_requests': 4482.0, 'failed_to_success_ratio': 0.050386688539957813}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35959088755446605, 'total_requests': 4945.0, 'failed_to_success_ratio': 0.38012838403572424}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35789409470335637, 'total_requests': 5003.0, 'failed_to_success_ratio': 1.4536537518391368}
#   reward4: 0.5823
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 22 ok, 8 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622286301413901, 'total_requests': 4503.0, 'failed_to_success_ratio': 0.05136586504786365}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3596195241371528, 'total_requests': 4946.0, 'failed_to_success_ratio': 0.38002232142857145}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35787670396303906, 'total_requests': 5011.0, 'failed_to_success_ratio': 1.4515655577299413}
#   reward4: 0.6056
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 9 ok, 21 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622547527042143, 'total_requests': 4508.0, 'failed_to_success_ratio': 0.051305970149253734}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35956186154058334, 'total_requests': 4950.0, 'failed_to_success_ratio': 0.3795986622073579}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35787670396303906, 'total_requests': 5032.0, 'failed_to_success_ratio': 1.461839530332681}
#   reward4: 0.1969
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 14 ok, 16 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622141827575629, 'total_requests': 4512.0, 'failed_to_success_ratio': 0.05125815470643057}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35958946830162253, 'total_requests': 4955.0, 'failed_to_success_ratio': 0.3790704146952407}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578049178137964, 'total_requests': 5053.0, 'failed_to_success_ratio': 1.4660810151293313}
#   reward4: 0.2227
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622098730571711, 'total_requests': 4533.0, 'failed_to_success_ratio': 0.051008578715511246}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3596343707914887, 'total_requests': 4960.0, 'failed_to_success_ratio': 0.37854363535297386}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3577700810524178, 'total_requests': 5057.0, 'failed_to_success_ratio': 1.4632245494398441}
#   reward4: 0.6408
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 25 ok, 5 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36217799170616544, 'total_requests': 4554.0, 'failed_to_success_ratio': 0.05197505197505198}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3597183626721159, 'total_requests': 4965.0, 'failed_to_success_ratio': 0.37801831806827646}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35774266106014513, 'total_requests': 5061.0, 'failed_to_success_ratio': 1.4603791929995138}
#   reward4: 0.6207
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 24 ok, 6 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36216627655109357, 'total_requests': 4558.0, 'failed_to_success_ratio': 0.05192707131317794}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35961714356198377, 'total_requests': 4986.0, 'failed_to_success_ratio': 0.3781094527363184}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3577948300683714, 'total_requests': 5066.0, 'failed_to_success_ratio': 1.4568380213385064}
#   reward4: 0.5228
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36221388190055115, 'total_requests': 4579.0, 'failed_to_success_ratio': 0.051676619200734956}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3595812417906222, 'total_requests': 4991.0, 'failed_to_success_ratio': 0.37758763455699695}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35797072516987327, 'total_requests': 5070.0, 'failed_to_success_ratio': 1.4540174249757987}
#   reward4: 0.6283
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621935576302766, 'total_requests': 4582.0, 'failed_to_success_ratio': 0.05164103741106266}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35954240454885916, 'total_requests': 4997.0, 'failed_to_success_ratio': 0.3769633507853403}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.357988629054591, 'total_requests': 5091.0, 'failed_to_success_ratio': 1.457046332046332}
#   reward4: 0.2311
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 23 ok, 7 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622020817274661, 'total_requests': 4587.0, 'failed_to_success_ratio': 0.0515818431911967}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3595065565488623, 'total_requests': 5018.0, 'failed_to_success_ratio': 0.3774361789733736}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578551323221492, 'total_requests': 5095.0, 'failed_to_success_ratio': 1.4542389210019269}
#   reward4: 0.5549
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 15 ok, 15 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36217984924305346, 'total_requests': 4591.0, 'failed_to_success_ratio': 0.051534585432890516}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35945760611509303, 'total_requests': 5023.0, 'failed_to_success_ratio': 0.3769188596491228}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3576892634969353, 'total_requests': 5116.0, 'failed_to_success_ratio': 1.4572526416906821}
#   reward4: 0.2513
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 24 ok, 6 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621142222871578, 'total_requests': 4595.0, 'failed_to_success_ratio': 0.05148741418764302}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35940226104494144, 'total_requests': 5044.0, 'failed_to_success_ratio': 0.377013377013377}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.357761773933997, 'total_requests': 5121.0, 'failed_to_success_ratio': 1.4537613799712505}
#   reward4: 0.5754
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 19 ok, 11 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36211114403175104, 'total_requests': 4599.0, 'failed_to_success_ratio': 0.051440329218107}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35929165829240306, 'total_requests': 5065.0, 'failed_to_success_ratio': 0.3789817587802886}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3577776369504073, 'total_requests': 5126.0, 'failed_to_success_ratio': 1.4502868068833652}
#   reward4: 0.5748
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 29 ok, 1 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3620477947427661, 'total_requests': 4620.0, 'failed_to_success_ratio': 0.051194539249146756}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35932061450156383, 'total_requests': 5068.0, 'failed_to_success_ratio': 0.3786724700761698}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35781482017177574, 'total_requests': 5132.0, 'failed_to_success_ratio': 1.447305674773486}
#   reward4: 0.6731
# [Model4] Routing → http://127.0.0.1:8002
#   traffic: 10 ok, 20 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36204813387774976, 'total_requests': 4623.0, 'failed_to_success_ratio': 0.05115961800818554}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35937559302217875, 'total_requests': 5074.0, 'failed_to_success_ratio': 0.3780554046713743}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35787857044821125, 'total_requests': 5153.0, 'failed_to_success_ratio': 1.4561487130600572}
#   reward4: 0.2615
# [Model4] Routing → http://127.0.0.1:8001
#   traffic: 21 ok, 9 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3620398415214467, 'total_requests': 4625.0, 'failed_to_success_ratio': 0.05113636363636364}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3593457295472791, 'total_requests': 5095.0, 'failed_to_success_ratio': 0.37851731601731603}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35798302097015766, 'total_requests': 5160.0, 'failed_to_success_ratio': 1.4536376604850214}
#   reward4: 0.5848
# [Model4] Routing → http://127.0.0.1:8000
#   traffic: 30 ok, 0 failed
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36199106772094664, 'total_requests': 4646.0, 'failed_to_success_ratio': 0.05089346301741687}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3594473205583028, 'total_requests': 5101.0, 'failed_to_success_ratio': 0.37790383576445163}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35789819102584414, 'total_requests': 5163.0, 'failed_to_success_ratio': 1.4515669515669516}
#   reward4: 0.6785
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# Replay buffer ready.

# %%
#new claude code for training

import matplotlib.pyplot as plt
import os
import numpy as np
from IPython.display import clear_output

plot_dir = "training_plots"
os.makedirs(plot_dir, exist_ok=True)

# ---------------------------------------------------------------------------
# 4. Training the Agent with Visualization
# ---------------------------------------------------------------------------

num_iterations = 800
train_loss_history = []
eval_returns_history = []       # NEW
eval_steps_history = []         # NEW: x-axis points for reward curve

eval_interval = 200              # NEW: evaluate every 50 steps
num_eval_episodes = 1         # NEW: average over 5 episodes for stability

def evaluate_agent(env, policy, num_episodes, max_eval_steps=20):
    """Run greedy policy for num_episodes, return average return."""
    total_return = 0.0
    for _ in range(num_episodes):
        time_step = env.reset()
        episode_return = 0.0
        step_count = 0.0
        while not time_step.is_last() and step_count < max_eval_steps:
            action_step = policy.action(time_step)
            time_step = env.step(action_step.action)
            episode_return += time_step.reward.numpy()[0]
            step_count += 1
        total_return += episode_return
    return total_return / num_episodes

consecutive_increase_count = 0
max_consecutive_increases = 5

plt.ion()

for step in range(num_iterations):
    collect_step(train_env4, collect_policy, replay_buffer4)

    experience, unused_info = next(iterator4)
    train_loss = agent4.train(experience).loss.numpy()

    train_loss_history.append(train_loss)
    train_step_counter4.assign_add(1)

    # --- NEW: Evaluate every eval_interval steps ---
    current_step = train_step_counter4.numpy()
    if current_step % eval_interval == 0:
        avg_return = evaluate_agent(train_env4, agent4.policy, num_eval_episodes)
        eval_returns_history.append(avg_return)
        eval_steps_history.append(current_step)
        print(f'Step = {current_step}: Loss = {train_loss:.4f} | Avg Return = {avg_return:.4f}')

    # Early stopping checks
    if len(train_loss_history) > 1 and train_loss > train_loss_history[-2]:
        consecutive_increase_count += 1
    else:
        consecutive_increase_count = 0

    if np.isnan(train_loss) or train_loss > 100.0:
        print("Stopping: Loss has diverged.")
        break

    # --- MODIFIED: Plot both curves every 100 steps ---
    if current_step % 100 == 0:
        clear_output(wait=True)

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))  # side-by-side

        # Loss curve
        ax1.plot(train_loss_history, color="blue", label="Training Loss")
        ax1.set_xlabel("Training Steps")
        ax1.set_ylabel("Loss")
        ax1.set_title("Training Loss Over Time")
        ax1.legend()
        ax1.grid(True)

        # Reward curve
        if eval_returns_history:
            ax2.plot(eval_steps_history, eval_returns_history,
                     color="green", marker="o", label="Avg Eval Return")
            # Smoothed trend line
            if len(eval_returns_history) >= 5:
                smoothed = np.convolve(eval_returns_history,
                                       np.ones(5)/5, mode='valid')
                ax2.plot(eval_steps_history[4:], smoothed,
                         color="orange", linestyle="--", label="Smoothed (window=5)")
        ax2.set_xlabel("Training Steps")
        ax2.set_ylabel("Average Return")
        ax2.set_title("Evaluation Return Over Training")
        ax2.legend()
        ax2.grid(True)

        plt.tight_layout()
        plt.show()

        step_num = int(current_step // 10)
        fig.savefig(os.path.join(plot_dir, f"Output_{step_num}.png"))
        plt.close(fig)

plt.ioff()
print("Training completed successfully.")

# ---------------------------------------------------------------------------
# Final standalone reward plot (for paper)
# ---------------------------------------------------------------------------
plt.figure(figsize=(8, 5))
plt.plot(eval_steps_history, eval_returns_history,
         color="green", marker="o", label="Avg Eval Return")
if len(eval_returns_history) >= 5:
    smoothed = np.convolve(eval_returns_history, np.ones(5)/5, mode='valid')
    plt.plot(eval_steps_history[4:], smoothed,
             color="orange", linestyle="--", label="Smoothed (window=5)")
plt.xlabel("Training Steps")
plt.ylabel("Average Return")
plt.title("Evaluation Return Over Training (HAMR Agent)")
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(plot_dir, "eval_return_final.png"), dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Training completed successfully.

# %%
# ---------------------------------------------------------------------------
# Save trained policy
# ---------------------------------------------------------------------------
policy_dir4 = "loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model4"
os.makedirs(policy_dir4, exist_ok=True)

class ExportablePolicy(tf.Module):
    def __init__(self, policy):
        super().__init__()
        self.policy = policy

    @tf.function(input_signature=[
        ts.TimeStep(
            step_type   = tf.TensorSpec(shape=(1,), dtype=tf.int32,   name="step_type"),
            reward      = tf.TensorSpec(shape=(1,), dtype=tf.float32, name="reward"),
            discount    = tf.TensorSpec(shape=(1,), dtype=tf.float32, name="discount"),
            observation = tf.TensorSpec(shape=(1, 3, 3), dtype=tf.float32, name="observation")
        )
    ])
    def action(self, time_step):
        return self.policy.action(time_step).action

exportable4 = ExportablePolicy(agent4.policy)
tf.saved_model.save(exportable4, policy_dir4)

# Verify
loaded4 = tf.saved_model.load(policy_dir4)
print("Policy saved to:", policy_dir4)
print("Signatures:", list(loaded4.signatures.keys()))
# Out:
# C:\Users\hp\AppData\Local\Temp\__autograph_generated_filed4onrsac.py:14: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   retval_ = ag__.and_(lambda : ag__.ld(state) is not None, lambda : ag__.and_(lambda : ag__.ld(state) is not (), lambda : ag__.ld(state) is not []))
# C:\Users\hp\AppData\Local\Temp\__autograph_generated_filex9r8dj0t.py:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ag__.if_stmt(ag__.ld(policy_state) is (), if_body_2, else_body_2, get_state_2, set_state_2, ('do_return', 'retval_'), 2)
# INFO:tensorflow:Assets written to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model4\assets
# INFO:tensorflow:Assets written to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model4\assets
# Policy saved to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model4
# Signatures: ['serving_default']
