# %%
# %pip install gin-config
# %pip install absl-py
# %pip install gym==0.23.0
# %pip install matplot
# Out:
# Requirement already satisfied: gin-config in e:\loadbalancer\venv\lib\site-packages (0.5.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: absl-py in e:\loadbalancer\venv\lib\site-packages (2.4.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: gym==0.23.0 in e:\loadbalancer\venv\lib\site-packages (0.23.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (3.1.2)
# Requirement already satisfied: gym_notices>=0.0.4 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (0.1.0)
# Requirement already satisfied: numpy>=1.18.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: matplot in e:\loadbalancer\venv\lib\site-packages (0.1.9)Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: pyloco>=0.0.134 in e:\loadbalancer\venv\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: matplotlib>=3.1.1 in e:\loadbalancer\venv\lib\site-packages (from matplot) (3.10.8)
# Requirement already satisfied: numpy>=1.23 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (26.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.62.1)
# Requirement already satisfied: pillow>=8 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.5.0)
# Requirement already satisfied: cycler>=0.10 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: SimpleWebSocketServer in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: ushlex in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: typing in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: websocket-client in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (1.9.0)
# Requirement already satisfied: twine in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (6.2.0)
# Requirement already satisfied: six>=1.5 in e:\loadbalancer\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.17.0)
# Requirement already satisfied: rfc3986>=1.4.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.6.3)
# Requirement already satisfied: requests>=2.20 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Requirement already satisfied: keyring>=21.2.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (25.7.0)
# Requirement already satisfied: id in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.6.1)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: readme-renderer>=35.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (44.0)
# Requirement already satisfied: rich>=12.0.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.9.4)
# Requirement already satisfied: jaraco.context in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (6.1.1)
# Requirement already satisfied: jaraco.functools in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (4.4.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (0.2.3)
# Requirement already satisfied: jaraco.classes in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: importlib_metadata>=4.11.4 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (9.0.0)
# Requirement already satisfied: docutils>=0.21.2 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.22.4)
# Requirement already satisfied: Pygments>=2.5.1 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.19.2)
# Requirement already satisfied: nh3>=0.2.14 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2026.2.25)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.0.0)
# Requirement already satisfied: zipp>=3.20 in e:\loadbalancer\venv\lib\site-packages (from importlib_metadata>=4.11.4->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in e:\loadbalancer\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: more-itertools in e:\loadbalancer\venv\lib\site-packages (from jaraco.classes->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (10.8.0)
# Requirement already satisfied: backports.tarfile in e:\loadbalancer\venv\lib\site-packages (from jaraco.context->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (1.2.0)

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import re
from concurrent.futures import ThreadPoolExecutor, as_completed
import tensorflow as tf
import numpy as np 
import numpy as np
import requests 
import time

# TF‑Agents imports  
from tf_agents.environments import tf_py_environment  
from tf_agents.trajectories import trajectory
from tf_agents.networks import q_network
from tf_agents.agents.dqn import dqn_agent
from tf_agents.utils import common
from tf_agents.replay_buffers import tf_uniform_replay_buffer 
from tf_agents.policies import epsilon_greedy_policy

from tf_agents.environments import py_environment
from tf_agents.specs import array_spec
from tf_agents.trajectories import time_step as ts
# Out:
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_agents\typing\types.py:114: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
def getResponseFromServer():
    url = 'http://localhost:8005'

    try:
        response = requests.get(url)

        if response.status_code == 200:
            print("Successfully received response from load balancer")
            return
        else:
            print('Error:', response.status_code)
            return None
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
getResponseFromServer()
# Out:
# Successfully received response from load balancer

# %%
SERVER_METRICS_URL = "http://localhost:8005/server-metrics"
SERVERS = [
    "http://127.0.0.1:8000",
    "http://127.0.0.1:8001",
    "http://127.0.0.1:8002",
]

# %%
def _parse_prometheus_metrics(metrics_text: str) -> dict:
    """Extract aggregated metrics from Prometheus text format."""
    failed_count_match = re.search(
        r'flask_http_request_total\{method="GET",status="429"\}\s+([\d.]+)', metrics_text)
    failed_count = float(failed_count_match.group(1)) if failed_count_match else 0.0

    success_count_match = re.search(
        r'flask_http_request_total\{method="GET",status="200"\}\s+([\d.]+)', metrics_text)
    success_count = float(success_count_match.group(1)) if success_count_match else 0.0

    total_requests = failed_count + success_count

    success_sum_match = re.search(
        r'flask_http_request_duration_seconds_sum\{method="GET",path="/heavy-task",status="200"\}\s+([\d.]+)', metrics_text)
    success_sum = float(success_sum_match.group(1)) if success_sum_match else 0.0

    success_time_count_match = re.search(
        r'flask_http_request_duration_seconds_count\{method="GET",path="/heavy-task",status="200"\}\s+([\d.]+)', metrics_text)
    success_time_count = float(success_time_count_match.group(1)) if success_time_count_match else 0.0

    avg_success_response = success_sum / success_time_count if success_time_count > 0 else 0.0

    failed_to_success_ratio = failed_count / success_count if success_count > 0 else (float('inf') if total_requests > 0 else 0.5)

    return {
        "avg_successful_response_time": avg_success_response,
        "total_requests": total_requests,
        "failed_to_success_ratio": failed_to_success_ratio
    }

# %%
def generate_state(serverUrl):
    latency = []
    requests_handled = []
    failed_to_success_ratio = []

    for server in SERVERS:
        try:
            response = requests.get(f"{server}/metrics", timeout=2)
            response.raise_for_status()
            backend_metrics = _parse_prometheus_metrics(response.text)

            print(f"{server}: {backend_metrics}")

            raw_latency = backend_metrics.get("avg_successful_response_time", 0.0)
            latency.append(min(raw_latency / 5.0, 1.0))
            raw_requests = backend_metrics.get("total_requests", 0.0)
            requests_handled.append(min(raw_requests / 10000, 1.0))
            failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
        except requests.RequestException as e:
            print(f"Error fetching metrics from {server}: {e}")
            latency.append(1.0)
            requests_handled.append(0.0)
            failed_to_success_ratio.append(0.5)
      
    state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
    return state.astype(np.float32)

# %%
state = generate_state(SERVER_METRICS_URL)
print("Generated state:\n", state)
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# Generated state:
#  [[0.  0.  0.5]
#  [0.  0.  0.5]
#  [0.  0.  0.5]]

# %%
# ---------------------------------------------------------------------------
# REWARD-4: Adaptive SLA-Penalized Reliability Reward with Entropy Fairness Bonus
# ---------------------------------------------------------------------------
#
# Inputs (all already normalized to [0, 1] by _generate_state):
#   state_row[0]  latency_norm   = raw_latency / MAX_LATENCY
#   state_row[1]  requests_norm  = total_requests / MAX_REQUESTS  (unused here)
#   state_row[2]  failure_ratio  ∈ [0, 1]
#
# Parameters:
#   alpha       weight on the quadratic SLA-violation penalty   (default 1.0)
#   beta        weight on the failure-ratio penalty              (default 0.5)
#   lam         weight on the entropy fairness bonus             (default 0.2)
#   sla_norm    SLA latency threshold, already normalized        (default 0.1 = 0.5 s / 5.0 s)
#   action_history  list of recent server indices for entropy    (updated externally)
#   n_servers   total number of servers                          (default 3)
#
# Formula:
#   violation   = max(0, latency_norm - sla_norm)
#   latency_pen = alpha * violation^2          ← quadratic: punishes severe breaches harder
#   failure_pen = beta  * failure_ratio
#   entropy_H   = -sum_i[ p_i * log(p_i + eps) ]  over rolling action_history
#   fairness_bon= lam   * entropy_H / log(n_servers)   ← normalized to [0, 1] range
#
#   r4 = -latency_pen - failure_pen + fairness_bon
#
# ---------------------------------------------------------------------------

_action_history = []   # module-level rolling window, reset each episode

def reset_action_history():
    global _action_history
    _action_history = []

def compute_reward4(state_row,chosen_index, alpha=0.5,beta=0.3,lam=0.5, sla_norm=0.1, n_servers=3, history_window=10):
    """
    REWARD-4: Adaptive SLA-Penalized Reliability Reward with Entropy Fairness Bonus.

    Args:
        state_row     (np.ndarray): Normalized [latency_norm, requests_norm, failure_ratio].
        chosen_index  (int)       : Index of the server selected this step.
        alpha         (float)     : Quadratic SLA violation penalty weight.
        beta          (float)     : Failure ratio penalty weight.
        lam           (float)     : Entropy fairness bonus weight.
        sla_norm      (float)     : Normalized SLA latency threshold (e.g. 0.1 = 0.5 s).
        n_servers     (int)       : Total number of servers (for entropy normalization).
        history_window(int)       : Rolling window size for entropy calculation.

    Returns:
        float: Scalar reward signal.
    """
    global _action_history

    latency_norm  = float(state_row[0])
    failure_ratio = float(state_row[2])

    # ── Quadratic SLA-violation penalty ─────────────────────────────────────
    violation   = max(0.0, latency_norm - sla_norm)
    latency_pen = alpha * (violation ** 2)

    # ── Failure-ratio penalty ────────────────────────────────────────────────
    failure_pen = beta * failure_ratio

    # ── Entropy fairness bonus ───────────────────────────────────────────────
    _action_history.append(chosen_index)
    if len(_action_history) > history_window:
        _action_history.pop(0)

    counts = np.bincount(_action_history, minlength=n_servers).astype(np.float32)
    probs  = counts / counts.sum()
    eps    = 1e-8
    H      = -np.sum(probs * np.log(probs + eps))          # raw Shannon entropy
    H_max  = np.log(n_servers)                             # maximum possible entropy
    fairness_bon = lam * (H / H_max) 

    reward = -latency_pen - failure_pen + fairness_bon

    latency_slack = max(0.0, sla_norm - latency_norm) / sla_norm   # 0→1 as latency drops below SLA
    health_factor = max(0.0, 1.0 - failure_ratio / 1.0)            # fades out as failure_ratio → 1.0 (calibrated to real server range)
    bonus = 0.3 * latency_slack * health_factor
    reward += bonus

    return float(reward)

# %%
# ---------------------------------------------------------------------------
# Hyperparameters — identical to model2 for fair comparison
# ---------------------------------------------------------------------------
GAMMA                    = 0.99
NEURAL_NETWORK_HIDDEN_UNITS = (64, 64)
MAX_BUFFER_SIZE          = 10000
LEARNING_RATE            = 5e-5

# Reward-4 specific (documented for the paper)
REWARD4_ALPHA  = 0.2   # minimal — latency within SLA for all servers
REWARD4_BETA   = 0.3   # dominant — only differentiating signal
REWARD4_LAMBDA = 0.6   # meaningful fairness bonus that can push reward positive
REWARD4_SLA_NORM = 0.1   # 0.5 s threshold / 5.0 s MAX_LATENCY
REWARD4_HISTORY_WINDOW   = 10    # rolling window for entropy calculation

# %%
class LoadBalancerEnvModel4(py_environment.PyEnvironment):
    """
    RL environment for REWARD-4.
    Identical structure to model2 LoadBalancerEnv but uses compute_reward4().
    State normalization is applied inside _generate_state() so the Q-network
    always receives values in [0, 1] matching the BoundedArraySpec.
    """

    MAX_LATENCY  = 5.0      # seconds  — normalization cap
    MAX_REQUESTS = 10000.0  # requests — normalization cap

    def __init__(self, server_metrics_url, servers):
        super(LoadBalancerEnvModel4, self).__init__()
        self._servers            = servers
        self._num_servers        = len(servers)
        self._server_metrics_url = server_metrics_url

        # All 3 features normalized to [0, 1]
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(self._num_servers * 3,),   # flat: 9 values
            dtype=np.float32,
            minimum=np.array([0.0]*9, dtype=np.float32),
            maximum=np.array([1.0, 1.0, 5.0] * self._num_servers, dtype=np.float32),  # failure_ratio unbounded above 1
            name='observation'
        )
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(),
            dtype=np.int32,
            minimum=0,
            maximum=self._num_servers - 1,
            name='action'
        )

        self._episode_ended = False
        self._step_count    = 0
        self._max_steps     = 100

        reset_action_history()
        self._state = self._generate_state()

    # ── specs ─────────────────────────────────────────────────────────────────
    def action_spec(self):      return self._action_spec
    def observation_spec(self): return self._observation_spec

    # ── state ─────────────────────────────────────────────────────────────────
    def _generate_state(self):
        """
        Fetch metrics and normalize to [0, 1]:
          latency_norm  = raw_latency  / MAX_LATENCY   (clamped)
          requests_norm = total_reqs   / MAX_REQUESTS  (clamped)
          failure_ratio already in [0, 1]
        """
        latency = []
        requests_handled = []
        failed_to_success_ratio = []

        for server in SERVERS:
            try:
                response = requests.get(f"{server}/metrics", timeout=2)
                response.raise_for_status()
                backend_metrics = _parse_prometheus_metrics(response.text)

                print(f"{server}: {backend_metrics}")

                raw_latency = backend_metrics.get("avg_successful_response_time", 1.0)
                latency.append(min(raw_latency / 5.0, 1.0))
                raw_requests = backend_metrics.get("total_requests", 0.0)
                requests_handled.append(min(raw_requests / 10000, 1.0))
                failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
            except requests.RequestException as e:
                print(f"Error fetching metrics from {server}: {e}")
                latency.append(1.0)
                requests_handled.append(0.0)
                failed_to_success_ratio.append(0.5)
    
        state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
        return state.flatten().astype(np.float32) 

    # ── reset ─────────────────────────────────────────────────────────────────
    def _reset(self):
        self._episode_ended = False
        self._step_count    = 0
        reset_action_history()          # clear entropy window each episode
        self._state = self._generate_state()
        return ts.restart(self._state)

    # ── step ──────────────────────────────────────────────────────────────────
    def _step(self, action):
        if self._episode_ended:
            return self.reset()

        self._step_count += 1
        chosen_index  = int(action)
        chosen_server = self._servers[chosen_index]
        print(f"[Model4] Routing → {chosen_server}")

        # Send 50 requests: 70% to chosen, 30% spread across others
        total_requests      = 30
        chosen_requests     = int(total_requests * 0.7)
        remaining_requests = total_requests - chosen_requests  # 30% to others

        # Instead of all at once, send in small batches
        batch_size = 10
        delay_between_batches = 0.1  # 100ms

        other_indices  = [i for i in range(self._num_servers) if i != chosen_index]

        request_targets        = [f"{chosen_server}/heavy-task"] * chosen_requests
        for _ in range(total_requests - chosen_requests):
            request_targets.append(f"{self._servers[np.random.choice(other_indices)]}/heavy-task")

        # Send the requests concurrently using ThreadPoolExecutor
        responses = []
        for i in range(0, len(request_targets), batch_size):
            batch = request_targets[i:i + batch_size]
            with ThreadPoolExecutor(max_workers=batch_size) as executor:
                futures = [executor.submit(requests.get, target, timeout=5) for target in batch]
                for future in as_completed(futures):
                    try:
                        resp = future.result()
                        responses.append(resp.status_code)
                    except Exception as e:
                        responses.append(None)
            time.sleep(delay_between_batches)

        success_count = sum(1 for r in responses if r == 200)
        failure_count = sum(1 for r in responses if r is None or r != 200)

        print(f"Simulated traffic: {success_count} successes, {failure_count} failures.")

        new_state = self._generate_state()

        start = chosen_index * 3
        # REWARD-4 — uses normalized state + entropy over rolling action window
        reward = compute_reward4(
            state_row      = new_state[start:start+3],
            chosen_index   = chosen_index,
            alpha          = REWARD4_ALPHA,
            beta           = REWARD4_BETA,
            lam            = REWARD4_LAMBDA,
            sla_norm       = REWARD4_SLA_NORM,
            n_servers      = self._num_servers,
            history_window = REWARD4_HISTORY_WINDOW,
        )
        print(f"  reward4: {reward:.4f}")

        self._state = new_state

        if self._step_count >= self._max_steps:
            self._episode_ended = True
            return ts.termination(self._state, reward)
        return ts.transition(self._state, reward=reward, discount=0.99)

# %%
# Quick sanity check — run this with your servers live
env4 = LoadBalancerEnvModel4(SERVER_METRICS_URL, SERVERS)
init_ts = env4.reset()
print("Initial state (normalized):\n", init_ts.observation)

test_ts = env4._step(0)
print("After step 0 — state:\n", test_ts.observation)
print("After step 0 — reward4:", test_ts.reward)
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# Initial state (normalized):
#  [0.  0.  0.5 0.  0.  0.5 0.  0.  0.5]
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 23 successes, 7 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.387799187519704, 'total_requests': 21.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36298899992834777, 'total_requests': 2.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.324402519967407, 'total_requests': 7.0, 'failed_to_success_ratio': 0.4}
#   reward4: -0.0475
# After step 0 — state:
#  [7.7559836e-02 2.0999999e-03 3.1250000e-01 7.2597802e-02 1.9999999e-04
#  0.0000000e+00 6.4880505e-02 6.9999998e-04 4.0000001e-01]
# After step 0 — reward4: -0.04746716

# %%
# ---------------------------------------------------------------------------
# Build TF-Agents environment and DQN agent
# ---------------------------------------------------------------------------
train_env = tf_py_environment.TFPyEnvironment(env4)

q_net4 = q_network.QNetwork(
    train_env.observation_spec(),
    train_env.action_spec(),
    fc_layer_params=NEURAL_NETWORK_HIDDEN_UNITS
)

optimizer4 = tf.keras.optimizers.Adam(learning_rate=5e-5, clipnorm=1.0)
train_step_counter = tf.Variable(0)

agent = dqn_agent.DqnAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    q_network=q_net4,
    optimizer=optimizer4,
    gamma=GAMMA,
    target_update_tau = 1,
    target_update_period=100,
    td_errors_loss_fn=common.element_wise_huber_loss,
    train_step_counter=train_step_counter
)
agent.initialize()
print("Agent4 initialized.")
# Out:
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Agent4 initialized.

# %%
# ---------------------------------------------------------------------------
# Replay buffer and initial data collection
# ---------------------------------------------------------------------------

eval_env4 = LoadBalancerEnvModel4(SERVER_METRICS_URL, SERVERS)
eval_tf_env = tf_py_environment.TFPyEnvironment(eval_env4)

replay_buffer4 = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec  = agent.collect_data_spec,
    batch_size = train_env.batch_size,
    max_length = MAX_BUFFER_SIZE
)

EPSILON_GREEDY_START = 1.0
EPSILON_GREEDY_END   = 0.1
EPSILON_DECAY_STEPS  = 2000

epsilon = tf.compat.v1.train.polynomial_decay(
    learning_rate=EPSILON_GREEDY_START,
    global_step=train_step_counter,
    decay_steps=EPSILON_DECAY_STEPS,
    end_learning_rate=EPSILON_GREEDY_END
)

collect_policy = epsilon_greedy_policy.EpsilonGreedyPolicy(
    agent.policy, epsilon=epsilon
)

def collect_step(environment, policy, buffer):
    time_step   = environment.current_time_step()
    action_step = policy.action(time_step)
    next_ts     = environment.step(action_step.action)
    traj        = trajectory.from_transition(time_step, action_step, next_ts)
    buffer.add_batch(traj)

INITIAL_COLLECT_STEPS = 500
print(f"Collecting {INITIAL_COLLECT_STEPS} initial steps...")
for _ in range(INITIAL_COLLECT_STEPS):
    collect_step(train_env, collect_policy, replay_buffer4)

BATCH_SIZE = 64
dataset4   = replay_buffer4.as_dataset(
    sample_batch_size = BATCH_SIZE,
    num_steps         = 2
).prefetch(3)
iterator4 = iter(dataset4)
print("Replay buffer ready.")
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.387799187519704, 'total_requests': 21.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36298899992834777, 'total_requests': 2.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.324402519967407, 'total_requests': 7.0, 'failed_to_success_ratio': 0.4}
# Collecting 500 initial steps...
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.387799187519704, 'total_requests': 21.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36298899992834777, 'total_requests': 2.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.324402519967407, 'total_requests': 7.0, 'failed_to_success_ratio': 0.4}
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.38174875625554705, 'total_requests': 42.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35717960001784377, 'total_requests': 8.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3351442874991335, 'total_requests': 10.0, 'failed_to_success_ratio': 0.25}
#   reward4: -0.0450
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3706893415216638, 'total_requests': 63.0, 'failed_to_success_ratio': 0.18867924528301888}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3345795416777643, 'total_requests': 12.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3206484769291889, 'total_requests': 15.0, 'failed_to_success_ratio': 0.15384615384615385}
#   reward4: 0.0063
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 9 successes, 21 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36873002414960926, 'total_requests': 68.0, 'failed_to_success_ratio': 0.1724137931034483}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.34312737500295043, 'total_requests': 16.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3206484769291889, 'total_requests': 36.0, 'failed_to_success_ratio': 1.7692307692307692}
#   reward4: -0.1831
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3702208860718374, 'total_requests': 89.0, 'failed_to_success_ratio': 0.12658227848101267}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3528582700178958, 'total_requests': 20.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36115063888589954, 'total_requests': 41.0, 'failed_to_success_ratio': 1.2777777777777777}
#   reward4: 0.3372
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 23 successes, 7 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36623696736550254, 'total_requests': 110.0, 'failed_to_success_ratio': 0.15789473684210525}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35596636366310785, 'total_requests': 22.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3554781304328176, 'total_requests': 48.0, 'failed_to_success_ratio': 1.0869565217391304}
#   reward4: 0.2935
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3681707316825148, 'total_requests': 116.0, 'failed_to_success_ratio': 0.1485148514851485}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36483573250588963, 'total_requests': 43.0, 'failed_to_success_ratio': 0.075}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36104333076554423, 'total_requests': 51.0, 'failed_to_success_ratio': 0.9615384615384616}
#   reward4: 0.5263
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3690610917358205, 'total_requests': 137.0, 'failed_to_success_ratio': 0.1322314049586777}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36415080228206614, 'total_requests': 47.0, 'failed_to_success_ratio': 0.06818181818181818}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.34938918063116653, 'total_requests': 56.0, 'failed_to_success_ratio': 0.8064516129032258}
#   reward4: 0.4634
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36921806277088604, 'total_requests': 158.0, 'failed_to_success_ratio': 0.15328467153284672}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36668476735583827, 'total_requests': 52.0, 'failed_to_success_ratio': 0.061224489795918366}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35438004285097124, 'total_requests': 60.0, 'failed_to_success_ratio': 0.7142857142857143}
#   reward4: 0.4222
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36701635442839203, 'total_requests': 179.0, 'failed_to_success_ratio': 0.13291139240506328}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36807121539291426, 'total_requests': 55.0, 'failed_to_success_ratio': 0.057692307692307696}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3513854724995326, 'total_requests': 66.0, 'failed_to_success_ratio': 0.65}
#   reward4: 0.4027
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3656660327540668, 'total_requests': 200.0, 'failed_to_success_ratio': 0.14942528735632185}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3695700254587626, 'total_requests': 58.0, 'failed_to_success_ratio': 0.05454545454545454}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3548948111116058, 'total_requests': 72.0, 'failed_to_success_ratio': 0.6}
#   reward4: 0.3727
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3656910569192125, 'total_requests': 221.0, 'failed_to_success_ratio': 0.13333333333333333}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.372259506907571, 'total_requests': 61.0, 'failed_to_success_ratio': 0.05172413793103448}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3537329120049253, 'total_requests': 78.0, 'failed_to_success_ratio': 0.56}
#   reward4: 0.3788
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36542712653638415, 'total_requests': 242.0, 'failed_to_success_ratio': 0.14691943127962084}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3727950984466588, 'total_requests': 67.0, 'failed_to_success_ratio': 0.046875}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3529050792479571, 'total_requests': 81.0, 'failed_to_success_ratio': 0.5283018867924528}
#   reward4: 0.3738
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3673528633602285, 'total_requests': 263.0, 'failed_to_success_ratio': 0.1336206896551724}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.37211318592816384, 'total_requests': 74.0, 'failed_to_success_ratio': 0.04225352112676056}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35150514181957326, 'total_requests': 83.0, 'failed_to_success_ratio': 0.509090909090909}
#   reward4: 0.2064
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.366222064916773, 'total_requests': 284.0, 'failed_to_success_ratio': 0.14516129032258066}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.37659313948518647, 'total_requests': 79.0, 'failed_to_success_ratio': 0.039473684210526314}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35440645593818343, 'total_requests': 87.0, 'failed_to_success_ratio': 0.4745762711864407}
#   reward4: 0.2026
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3655291131448995, 'total_requests': 287.0, 'failed_to_success_ratio': 0.14342629482071714}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.37495370976706377, 'total_requests': 85.0, 'failed_to_success_ratio': 0.036585365853658534}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3507033984678296, 'total_requests': 108.0, 'failed_to_success_ratio': 0.6615384615384615}
#   reward4: 0.1809
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 23 successes, 7 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3648299179658352, 'total_requests': 292.0, 'failed_to_success_ratio': 0.140625}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3710860218828505, 'total_requests': 106.0, 'failed_to_success_ratio': 0.10416666666666667}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3516715072480071, 'total_requests': 112.0, 'failed_to_success_ratio': 0.6231884057971014}
#   reward4: 0.3870
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3657341130243764, 'total_requests': 297.0, 'failed_to_success_ratio': 0.13793103448275862}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.369118915006984, 'total_requests': 110.0, 'failed_to_success_ratio': 0.1}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3553206813366463, 'total_requests': 133.0, 'failed_to_success_ratio': 0.7733333333333333}
#   reward4: 0.2256
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36521778943122557, 'total_requests': 301.0, 'failed_to_success_ratio': 0.13584905660377358}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3692382219070125, 'total_requests': 115.0, 'failed_to_success_ratio': 0.09523809523809523}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35314274750417096, 'total_requests': 154.0, 'failed_to_success_ratio': 0.925}
#   reward4: 0.2195
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3636620276187501, 'total_requests': 322.0, 'failed_to_success_ratio': 0.1258741258741259}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3718981972962685, 'total_requests': 121.0, 'failed_to_success_ratio': 0.09009009009009009}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35475229277241843, 'total_requests': 157.0, 'failed_to_success_ratio': 0.891566265060241}
#   reward4: 0.5242
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 21 successes, 9 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3633528013847859, 'total_requests': 324.0, 'failed_to_success_ratio': 0.125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.37150347359851005, 'total_requests': 142.0, 'failed_to_success_ratio': 0.136}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35367889317884954, 'total_requests': 164.0, 'failed_to_success_ratio': 0.8636363636363636}
#   reward4: 0.5882
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621279368568021, 'total_requests': 329.0, 'failed_to_success_ratio': 0.12286689419795221}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.
:\LoadBalancer\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# Replay buffer ready.

# %%
#new claude code for training

import matplotlib.pyplot as plt
import os
import numpy as np
from IPython.display import clear_output

plot_dir = "training_plots"
os.makedirs(plot_dir, exist_ok=True)

# ---------------------------------------------------------------------------
# 4. Training the Agent with Visualization
# ---------------------------------------------------------------------------

num_iterations = 1000
train_loss_history = []
eval_returns_history = []       # NEW
eval_steps_history = []         # NEW: x-axis points for reward curve

eval_interval = 200              # NEW: evaluate every 50 steps
num_eval_episodes = 1         # NEW: average over 5 episodes for stability

def evaluate_agent(env, policy, num_episodes, max_eval_steps=20):
    """Run greedy policy for num_episodes, return average return."""
    total_return = 0.0
    for _ in range(num_episodes):
        time_step = env.reset()
        episode_return = 0.0
        step_count = 0.0
        while not time_step.is_last() and step_count < max_eval_steps:
            action_step = policy.action(time_step)
            time_step = env.step(action_step.action)
            episode_return += time_step.reward.numpy()[0]
            step_count += 1
        total_return += episode_return
    return total_return / num_episodes

consecutive_increase_count = 0
max_consecutive_increases = 5

plt.ion()

for step in range(num_iterations):
    collect_step(train_env, collect_policy, replay_buffer4)

    experience, unused_info = next(iterator4)
    train_loss = agent.train(experience).loss.numpy()

    train_loss_history.append(train_loss)
    train_step_counter.assign_add(1)

    # --- NEW: Evaluate every eval_interval steps ---
    current_step = train_step_counter.numpy()
    if current_step % eval_interval == 0:
        avg_return = evaluate_agent(eval_tf_env, agent.policy, num_eval_episodes)
        eval_returns_history.append(avg_return)
        eval_steps_history.append(current_step)
        print(f'Step = {current_step}: Loss = {train_loss:.4f} | Avg Return = {avg_return:.4f}')

    # Early stopping checks
    if len(train_loss_history) > 1 and train_loss > train_loss_history[-2]:
        consecutive_increase_count += 1
    else:
        consecutive_increase_count = 0

    if np.isnan(train_loss) or train_loss > 100.0:
        print("Stopping: Loss has diverged.")
        break

    # --- MODIFIED: Plot both curves every 100 steps ---
    if current_step % 100 == 0:
        clear_output(wait=True)

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))  # side-by-side

        # Loss curve
        ax1.plot(train_loss_history, color="blue", label="Training Loss")
        ax1.set_xlabel("Training Steps")
        ax1.set_ylabel("Loss")
        ax1.set_title("Training Loss Over Time")
        ax1.legend()
        ax1.grid(True)

        # Reward curve
        if eval_returns_history:
            ax2.plot(eval_steps_history, eval_returns_history,
                     color="green", marker="o", label="Avg Eval Return")
            # Smoothed trend line
            if len(eval_returns_history) >= 5:
                smoothed = np.convolve(eval_returns_history,
                                       np.ones(5)/5, mode='valid')
                ax2.plot(eval_steps_history[4:], smoothed,
                         color="orange", linestyle="--", label="Smoothed (window=5)")
        ax2.set_xlabel("Training Steps")
        ax2.set_ylabel("Average Return")
        ax2.set_title("Evaluation Return Over Training")
        ax2.legend()
        ax2.grid(True)

        plt.tight_layout()
        plt.show()

        step_num = int(current_step // 10)
        fig.savefig(os.path.join(plot_dir, f"Output_{step_num}.png"))
        plt.close(fig)

plt.ioff()
print("Training completed successfully.")

# ---------------------------------------------------------------------------
# Final standalone reward plot (for paper)
# ---------------------------------------------------------------------------
plt.figure(figsize=(8, 5))
plt.plot(eval_steps_history, eval_returns_history,
         color="green", marker="o", label="Avg Eval Return")
if len(eval_returns_history) >= 5:
    smoothed = np.convolve(eval_returns_history, np.ones(5)/5, mode='valid')
    plt.plot(eval_steps_history[4:], smoothed,
             color="orange", linestyle="--", label="Smoothed (window=5)")
plt.xlabel("Training Steps")
plt.ylabel("Average Return")
plt.title("Evaluation Return Over Training (HAMR Agent)")
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(plot_dir, "eval_return_final.png"), dpi=150, bbox_inches='tight')
plt.show()
# Out:
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36289165444405935, 'total_requests': 18019.0, 'failed_to_success_ratio': 0.07556855488569211}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3719586952547879, 'total_requests': 15618.0, 'failed_to_success_ratio': 0.3670021881838074}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3180708454392103, 'total_requests': 13433.0, 'failed_to_success_ratio': 1.0313019809466204}
#   reward4: -0.0615
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36289067011584586, 'total_requests': 18024.0, 'failed_to_success_ratio': 0.07554600787683495}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3719619276914589, 'total_requests': 15622.0, 'failed_to_success_ratio': 0.3668737422346662}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3179193569684786, 'total_requests': 13454.0, 'failed_to_success_ratio': 1.0341699425461144}
#   reward4: -0.1381
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628838208485794, 'total_requests': 18025.0, 'failed_to_success_ratio': 0.07554150008950415}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3719319920564154, 'total_requests': 15643.0, 'failed_to_success_ratio': 0.3667977282656182}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3171759519549384, 'total_requests': 13462.0, 'failed_to_success_ratio': 1.0338419700861157}
#   reward4: 0.1162
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362852263766498, 'total_requests': 18046.0, 'failed_to_success_ratio': 0.07544696066746126}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3719422571440953, 'total_requests': 15646.0, 'failed_to_success_ratio': 0.366701607267645}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3164171205902377, 'total_requests': 13468.0, 'failed_to_success_ratio': 1.0332125603864735}
#   reward4: 0.4024
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36283144101887244, 'total_requests': 18051.0, 'failed_to_success_ratio': 0.07542448614834674}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3977229608220283, 'total_requests': 15667.0, 'failed_to_success_ratio': 0.36638758067329497}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3158333015222567, 'total_requests': 13472.0, 'failed_to_success_ratio': 1.0325890162945082}
#   reward4: 0.2326
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628416612640953, 'total_requests': 18054.0, 'failed_to_success_ratio': 0.07541100786275912}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3968436582333386, 'total_requests': 15688.0, 'failed_to_success_ratio': 0.3670268386197281}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.315080958343009, 'total_requests': 13478.0, 'failed_to_success_ratio': 1.0319614050957335}
#   reward4: 0.2325
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628339204515071, 'total_requests': 18057.0, 'failed_to_success_ratio': 0.07539753439342504}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.395924685746643, 'total_requests': 15709.0, 'failed_to_success_ratio': 0.36766498345812293}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3143478720682513, 'total_requests': 13484.0, 'failed_to_success_ratio': 1.031334739379331}
#   reward4: 0.2323
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362834134490432, 'total_requests': 18062.0, 'failed_to_success_ratio': 0.07537508930697785}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.395031500329349, 'total_requests': 15730.0, 'failed_to_success_ratio': 0.3683020180932498}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3138073326240765, 'total_requests': 13488.0, 'failed_to_success_ratio': 1.0307136404697381}
#   reward4: 0.2321
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628400629703122, 'total_requests': 18066.0, 'failed_to_success_ratio': 0.07535714285714286}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3941267356584701, 'total_requests': 15751.0, 'failed_to_success_ratio': 0.368937945419781}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627268673182813, 'total_requests': 18211.0, 'failed_to_success_ratio': 0.07547392665209945}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.388235109202076, 'total_requests': 15850.0, 'failed_to_success_ratio': 0.36968544763221567}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.307558657290733, 'total_requests': 13549.0, 'failed_to_success_ratio': 1.0267763649962602}
#   reward4: 0.2996
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627312660983927, 'total_requests': 18232.0, 'failed_to_success_ratio': 0.07569768127913151}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3875392269590645, 'total_requests': 15858.0, 'failed_to_success_ratio': 0.3694300518134715}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.307414080300406, 'total_requests': 13550.0, 'failed_to_success_ratio': 1.0266227938976966}
#   reward4: 0.2774
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627188943843585, 'total_requests': 18253.0, 'failed_to_success_ratio': 0.0756040070713023}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3872653907265637, 'total_requests': 15861.0, 'failed_to_success_ratio': 0.36933436933436936}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3067067597053252, 'total_requests': 13556.0, 'failed_to_success_ratio': 1.0260050814526978}
#   reward4: 0.2592
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627169692218464, 'total_requests': 18274.0, 'failed_to_success_ratio': 0.07582715177204757}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3869401809256763, 'total_requests': 15865.0, 'failed_to_success_ratio': 0.3692068697678433}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3059807750729195, 'total_requests': 13561.0, 'failed_to_success_ratio': 1.0252389486260454}
#   reward4: 0.2439
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36274076057521054, 'total_requests': 18295.0, 'failed_to_success_ratio': 0.0757335214911507}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3866029114559215, 'total_requests': 15869.0, 'failed_to_success_ratio': 0.36907945820032784}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3052111216069924, 'total_requests': 13566.0, 'failed_to_success_ratio': 1.0244739591105805}
#   reward4: 0.2309
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627394888446806, 'total_requests': 18316.0, 'failed_to_success_ratio': 0.07595605944898079}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.386134583173981, 'total_requests': 15874.0, 'failed_to_success_ratio': 0.3689203173508106}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.30463000955831, 'total_requests': 13570.0, 'failed_to_success_ratio': 1.0238627889634602}
#   reward4: 0.0533
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627420902841432, 'total_requests': 18337.0, 'failed_to_success_ratio': 0.075862473597747}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3859610863067378, 'total_requests': 15876.0, 'failed_to_success_ratio': 0.36885669943093635}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3039202360490103, 'total_requests': 13577.0, 'failed_to_success_ratio': 1.023397913561848}
#   reward4: 0.0533
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627402491027123, 'total_requests': 18341.0, 'failed_to_success_ratio': 0.0758446738620366}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3843430999299087, 'total_requests': 15897.0, 'failed_to_success_ratio': 0.36854338842975204}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3031890146223146, 'total_requests': 13582.0, 'failed_to_success_ratio': 1.0226358897989576}
#   reward4: 0.0607
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362771365100706, 'total_requests': 18362.0, 'failed_to_success_ratio': 0.07575136211846037}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3839831160314913, 'total_requests': 15901.0, 'failed_to_success_ratio': 0.3684165232358003}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3025215331233215, 'total_requests': 13587.0, 'failed_to_success_ratio': 1.021875}
#   reward4: 0.2309
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36277941506611383, 'total_requests': 18383.0, 'failed_to_success_ratio': 0.07597307579748318}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3835303584676115, 'total_requests': 15906.0, 'failed_to_success_ratio': 0.368258064516129}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3019352732285119, 'total_requests': 13591.0, 'failed_to_success_ratio': 1.0212671029149316}
#   reward4: 0.2308
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36280474248827044, 'total_requests': 18404.0, 'failed_to_success_ratio': 0.07587980825441365}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3830960601277735, 'total_requests': 15911.0, 'failed_to_success_ratio': 0.36809974204643164}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.3013709993592026, 'total_requests': 13595.0, 'failed_to_success_ratio': 1.0206599286563616}
#   reward4: 0.2308
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36281747217051047, 'total_requests': 18425.0, 'failed_to_success_ratio': 0.07610092278939376}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3826361596721997, 'total_requests': 15916.0, 'failed_to_success_ratio': 0.36794155565105285}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.300805381890775, 'total_requests': 13599.0, 'failed_to_success_ratio': 1.0200534759358288}
#   reward4: 0.2308
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628251610629696, 'total_requests': 18428.0, 'failed_to_success_ratio': 0.07608759124087591}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.38209975343924, 'total_requests': 15922.0, 'failed_to_success_ratio': 0.36775191134782237}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2999654182975293, 'total_requests': 13620.0, 'failed_to_success_ratio': 1.0213713268032056}
#   reward4: 0.0375
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628157057857681, 'total_requests': 18449.0, 'failed_to_success_ratio': 0.07599440102647848}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3816499351095781, 'total_requests': 15927.0, 'failed_to_success_ratio': 0.36759402369912414}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2994502634068705, 'total_requests': 13624.0, 'failed_to_success_ratio': 1.0207653515277366}
#   reward4: 0.4023
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36280582309189086, 'total_requests': 18470.0, 'failed_to_success_ratio': 0.07621489336907121}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3815538749537413, 'total_requests': 15928.0, 'failed_to_success_ratio': 0.36756246243667895}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2987663513693761, 'total_requests': 13632.0, 'failed_to_success_ratio': 1.020453534904402}
#   reward4: 0.4022
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36280319771076625, 'total_requests': 18474.0, 'failed_to_success_ratio': 0.07619713386927647}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.37990070228755, 'total_requests': 15949.0, 'failed_to_success_ratio': 0.36713526487227843}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2980413175339318, 'total_requests': 13637.0, 'failed_to_success_ratio': 1.0196978672985781}
#   reward4: 0.3216
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628342909061049, 'total_requests': 18495.0, 'failed_to_success_ratio': 0.07610403211729795}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3793379937617083, 'total_requests': 15955.0, 'failed_to_success_ratio': 0.3669465387251542}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2976309230332252, 'total_requests': 13640.0, 'failed_to_success_ratio': 1.0192450037009622}
#   reward4: 0.4911
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628731459747302, 'total_requests': 18516.0, 'failed_to_success_ratio': 0.07632389699471022}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3790054026538747, 'total_requests': 15959.0, 'failed_to_success_ratio': 0.3668208290510449}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2969692873209164, 'total_requests': 13645.0, 'failed_to_success_ratio': 1.018491124260355}
#   reward4: 0.4021
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628913635800499, 'total_requests': 18537.0, 'failed_to_success_ratio': 0.07623084068741291}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3787251810246555, 'total_requests': 15962.0, 'failed_to_success_ratio': 0.3667266033050775}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2962834537013435, 'total_requests': 13651.0, 'failed_to_success_ratio': 1.0178861788617886}
#   reward4: 0.4021
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36290960138648254, 'total_requests': 18558.0, 'failed_to_success_ratio': 0.07645011600928074}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3783858816902204, 'total_requests': 15966.0, 'failed_to_success_ratio': 0.3666010442523325}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.295605075168334, 'total_requests': 13656.0, 'failed_to_success_ratio': 1.0171344165435745}
#   reward4: 0.4020
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628902880193926, 'total_requests': 18579.0, 'failed_to_success_ratio': 0.07635710561381148}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3779580555515587, 'total_requests': 15971.0, 'failed_to_success_ratio': 0.3664442162902122}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2950195689828077, 'total_requests': 13660.0, 'failed_to_success_ratio': 1.0165338057277826}
#   reward4: 0.4021
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36288453348395994, 'total_requests': 18600.0, 'failed_to_success_ratio': 0.07657579440875152}
# http://127.0.0.1:8001: {'avg_successful_response_time': 1.3776207395387257, 'total_requests': 15975.0, 'failed_to_success_ratio': 0.36631885049606566}
# http://127.0.0.1:8002: {'avg_successful_response_time': 1.2944122566143978, 'total_requests': 13665.0, 'failed_to_success_ratio': 1.015784038943797}
#   reward4: 0.4020
# [Model4] Routing → http://127.0.0.1:8000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 44
#      41 plt.ion()
#      43 for step in range(num_iterations):
# ---> 44     collect_step(train_env, collect_policy, replay_buffer4)
#      46     experience, unused_info = next(iterator4)
#      47     train_loss = agent.train(experience).loss.numpy()
#
# Cell In[15], line 32, in collect_step(environment, policy, buffer)
#      30 time_step   = environment.current_time_step()
#      31 action_step = policy.action(time_step)
# ---> 32 next_ts     = environment.step(action_step.action)
#      33 traj        = trajectory.from_transition(time_step, action_step, next_ts)
#      34 buffer.add_batch(traj)
#
# File e:\LoadBalancer\venv\lib\site-packages\tf_agents\environments\tf_environment.py:241, in TFEnvironment.step(self, action)
#     211 def step(self, action):
#     212   """Steps the environment according to the action.
#     213
#     214   If the environment returned a `TimeStep` with `StepType.LAST` at the
#    (...)
#     239         corresponding to `observation_spec()`.
#     240   """
# --> 241   return self._step(action)
#
# File e:\LoadBalancer\venv\lib\site-packages\tf_agents\environments\tf_py_environment.py:320, in TFPyEnvironment._step(self, actions)
#     312     if action.shape.rank == 0 or (
#     313         dim_value is not None and dim_value != self.batch_size
#     314     ):
#     315       raise ValueError(
#     316           'Expected actions whose major dimension is batch_size (%d), '
#     317           'but saw action with shape %s:\n   %s'
#     318           % (self.batch_size, action.shape, action)
#     319       )
# --> 320 outputs = tf.numpy_function(
#     321     _isolated_step_py,
#     322     flat_actions,
#     323     self._time_step_dtypes,
#     324     name='step_py_func',
#     325 )
#     326 return self._time_step_from_numpy_function_outputs(outputs)
#
# File e:\LoadBalancer\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File e:\LoadBalancer\venv\lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File e:\LoadBalancer\venv\lib\site-packages\tensorflow\python\ops\script_ops.py:945, in numpy_function(func, inp, Tout, stateful, name)
#     942 if decorator is not None:
#     943   return decorator
# --> 945 return py_func_common(func, inp, Tout, stateful=stateful, name=name)
#
# File e:\LoadBalancer\venv\lib\site-packages\tensorflow\python\ops\script_ops.py:754, in py_func_common(func, inp, Tout, stateful, name)
#     645 """Wraps a python function and uses it as a TensorFlow op.
#     646
#     647 Given a python function `func`, which takes numpy arrays as its
#    (...)
#     751
#     752 """
#     753 if context.executing_eagerly():
# --> 754   result = func(*[np.array(x) for x in inp])
#     755   result = nest.flatten(result)
#     757   result = [x if x is None else ops.convert_to_tensor(x) for x in result]
#
# File e:\LoadBalancer\venv\lib\site-packages\tf_agents\environments\tf_py_environment.py:305, in TFPyEnvironment._step.<locals>._isolated_step_py(*flattened_actions)
#     304 def _isolated_step_py(*flattened_actions):
# --> 305   return self._execute(_step_py, *flattened_actions)
#
# File e:\LoadBalancer\venv\lib\site-packages\tf_agents\environments\tf_py_environment.py:214, in TFPyEnvironment._execute(self, fn, *args, **kwargs)
#     212 def _execute(self, fn, *args, **kwargs):
#     213   if not self._pool:
# --> 214     return fn(*args, **kwargs)
#     215   return self._pool.apply(fn, args=args, kwds=kwargs)
#
# File e:\LoadBalancer\venv\lib\site-packages\tf_agents\environments\tf_py_environment.py:301, in TFPyEnvironment._step.<locals>._step_py(*flattened_actions)
#     297 with _check_not_called_concurrently(self._lock):
#     298   packed = tf.nest.pack_sequence_as(
#     299       structure=self.action_spec(), flat_sequence=flattened_actions
#     300   )
# --> 301   self._time_step = self._env.step(packed)
#     302   return tf.nest.flatten(self._time_step)
#
# File e:\LoadBalancer\venv\lib\site-packages\tf_agents\environments\py_environment.py:238, in PyEnvironment.step(self, action)
#     233 if self._current_time_step is None or self.should_reset(
#     234     self._current_time_step
#     235 ):
#     236   return self.reset()
# --> 238 self._current_time_step = self._step(action)
#     239 return self._current_time_step
#
# File e:\LoadBalancer\venv\lib\site-packages\tf_agents\environments\batched_py_environment.py:170, in BatchedPyEnvironment._step(self, actions)
#     168 if self._num_envs == 1:
#     169   actions = nest_utils.unbatch_nested_array(actions)
# --> 170   time_steps = self._envs[0].step(actions)
#     171   return nest_utils.batch_nested_array(time_steps)
#     172 else:
#
# File e:\LoadBalancer\venv\lib\site-packages\tf_agents\environments\py_environment.py:238, in PyEnvironment.step(self, action)
#     233 if self._current_time_step is None or self.should_reset(
#     234     self._current_time_step
#     235 ):
#     236   return self.reset()
# --> 238 self._current_time_step = self._step(action)
#     239 return self._current_time_step
#
# Cell In[12], line 118, in LoadBalancerEnvModel4._step(self, action)
#     116 with ThreadPoolExecutor(max_workers=batch_size) as executor:
#     117     futures = [executor.submit(requests.get, target, timeout=5) for target in batch]
# --> 118     for future in as_completed(futures):
#     119         try:
#     120             resp = future.result()
#
# File C:\Program Files\Python310\lib\concurrent\futures\_base.py:245, in as_completed(fs, timeout)
#     240     if wait_timeout < 0:
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#     248     finished = waiter.finished_futures
#
# File C:\Program Files\Python310\lib\threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File C:\Program Files\Python310\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# ---------------------------------------------------------------------------
# Save trained policy
# ---------------------------------------------------------------------------
policy_dir4 = "loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model4"
os.makedirs(policy_dir4, exist_ok=True)

class ExportablePolicy(tf.Module):
    def __init__(self, policy):
        super().__init__()
        self.policy = policy

    @tf.function(input_signature=[
        ts.TimeStep(
            step_type   = tf.TensorSpec(shape=(1,), dtype=tf.int32,   name="step_type"),
            reward      = tf.TensorSpec(shape=(1,), dtype=tf.float32, name="reward"),
            discount    = tf.TensorSpec(shape=(1,), dtype=tf.float32, name="discount"),
            observation = tf.TensorSpec(shape=(1, 3, 3), dtype=tf.float32, name="observation")
        )
    ])
    def action(self, time_step):
        return self.policy.action(time_step).action

exportable4 = ExportablePolicy(agent.policy)
tf.saved_model.save(exportable4, policy_dir4)

# Verify
loaded4 = tf.saved_model.load(policy_dir4)
print("Policy saved to:", policy_dir4)
print("Signatures:", list(loaded4.signatures.keys()))
