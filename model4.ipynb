# %%
# %pip install gin-config
# %pip install absl-py
# %pip install gym==0.23.0
# %pip install matplot
# Out:
# Requirement already satisfied: gin-config in e:\loadbalancer\venv\lib\site-packages (0.5.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: absl-py in e:\loadbalancer\venv\lib\site-packages (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: gym==0.23.0 in e:\loadbalancer\venv\lib\site-packages (0.23.0)
# Requirement already satisfied: gym_notices>=0.0.4 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (0.1.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (3.1.2)
# Requirement already satisfied: numpy>=1.18.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: matplot in e:\loadbalancer\venv\lib\site-packages (0.1.9)
# Requirement already satisfied: matplotlib>=3.1.1 in e:\loadbalancer\venv\lib\site-packages (from matplot) (3.10.8)
# Requirement already satisfied: pyloco>=0.0.134 in e:\loadbalancer\venv\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: pyparsing>=3 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.3.2)
# Requirement already satisfied: cycler>=0.10 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (12.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.62.1)
# Requirement already satisfied: contourpy>=1.0.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.3.2)
# Requirement already satisfied: numpy>=1.23 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (26.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.5.0)
# Requirement already satisfied: websocket-client in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (1.9.0)
# Requirement already satisfied: ushlex in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: twine in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (6.2.0)
# Requirement already satisfied: SimpleWebSocketServer in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: typing in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in e:\loadbalancer\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.6.3)
# Requirement already satisfied: readme-renderer>=35.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (44.0)
# Requirement already satisfied: keyring>=21.2.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (25.7.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: rich>=12.0.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.9.4)
# Requirement already satisfied: id in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.6.1)
# Requirement already satisfied: rfc3986>=1.4.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: requests>=2.20 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (0.2.3)
# Requirement already satisfied: jaraco.context in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (6.1.1)
# Requirement already satisfied: jaraco.classes in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: importlib_metadata>=4.11.4 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (9.0.0)
# Requirement already satisfied: jaraco.functools in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (4.4.0)
# Requirement already satisfied: docutils>=0.21.2 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.22.4)
# Requirement already satisfied: Pygments>=2.5.1 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.19.2)
# Requirement already satisfied: nh3>=0.2.14 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.3.3)
# Requirement already satisfied: idna<4,>=2.5 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2026.2.25)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.0.0)
# Requirement already satisfied: zipp>=3.20 in e:\loadbalancer\venv\lib\site-packages (from importlib_metadata>=4.11.4->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in e:\loadbalancer\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: more-itertools in e:\loadbalancer\venv\lib\site-packages (from jaraco.classes->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (10.8.0)
# Requirement already satisfied: backports.tarfile in e:\loadbalancer\venv\lib\site-packages (from jaraco.context->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import re
from concurrent.futures import ThreadPoolExecutor, as_completed
import tensorflow as tf
import numpy as np 
import numpy as np
import requests 
import time

# TF‑Agents imports  
from tf_agents.environments import tf_py_environment  
from tf_agents.trajectories import trajectory
from tf_agents.networks import q_network
from tf_agents.agents.dqn import dqn_agent
from tf_agents.utils import common
from tf_agents.replay_buffers import tf_uniform_replay_buffer 
from tf_agents.policies import epsilon_greedy_policy

from tf_agents.environments import py_environment
from tf_agents.specs import array_spec
from tf_agents.trajectories import time_step as ts

# %%
def getResponseFromServer():
    url = 'http://localhost:8005'

    try:
        response = requests.get(url)

        if response.status_code == 200:
            print("Successfully received response from load balancer")
            return
        else:
            print('Error:', response.status_code)
            return None
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
getResponseFromServer()
# Out:
# Successfully received response from load balancer

# %%
SERVER_METRICS_URL = "http://localhost:8005/server-metrics"
SERVERS = [
    "http://127.0.0.1:8000",
    "http://127.0.0.1:8001",
    "http://127.0.0.1:8002",
]

# %%
def _parse_prometheus_metrics(metrics_text: str) -> dict:
    """Extract aggregated metrics from Prometheus text format."""
    failed_count_match = re.search(
        r'flask_http_request_total\{method="GET",status="429"\}\s+([\d.]+)', metrics_text)
    failed_count = float(failed_count_match.group(1)) if failed_count_match else 0.0

    success_count_match = re.search(
        r'flask_http_request_total\{method="GET",status="200"\}\s+([\d.]+)', metrics_text)
    success_count = float(success_count_match.group(1)) if success_count_match else 0.0

    total_requests = failed_count + success_count

    success_sum_match = re.search(
        r'flask_http_request_duration_seconds_sum\{method="GET",path="/heavy-task",status="200"\}\s+([\d.]+)', metrics_text)
    success_sum = float(success_sum_match.group(1)) if success_sum_match else 0.0

    success_time_count_match = re.search(
        r'flask_http_request_duration_seconds_count\{method="GET",path="/heavy-task",status="200"\}\s+([\d.]+)', metrics_text)
    success_time_count = float(success_time_count_match.group(1)) if success_time_count_match else 0.0

    avg_success_response = success_sum / success_time_count if success_time_count > 0 else 0.0

    failed_to_success_ratio = failed_count / success_count if success_count > 0 else (float('inf') if total_requests > 0 else 0.5)

    return {
        "avg_successful_response_time": avg_success_response,
        "total_requests": total_requests,
        "failed_to_success_ratio": failed_to_success_ratio
    }

# %%
def generate_state(serverUrl):
    latency = []
    requests_handled = []
    failed_to_success_ratio = []

    for server in SERVERS:
        try:
            response = requests.get(f"{server}/metrics", timeout=2)
            response.raise_for_status()
            backend_metrics = _parse_prometheus_metrics(response.text)

            print(f"{server}: {backend_metrics}")

            raw_latency = backend_metrics.get("avg_successful_response_time", 0.0)
            latency.append(min(raw_latency / 5.0, 1.0))
            raw_requests = backend_metrics.get("total_requests", 0.0)
            requests_handled.append(min(raw_requests / 10000, 1.0))
            failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
        except requests.RequestException as e:
            print(f"Error fetching metrics from {server}: {e}")
            latency.append(1.0)
            requests_handled.append(0.0)
            failed_to_success_ratio.append(0.5)
      
    state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
    return state.astype(np.float32)

# %%
state = generate_state(SERVER_METRICS_URL)
print("Generated state:\n", state)
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# Generated state:
#  [[0.  0.  0.5]
#  [0.  0.  0.5]
#  [0.  0.  0.5]]

# %%
# ---------------------------------------------------------------------------
# REWARD-4: Adaptive SLA-Penalized Reliability Reward with Entropy Fairness Bonus
# ---------------------------------------------------------------------------
#
# Inputs (all already normalized to [0, 1] by _generate_state):
#   state_row[0]  latency_norm   = raw_latency / MAX_LATENCY
#   state_row[1]  requests_norm  = total_requests / MAX_REQUESTS  (unused here)
#   state_row[2]  failure_ratio  ∈ [0, 1]
#
# Parameters:
#   alpha       weight on the quadratic SLA-violation penalty   (default 1.0)
#   beta        weight on the failure-ratio penalty              (default 0.5)
#   lam         weight on the entropy fairness bonus             (default 0.2)
#   sla_norm    SLA latency threshold, already normalized        (default 0.1 = 0.5 s / 5.0 s)
#   action_history  list of recent server indices for entropy    (updated externally)
#   n_servers   total number of servers                          (default 3)
#
# Formula:
#   violation   = max(0, latency_norm - sla_norm)
#   latency_pen = alpha * violation^2          ← quadratic: punishes severe breaches harder
#   failure_pen = beta  * failure_ratio
#   entropy_H   = -sum_i[ p_i * log(p_i + eps) ]  over rolling action_history
#   fairness_bon= lam   * entropy_H / log(n_servers)   ← normalized to [0, 1] range
#
#   r4 = -latency_pen - failure_pen + fairness_bon
#
# ---------------------------------------------------------------------------

_action_history = []   # module-level rolling window, reset each episode

def reset_action_history():
    global _action_history
    _action_history = []

def compute_reward4(state_row,chosen_index, alpha=0.5,beta=0.3,lam=0.5, sla_norm=0.1, n_servers=3, history_window=10):
    """
    REWARD-4: Adaptive SLA-Penalized Reliability Reward with Entropy Fairness Bonus.

    Args:
        state_row     (np.ndarray): Normalized [latency_norm, requests_norm, failure_ratio].
        chosen_index  (int)       : Index of the server selected this step.
        alpha         (float)     : Quadratic SLA violation penalty weight.
        beta          (float)     : Failure ratio penalty weight.
        lam           (float)     : Entropy fairness bonus weight.
        sla_norm      (float)     : Normalized SLA latency threshold (e.g. 0.1 = 0.5 s).
        n_servers     (int)       : Total number of servers (for entropy normalization).
        history_window(int)       : Rolling window size for entropy calculation.

    Returns:
        float: Scalar reward signal.
    """
    global _action_history

    latency_norm  = float(state_row[0])
    failure_ratio = float(state_row[2])

    # ── Quadratic SLA-violation penalty ─────────────────────────────────────
    violation   = max(0.0, latency_norm - sla_norm)
    latency_pen = alpha * (violation ** 2)

    # ── Failure-ratio penalty ────────────────────────────────────────────────
    failure_pen = beta * failure_ratio

    # ── Entropy fairness bonus ───────────────────────────────────────────────
    _action_history.append(chosen_index)
    if len(_action_history) > history_window:
        _action_history.pop(0)

    counts = np.bincount(_action_history, minlength=n_servers).astype(np.float32)
    probs  = counts / counts.sum()
    eps    = 1e-8
    H      = -np.sum(probs * np.log(probs + eps))          # raw Shannon entropy
    H_max  = np.log(n_servers)                             # maximum possible entropy
    fairness_bon = lam * (H / H_max) 

    reward = -latency_pen - failure_pen + fairness_bon

    latency_slack = max(0.0, sla_norm - latency_norm) / sla_norm   # 0→1 as latency drops below SLA
    health_factor = max(0.0, 1.0 - failure_ratio / 1.0)            # fades out as failure_ratio → 1.0 (calibrated to real server range)
    bonus = 0.3 * latency_slack * health_factor
    reward += bonus

    return float(reward)

# %%
# ---------------------------------------------------------------------------
# Hyperparameters — identical to model2 for fair comparison
# ---------------------------------------------------------------------------
GAMMA                    = 0.99
NEURAL_NETWORK_HIDDEN_UNITS = (64, 64)
MAX_BUFFER_SIZE          = 10000
LEARNING_RATE            = 5e-5

# Reward-4 specific (documented for the paper)
REWARD4_ALPHA  = 0.2   # minimal — latency within SLA for all servers
REWARD4_BETA   = 0.3   # dominant — only differentiating signal
REWARD4_LAMBDA = 0.6   # meaningful fairness bonus that can push reward positive
REWARD4_SLA_NORM = 0.1   # 0.5 s threshold / 5.0 s MAX_LATENCY
REWARD4_HISTORY_WINDOW   = 10    # rolling window for entropy calculation

# %%
class LoadBalancerEnvModel4(py_environment.PyEnvironment):
    """
    RL environment for REWARD-4.
    Identical structure to model2 LoadBalancerEnv but uses compute_reward4().
    State normalization is applied inside _generate_state() so the Q-network
    always receives values in [0, 1] matching the BoundedArraySpec.
    """

    MAX_LATENCY  = 5.0      # seconds  — normalization cap
    MAX_REQUESTS = 10000.0  # requests — normalization cap

    def __init__(self, server_metrics_url, servers):
        super(LoadBalancerEnvModel4, self).__init__()
        self._servers            = servers
        self._num_servers        = len(servers)
        self._server_metrics_url = server_metrics_url

        # All 3 features normalized to [0, 1]
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(self._num_servers * 3,),   # flat: 9 values
            dtype=np.float32,
            minimum=np.array([0.0]*9, dtype=np.float32),
            maximum=np.array([1.0, 1.0, 5.0] * self._num_servers, dtype=np.float32),  # failure_ratio unbounded above 1
            name='observation'
        )
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(),
            dtype=np.int32,
            minimum=0,
            maximum=self._num_servers - 1,
            name='action'
        )

        self._episode_ended = False
        self._step_count    = 0
        self._max_steps     = 100

        reset_action_history()
        self._state = self._generate_state()

    # ── specs ─────────────────────────────────────────────────────────────────
    def action_spec(self):      return self._action_spec
    def observation_spec(self): return self._observation_spec

    # ── state ─────────────────────────────────────────────────────────────────
    def _generate_state(self):
        """
        Fetch metrics and normalize to [0, 1]:
          latency_norm  = raw_latency  / MAX_LATENCY   (clamped)
          requests_norm = total_reqs   / MAX_REQUESTS  (clamped)
          failure_ratio already in [0, 1]
        """
        latency = []
        requests_handled = []
        failed_to_success_ratio = []

        for server in SERVERS:
            try:
                response = requests.get(f"{server}/metrics", timeout=2)
                response.raise_for_status()
                backend_metrics = _parse_prometheus_metrics(response.text)

                print(f"{server}: {backend_metrics}")

                raw_latency = backend_metrics.get("avg_successful_response_time", 1.0)
                latency.append(min(raw_latency / 5.0, 1.0))
                raw_requests = backend_metrics.get("total_requests", 0.0)
                requests_handled.append(min(raw_requests / 10000, 1.0))
                failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
            except requests.RequestException as e:
                print(f"Error fetching metrics from {server}: {e}")
                latency.append(1.0)
                requests_handled.append(0.0)
                failed_to_success_ratio.append(0.5)
    
        state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
        return state.flatten().astype(np.float32) 

    # ── reset ─────────────────────────────────────────────────────────────────
    def _reset(self):
        self._episode_ended = False
        self._step_count    = 0
        reset_action_history()          # clear entropy window each episode
        self._state = self._generate_state()
        return ts.restart(self._state)

    # ── step ──────────────────────────────────────────────────────────────────
    def _step(self, action):
        if self._episode_ended:
            return self.reset()

        self._step_count += 1
        chosen_index  = int(action)
        chosen_server = self._servers[chosen_index]
        print(f"[Model4] Routing → {chosen_server}")

        # Send 50 requests: 70% to chosen, 30% spread across others
        total_requests      = 30
        chosen_requests     = int(total_requests * 0.7)
        remaining_requests = total_requests - chosen_requests  # 30% to others

        # Instead of all at once, send in small batches
        batch_size = 10
        delay_between_batches = 0.1  # 100ms

        other_indices  = [i for i in range(self._num_servers) if i != chosen_index]

        request_targets        = [f"{chosen_server}/heavy-task"] * chosen_requests
        for _ in range(total_requests - chosen_requests):
            request_targets.append(f"{self._servers[np.random.choice(other_indices)]}/heavy-task")

        # Send the requests concurrently using ThreadPoolExecutor
        responses = []
        for i in range(0, len(request_targets), batch_size):
            batch = request_targets[i:i + batch_size]
            with ThreadPoolExecutor(max_workers=batch_size) as executor:
                futures = [executor.submit(requests.get, target, timeout=5) for target in batch]
                for future in as_completed(futures):
                    try:
                        resp = future.result()
                        responses.append(resp.status_code)
                    except Exception as e:
                        responses.append(None)
            time.sleep(delay_between_batches)

        success_count = sum(1 for r in responses if r == 200)
        failure_count = sum(1 for r in responses if r is None or r != 200)

        print(f"Simulated traffic: {success_count} successes, {failure_count} failures.")

        new_state = self._generate_state()

        start = chosen_index * 3
        # REWARD-4 — uses normalized state + entropy over rolling action window
        reward = compute_reward4(
            state_row      = new_state[start:start+3],
            chosen_index   = chosen_index,
            alpha          = REWARD4_ALPHA,
            beta           = REWARD4_BETA,
            lam            = REWARD4_LAMBDA,
            sla_norm       = REWARD4_SLA_NORM,
            n_servers      = self._num_servers,
            history_window = REWARD4_HISTORY_WINDOW,
        )
        print(f"  reward4: {reward:.4f}")

        self._state = new_state

        if self._step_count >= self._max_steps:
            self._episode_ended = True
            return ts.termination(self._state, reward)
        return ts.transition(self._state, reward=reward, discount=0.99)

# %%
# Quick sanity check — run this with your servers live
env4 = LoadBalancerEnvModel4(SERVER_METRICS_URL, SERVERS)
init_ts = env4.reset()
print("Initial state (normalized):\n", init_ts.observation)

test_ts = env4._step(0)
print("After step 0 — state:\n", test_ts.observation)
print("After step 0 — reward4:", test_ts.reward)
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.0, 'total_requests': 0.0, 'failed_to_success_ratio': 0.5}
# Initial state (normalized):
#  [0.  0.  0.5 0.  0.  0.5 0.  0.  0.5]
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37318363126541954, 'total_requests': 21.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.4068630333058536, 'total_requests': 6.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.38672506669536233, 'total_requests': 3.0, 'failed_to_success_ratio': 0.0}
#   reward4: -0.0414
# After step 0 — state:
#  [7.4636728e-02 2.0999999e-03 3.1250000e-01 8.1372604e-02 6.0000003e-04
#  0.0000000e+00 7.7345014e-02 3.0000001e-04 0.0000000e+00]
# After step 0 — reward4: -0.04143825

# %%
# ---------------------------------------------------------------------------
# Build TF-Agents environment and DQN agent
# ---------------------------------------------------------------------------
train_env = tf_py_environment.TFPyEnvironment(env4)

q_net4 = q_network.QNetwork(
    train_env.observation_spec(),
    train_env.action_spec(),
    fc_layer_params=NEURAL_NETWORK_HIDDEN_UNITS
)

optimizer4 = tf.keras.optimizers.Adam(learning_rate=5e-5, clipnorm=1.0)
train_step_counter = tf.Variable(0)

agent = dqn_agent.DqnAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    q_network=q_net4,
    optimizer=optimizer4,
    gamma=GAMMA,
    target_update_tau = 1,
    target_update_period=100,
    td_errors_loss_fn=common.element_wise_huber_loss,
    train_step_counter=train_step_counter
)
agent.initialize()
print("Agent4 initialized.")
# Out:
# Agent4 initialized.

# %%
# ---------------------------------------------------------------------------
# Replay buffer and initial data collection
# ---------------------------------------------------------------------------

eval_env4 = LoadBalancerEnvModel4(SERVER_METRICS_URL, SERVERS)
eval_tf_env = tf_py_environment.TFPyEnvironment(eval_env4)

replay_buffer4 = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec  = agent.collect_data_spec,
    batch_size = train_env.batch_size,
    max_length = MAX_BUFFER_SIZE
)

EPSILON_GREEDY_START = 1.0
EPSILON_GREEDY_END   = 0.1
EPSILON_DECAY_STEPS  = 2000

epsilon = tf.compat.v1.train.polynomial_decay(
    learning_rate=EPSILON_GREEDY_START,
    global_step=train_step_counter,
    decay_steps=EPSILON_DECAY_STEPS,
    end_learning_rate=EPSILON_GREEDY_END
)

collect_policy = epsilon_greedy_policy.EpsilonGreedyPolicy(
    agent.policy, epsilon=epsilon
)

def collect_step(environment, policy, buffer):
    time_step   = environment.current_time_step()
    action_step = policy.action(time_step)
    next_ts     = environment.step(action_step.action)
    traj        = trajectory.from_transition(time_step, action_step, next_ts)
    buffer.add_batch(traj)

INITIAL_COLLECT_STEPS = 500
print(f"Collecting {INITIAL_COLLECT_STEPS} initial steps...")
for _ in range(INITIAL_COLLECT_STEPS):
    collect_step(train_env, collect_policy, replay_buffer4)

BATCH_SIZE = 64
dataset4   = replay_buffer4.as_dataset(
    sample_batch_size = BATCH_SIZE,
    num_steps         = 2
).prefetch(3)
iterator4 = iter(dataset4)
print("Replay buffer ready.")
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37318363126541954, 'total_requests': 21.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.4068630333058536, 'total_requests': 6.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.38672506669536233, 'total_requests': 3.0, 'failed_to_success_ratio': 0.0}
# Collecting 500 initial steps...
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37318363126541954, 'total_requests': 21.0, 'failed_to_success_ratio': 0.3125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.4068630333058536, 'total_requests': 6.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.38672506669536233, 'total_requests': 3.0, 'failed_to_success_ratio': 0.0}
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37932365715858485, 'total_requests': 26.0, 'failed_to_success_ratio': 0.23809523809523808}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3942593899788335, 'total_requests': 10.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.40636327501852065, 'total_requests': 24.0, 'failed_to_success_ratio': 2.0}
#   reward4: -0.6000
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37249860237906907, 'total_requests': 47.0, 'failed_to_success_ratio': 0.11904761904761904}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3584018845934994, 'total_requests': 13.0, 'failed_to_success_ratio': 0.0}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.403253246170397, 'total_requests': 30.0, 'failed_to_success_ratio': 1.3076923076923077}
#   reward4: 0.4102
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 26 successes, 4 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3741452191470865, 'total_requests': 52.0, 'failed_to_success_ratio': 0.10638297872340426}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3720761333126575, 'total_requests': 34.0, 'failed_to_success_ratio': 0.13333333333333333}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.39255466473781886, 'total_requests': 34.0, 'failed_to_success_ratio': 1.0}
#   reward4: 0.6265
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3719611235291642, 'total_requests': 56.0, 'failed_to_success_ratio': 0.09803921568627451}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3661206949793268, 'total_requests': 55.0, 'failed_to_success_ratio': 0.375}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3716565954858776, 'total_requests': 39.0, 'failed_to_success_ratio': 0.7727272727272727}
#   reward4: 0.5055
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37028008213798913, 'total_requests': 61.0, 'failed_to_success_ratio': 0.08928571428571429}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3614432259788737, 'total_requests': 76.0, 'failed_to_success_ratio': 0.52}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36506280003008074, 'total_requests': 43.0, 'failed_to_success_ratio': 0.6538461538461539}
#   reward4: 0.4029
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37255722986739853, 'total_requests': 82.0, 'failed_to_success_ratio': 0.06493506493506493}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35951029071670576, 'total_requests': 80.0, 'failed_to_success_ratio': 0.48148148148148145}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3496585806621419, 'total_requests': 48.0, 'failed_to_success_ratio': 0.5483870967741935}
#   reward4: 0.6044
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 9 successes, 21 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3714659204818757, 'total_requests': 88.0, 'failed_to_success_ratio': 0.060240963855421686}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36144974909869854, 'total_requests': 83.0, 'failed_to_success_ratio': 0.45614035087719296}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3496585806621419, 'total_requests': 69.0, 'failed_to_success_ratio': 1.2258064516129032}
#   reward4: 0.2215
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36995900388653347, 'total_requests': 109.0, 'failed_to_success_ratio': 0.05825242718446602}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3608280457398396, 'total_requests': 85.0, 'failed_to_success_ratio': 0.4406779661016949}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35494068890370223, 'total_requests': 76.0, 'failed_to_success_ratio': 1.1111111111111112}
#   reward4: 0.6470
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3686044963003412, 'total_requests': 114.0, 'failed_to_success_ratio': 0.05555555555555555}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35572141296133497, 'total_requests': 106.0, 'failed_to_success_ratio': 0.37662337662337664}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3588397150102537, 'total_requests': 80.0, 'failed_to_success_ratio': 1.0}
#   reward4: 0.5204
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36917719912130087, 'total_requests': 119.0, 'failed_to_success_ratio': 0.05309734513274336}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35998361721506406, 'total_requests': 127.0, 'failed_to_success_ratio': 0.45977011494252873}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3557914727346294, 'total_requests': 84.0, 'failed_to_success_ratio': 0.9090909090909091}
#   reward4: 0.4698
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36720175948997574, 'total_requests': 122.0, 'failed_to_success_ratio': 0.05172413793103448}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35792359584923256, 'total_requests': 148.0, 'failed_to_success_ratio': 0.5257731958762887}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35610859795967686, 'total_requests': 90.0, 'failed_to_success_ratio': 0.8367346938775511}
#   reward4: 0.3731
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36716624538555054, 'total_requests': 125.0, 'failed_to_success_ratio': 0.05042016806722689}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36005854483902733, 'total_requests': 169.0, 'failed_to_success_ratio': 0.5794392523364486}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3542869426008245, 'total_requests': 96.0, 'failed_to_success_ratio': 0.7777777777777778}
#   reward4: 0.2994
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36988478456055973, 'total_requests': 129.0, 'failed_to_success_ratio': 0.04878048780487805}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3581370428375002, 'total_requests': 174.0, 'failed_to_success_ratio': 0.5535714285714286}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3522364472843368, 'total_requests': 117.0, 'failed_to_success_ratio': 1.1272727272727272}
#   reward4: 0.1808
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36849176385260834, 'total_requests': 136.0, 'failed_to_success_ratio': 0.046153846153846156}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35539731888217835, 'total_requests': 195.0, 'failed_to_success_ratio': 0.5354330708661418}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3484509175545291, 'total_requests': 119.0, 'failed_to_success_ratio': 1.087719298245614}
#   reward4: 0.3987
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 17 successes, 13 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3671181142939381, 'total_requests': 139.0, 'failed_to_success_ratio': 0.045112781954887216}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.355151967654929, 'total_requests': 201.0, 'failed_to_success_ratio': 0.5112781954887218}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35114361693581136, 'total_requests': 140.0, 'failed_to_success_ratio': 1.1538461538461537}
#   reward4: 0.2162
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3699731279297599, 'total_requests': 160.0, 'failed_to_success_ratio': 0.03896103896103896}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3560113255342428, 'total_requests': 205.0, 'failed_to_success_ratio': 0.49635036496350365}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3538688443002424, 'total_requests': 145.0, 'failed_to_success_ratio': 1.0714285714285714}
#   reward4: 0.6256
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36951382642424424, 'total_requests': 165.0, 'failed_to_success_ratio': 0.03773584905660377}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3556170921858585, 'total_requests': 209.0, 'failed_to_success_ratio': 0.48226950354609927}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35521777466096927, 'total_requests': 166.0, 'failed_to_success_ratio': 1.3380281690140845}
#   reward4: 0.1609
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36906249940282465, 'total_requests': 171.0, 'failed_to_success_ratio': 0.03636363636363636}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35419102776439915, 'total_requests': 212.0, 'failed_to_success_ratio': 0.4722222222222222}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35612472001521384, 'total_requests': 187.0, 'failed_to_success_ratio': 1.3375}
#   reward4: 0.1140
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36874527693037273, 'total_requests': 175.0, 'failed_to_success_ratio': 0.03550295857988166}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3565480234773342, 'total_requests': 217.0, 'failed_to_success_ratio': 0.4563758389261745}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35625958354486265, 'total_requests': 208.0, 'failed_to_success_ratio': 1.4470588235294117}
#   reward4: 0.0811
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36966854458009557, 'total_requests': 181.0, 'failed_to_success_ratio': 0.03428571428571429}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3549495835237705, 'total_requests': 238.0, 'failed_to_success_ratio': 0.45121951219512196}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3591890966054052, 'total_requests': 211.0, 'failed_to_success_ratio': 1.3977272727272727}
#   reward4: 0.4276
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 16 successes, 14 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3697915329694144, 'total_requests': 185.0, 'failed_to_success_ratio': 0.0335195530726257}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35630435146909406, 'total_requests': 243.0, 'failed_to_success_ratio': 0.4378698224852071}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35973029791034367, 'total_requests': 232.0, 'failed_to_success_ratio': 1.4421052631578948}
#   reward4: 0.0578
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3696407519016616, 'total_requests': 191.0, 'failed_to_success_ratio': 0.032432432432432434}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35688639835849323, 'total_requests': 264.0, 'failed_to_success_ratio': 0.43478260869565216}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3596120306281183, 'total_requests': 235.0, 'failed_to_success_ratio': 1.3979591836734695}
#   reward4: 0.4085
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3707313370811412, 'total_requests': 212.0, 'failed_to_success_ratio': 0.03414634146341464}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3558734827114181, 'total_requests': 271.0, 'failed_to_success_ratio': 0.418848167539267}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35815276101464405, 'total_requests': 237.0, 'failed_to_success_ratio': 1.37}
#   reward4: 0.6270
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3725105986490053, 'total_requests': 233.0, 'failed_to_success_ratio': 0.05429864253393665}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3567796948604668, 'total_requests': 275.0, 'failed_to_success_ratio': 0.41025641025641024}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3563787647766904, 'total_requests': 242.0, 'failed_to_success_ratio': 1.3047619047619048}
#   reward4: 0.6184
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3711148177822017, 'total_requests': 237.0, 'failed_to_success_ratio': 0.05333333333333334}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3548890759900678, 'total_requests': 280.0, 'failed_to_success_ratio': 0.4}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35540496888306905, 'total_requests': 263.0, 'failed_to_success_ratio': 1.4811320754716981}
#   reward4: 0.1180
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37213879087534935, 'total_requests': 242.0, 'failed_to_success_ratio': 0.05217391304347826}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3551140691087508, 'total_requests': 284.0, 'failed_to_success_ratio': 0.39215686274509803}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35614895044583017, 'total_requests': 284.0, 'failed_to_success_ratio': 1.4695652173913043}
#   reward4: 0.0781
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37112146496283227, 'total_requests': 246.0, 'failed_to_success_ratio': 0.05128205128205128}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3572546327222054, 'total_requests': 305.0, 'failed_to_success_ratio': 0.38636363636363635}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35833047834263804, 'total_requests': 289.0, 'failed_to_success_ratio': 1.4083333333333334}
#   reward4: 0.4990
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37072068471005004, 'total_requests': 267.0, 'failed_to_success_ratio': 0.047058823529411764}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3563361656186836, 'total_requests': 309.0, 'failed_to_success_ratio': 0.3794642857142857}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35805423920974133, 'total_requests': 294.0, 'failed_to_success_ratio': 1.352}
#   reward4: 0.6545
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 6 successes, 24 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37072068471005004, 'total_requests': 267.0, 'failed_to_success_ratio': 0.047058823529411764}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35538166608033783, 'total_requests': 318.0, 'failed_to_success_ratio': 0.3826086956521739}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35805423920974133, 'total_requests': 315.0, 'failed_to_success_ratio': 1.52}
#   reward4: 0.1387
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3693146247260369, 'total_requests': 288.0, 'failed_to_success_ratio': 0.06273062730627306}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35436729744096546, 'total_requests': 323.0, 'failed_to_success_ratio': 0.37446808510638296}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3575802814024103, 'total_requests': 319.0, 'failed_to_success_ratio': 1.4728682170542635}
#   reward4: 0.6308
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36924213673157447, 'total_requests': 292.0, 'failed_to_success_ratio': 0.06181818181818182}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35415794416039714, 'total_requests': 328.0, 'failed_to_success_ratio': 0.36666666666666664}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36239125852438586, 'total_requests': 340.0, 'failed_to_success_ratio': 1.5185185185185186}
#   reward4: 0.1206
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3696353046464667, 'total_requests': 297.0, 'failed_to_success_ratio': 0.060714285714285714}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35473394138856834, 'total_requests': 332.0, 'failed_to_success_ratio': 0.36065573770491804}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3631528485765947, 'total_requests': 361.0, 'failed_to_success_ratio': 1.5785714285714285}
#   reward4: 0.0416
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36877930099902634, 'total_requests': 318.0, 'failed_to_success_ratio': 0.05647840531561462}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35554356788137426, 'total_requests': 334.0, 'failed_to_success_ratio': 0.35772357723577236}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36154398896956236, 'total_requests': 368.0, 'failed_to_success_ratio': 1.5379310344827586}
#   reward4: 0.5725
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3684020016418739, 'total_requests': 322.0, 'failed_to_success_ratio': 0.05573770491803279}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35608254899957265, 'total_requests': 339.0, 'failed_to_success_ratio': 0.350597609561753}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36223212055294224, 'total_requests': 389.0, 'failed_to_success_ratio': 1.6643835616438356}
#   reward4: -0.0089
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3672703490842511, 'total_requests': 343.0, 'failed_to_success_ratio': 0.05214723926380368}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3560951054632824, 'total_requests': 344.0, 'failed_to_success_ratio': 0.34375}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35880493734031915, 'total_requests': 393.0, 'failed_to_success_ratio': 1.62}
#   reward4: 0.5750
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3660941403542988, 'total_requests': 364.0, 'failed_to_success_ratio': 0.06432748538011696}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35719587125769064, 'total_requests': 349.0, 'failed_to_success_ratio': 0.3371647509578544}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35898316299312977, 'total_requests': 397.0, 'failed_to_success_ratio': 1.577922077922078}
#   reward4: 0.5711
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3662964895363774, 'total_requests': 385.0, 'failed_to_success_ratio': 0.06060606060606061}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35767454980556274, 'total_requests': 353.0, 'failed_to_success_ratio': 0.3320754716981132}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35996930818249173, 'total_requests': 402.0, 'failed_to_success_ratio': 1.528301886792453}
#   reward4: 0.4247
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3672354639618882, 'total_requests': 391.0, 'failed_to_success_ratio': 0.05962059620596206}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3575451555090138, 'total_requests': 374.0, 'failed_to_success_ratio': 0.3309608540925267}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35924840062270286, 'total_requests': 405.0, 'failed_to_success_ratio': 1.5}
#   reward4: 0.4731
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 17 successes, 13 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3673776253415246, 'total_requests': 393.0, 'failed_to_success_ratio': 0.05929919137466307}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3572986804059294, 'total_requests': 395.0, 'failed_to_success_ratio': 0.35738831615120276}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3572286137778446, 'total_requests': 412.0, 'failed_to_success_ratio': 1.467065868263473}
#   reward4: 0.5101
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36643607628042335, 'total_requests': 414.0, 'failed_to_success_ratio': 0.05612244897959184}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3577689180824486, 'total_requests': 397.0, 'failed_to_success_ratio': 0.35494880546075086}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35794239651633775, 'total_requests': 419.0, 'failed_to_success_ratio': 1.436046511627907}
#   reward4: 0.6211
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36638809824174723, 'total_requests': 419.0, 'failed_to_success_ratio': 0.055415617128463476}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3584185986472325, 'total_requests': 401.0, 'failed_to_success_ratio': 0.3501683501683502}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3582351924891912, 'total_requests': 440.0, 'failed_to_success_ratio': 1.5433526011560694}
#   reward4: 0.0993
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36678168350481427, 'total_requests': 422.0, 'failed_to_success_ratio': 0.055}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3591024834922401, 'total_requests': 407.0, 'failed_to_success_ratio': 0.3432343234323432}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3589474098938568, 'total_requests': 461.0, 'failed_to_success_ratio': 1.532967032967033}
#   reward4: 0.1024
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3677838240837088, 'total_requests': 429.0, 'failed_to_success_ratio': 0.05405405405405406}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35924180327212346, 'total_requests': 409.0, 'failed_to_success_ratio': 0.34098360655737703}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35801759412273126, 'total_requests': 482.0, 'failed_to_success_ratio': 1.5775401069518717}
#   reward4: 0.1029
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3676026178455033, 'total_requests': 450.0, 'failed_to_success_ratio': 0.056338028169014086}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35936834966815256, 'total_requests': 412.0, 'failed_to_success_ratio': 0.33766233766233766}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3562361724010164, 'total_requests': 488.0, 'failed_to_success_ratio': 1.5416666666666667}
#   reward4: 0.6204
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 9 successes, 21 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36802104838446853, 'total_requests': 456.0, 'failed_to_success_ratio': 0.05555555555555555}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3584887356837235, 'total_requests': 415.0, 'failed_to_success_ratio': 0.33440514469453375}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3562361724010164, 'total_requests': 509.0, 'failed_to_success_ratio': 1.6510416666666667}
#   reward4: 0.0808
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3681986811998366, 'total_requests': 477.0, 'failed_to_success_ratio': 0.05530973451327434}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3576774829026029, 'total_requests': 420.0, 'failed_to_success_ratio': 0.3291139240506329}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35434781224942025, 'total_requests': 513.0, 'failed_to_success_ratio': 1.6173469387755102}
#   reward4: 0.6343
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36774189607545277, 'total_requests': 483.0, 'failed_to_success_ratio': 0.05458515283842795}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35663689121379166, 'total_requests': 423.0, 'failed_to_success_ratio': 0.32601880877742945}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35412101485618935, 'total_requests': 534.0, 'failed_to_success_ratio': 1.6435643564356435}
#   reward4: 0.0693
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3675585566994551, 'total_requests': 504.0, 'failed_to_success_ratio': 0.05439330543933055}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3571890437793311, 'total_requests': 426.0, 'failed_to_success_ratio': 0.32298136645962733}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3548591864803707, 'total_requests': 540.0, 'failed_to_success_ratio': 1.608695652173913}
#   reward4: 0.5740
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 26 successes, 4 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36791448012923755, 'total_requests': 509.0, 'failed_to_success_ratio': 0.053830227743271224}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35747562919518083, 'total_requests': 447.0, 'failed_to_success_ratio': 0.3185840707964602}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3559731559318124, 'total_requests': 544.0, 'failed_to_success_ratio': 1.5781990521327014}
#   reward4: 0.4779
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36845559384473037, 'total_requests': 513.0, 'failed_to_success_ratio': 0.053388090349075976}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35752796481747917, 'total_requests': 452.0, 'failed_to_success_ratio': 0.313953488372093}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35605972443175105, 'total_requests': 565.0, 'failed_to_success_ratio': 1.6036866359447004}
#   reward4: 0.0093
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36814552703654635, 'total_requests': 518.0, 'failed_to_success_ratio': 0.052845528455284556}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35766253314074387, 'total_requests': 473.0, 'failed_to_success_ratio': 0.31754874651810583}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35662888552955607, 'total_requests': 569.0, 'failed_to_success_ratio': 1.5746606334841629}
#   reward4: 0.5254
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36838319779599993, 'total_requests': 524.0, 'failed_to_success_ratio': 0.05220883534136546}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.358843010563787, 'total_requests': 494.0, 'failed_to_success_ratio': 0.33875338753387535}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3577214348302472, 'total_requests': 572.0, 'failed_to_success_ratio': 1.5535714285714286}
#   reward4: 0.5491
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36858002625857067, 'total_requests': 545.0, 'failed_to_success_ratio': 0.052123552123552123}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35865347459352015, 'total_requests': 499.0, 'failed_to_success_ratio': 0.3342245989304813}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3584309122892783, 'total_requests': 576.0, 'failed_to_success_ratio': 1.5263157894736843}
#   reward4: 0.6538
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3688315086577159, 'total_requests': 547.0, 'failed_to_success_ratio': 0.051923076923076926}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3591997120676078, 'total_requests': 506.0, 'failed_to_success_ratio': 0.32808398950131235}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35803647650282383, 'total_requests': 597.0, 'failed_to_success_ratio': 1.5512820512820513}
#   reward4: 0.1293
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3684855127571987, 'total_requests': 568.0, 'failed_to_success_ratio': 0.04990757855822551}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3595663542571677, 'total_requests': 512.0, 'failed_to_success_ratio': 0.32299741602067183}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35820701603978117, 'total_requests': 600.0, 'failed_to_success_ratio': 1.5316455696202531}
#   reward4: 0.6547
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3681142675076717, 'total_requests': 589.0, 'failed_to_success_ratio': 0.05745062836624776}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35998958396386477, 'total_requests': 518.0, 'failed_to_success_ratio': 0.31806615776081426}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3583990583400009, 'total_requests': 603.0, 'failed_to_success_ratio': 1.5125}
#   reward4: 0.6520
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3678105408341904, 'total_requests': 610.0, 'failed_to_success_ratio': 0.05536332179930796}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.360846674488975, 'total_requests': 521.0, 'failed_to_success_ratio': 0.31565656565656564}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35800558286433926, 'total_requests': 609.0, 'failed_to_success_ratio': 1.4857142857142858}
#   reward4: 0.6207
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36786662626686983, 'total_requests': 631.0, 'failed_to_success_ratio': 0.06228956228956229}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36130333183546415, 'total_requests': 527.0, 'failed_to_success_ratio': 0.31094527363184077}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3582459508137207, 'total_requests': 612.0, 'failed_to_success_ratio': 1.467741935483871}
#   reward4: 0.6180
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 16 successes, 14 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36779381488691265, 'total_requests': 635.0, 'failed_to_success_ratio': 0.061872909698996656}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3614886604370755, 'total_requests': 532.0, 'failed_to_success_ratio': 0.3071253071253071}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3590713913789859, 'total_requests': 633.0, 'failed_to_success_ratio': 1.4823529411764707}
#   reward4: 0.1176
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.368318185078947, 'total_requests': 640.0, 'failed_to_success_ratio': 0.06135986733001658}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3616617739281145, 'total_requests': 553.0, 'failed_to_success_ratio': 0.3104265402843602}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3594649378444036, 'total_requests': 637.0, 'failed_to_success_ratio': 1.4594594594594594}
#   reward4: 0.5264
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36738953814514946, 'total_requests': 661.0, 'failed_to_success_ratio': 0.05929487179487179}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3617117608847223, 'total_requests': 558.0, 'failed_to_success_ratio': 0.30679156908665106}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3581845121734383, 'total_requests': 641.0, 'failed_to_success_ratio': 1.4372623574144487}
#   reward4: 0.5760
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.367406659748795, 'total_requests': 663.0, 'failed_to_success_ratio': 0.05910543130990415}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3609172193492304, 'total_requests': 565.0, 'failed_to_success_ratio': 0.30184331797235026}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35829316617637097, 'total_requests': 662.0, 'failed_to_success_ratio': 1.4609665427509293}
#   reward4: 0.0521
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3675362535819725, 'total_requests': 666.0, 'failed_to_success_ratio': 0.058823529411764705}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3605640084032943, 'total_requests': 571.0, 'failed_to_success_ratio': 0.29772727272727273}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3579006299332301, 'total_requests': 683.0, 'failed_to_success_ratio': 1.4927007299270072}
#   reward4: 0.0674
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3673995676959077, 'total_requests': 687.0, 'failed_to_success_ratio': 0.05692307692307692}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3613249692938692, 'total_requests': 574.0, 'failed_to_success_ratio': 0.29571106094808125}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35688958029382895, 'total_requests': 689.0, 'failed_to_success_ratio': 1.4695340501792116}
#   reward4: 0.5484
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36754253628435146, 'total_requests': 693.0, 'failed_to_success_ratio': 0.056402439024390245}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36162242017302143, 'total_requests': 577.0, 'failed_to_success_ratio': 0.2937219730941704}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3569188142927097, 'total_requests': 710.0, 'failed_to_success_ratio': 1.5357142857142858}
#   reward4: 0.0545
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36721535932276805, 'total_requests': 714.0, 'failed_to_success_ratio': 0.05621301775147929}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36095680797549, 'total_requests': 582.0, 'failed_to_success_ratio': 0.29046563192904656}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3568815404998506, 'total_requests': 714.0, 'failed_to_success_ratio': 1.5140845070422535}
#   reward4: 0.5735
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36670394956990215, 'total_requests': 735.0, 'failed_to_success_ratio': 0.06213872832369942}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3615145975865497, 'total_requests': 588.0, 'failed_to_success_ratio': 0.28665207877461707}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35722321603375806, 'total_requests': 717.0, 'failed_to_success_ratio': 1.4982578397212543}
#   reward4: 0.5716
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3657675019660011, 'total_requests': 756.0, 'failed_to_success_ratio': 0.06030855539971949}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3620471722875758, 'total_requests': 593.0, 'failed_to_success_ratio': 0.28354978354978355}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3574741460531758, 'total_requests': 721.0, 'failed_to_success_ratio': 1.47766323024055}
#   reward4: 0.5728
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3662454549401936, 'total_requests': 762.0, 'failed_to_success_ratio': 0.059805285118219746}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36262290208967524, 'total_requests': 614.0, 'failed_to_success_ratio': 0.28721174004192873}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35812839932524326, 'total_requests': 724.0, 'failed_to_success_ratio': 1.4625850340136055}
#   reward4: 0.5349
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3662359283774573, 'total_requests': 769.0, 'failed_to_success_ratio': 0.05922865013774105}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36246008377137845, 'total_requests': 635.0, 'failed_to_success_ratio': 0.30390143737166325}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35879706453242516, 'total_requests': 726.0, 'failed_to_success_ratio': 1.4527027027027026}
#   reward4: 0.5286
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 17 successes, 13 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3663749571258126, 'total_requests': 773.0, 'failed_to_success_ratio': 0.0589041095890411}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36192489104966324, 'total_requests': 640.0, 'failed_to_success_ratio': 0.3008130081300813}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3595980282951036, 'total_requests': 747.0, 'failed_to_success_ratio': 1.457236842105263}
#   reward4: 0.1390
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3662324043386426, 'total_requests': 781.0, 'failed_to_success_ratio': 0.058265582655826556}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3623425360875575, 'total_requests': 661.0, 'failed_to_success_ratio': 0.3037475345167653}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3598129547598054, 'total_requests': 748.0, 'failed_to_success_ratio': 1.4524590163934425}
#   reward4: 0.5611
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36677939669511195, 'total_requests': 802.0, 'failed_to_success_ratio': 0.06084656084656084}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36163967460197455, 'total_requests': 666.0, 'failed_to_success_ratio': 0.30078125}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35987918932611745, 'total_requests': 752.0, 'failed_to_success_ratio': 1.4336569579288025}
#   reward4: 0.6192
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3670413782456975, 'total_requests': 809.0, 'failed_to_success_ratio': 0.06028833551769332}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3619679396519653, 'total_requests': 687.0, 'failed_to_success_ratio': 0.3036053130929791}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3595240016136965, 'total_requests': 754.0, 'failed_to_success_ratio': 1.4244372990353698}
#   reward4: 0.5427
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3667979737874144, 'total_requests': 830.0, 'failed_to_success_ratio': 0.061381074168797956}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3617871945521202, 'total_requests': 693.0, 'failed_to_success_ratio': 0.300187617260788}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36005789904994595, 'total_requests': 757.0, 'failed_to_success_ratio': 1.410828025477707}
#   reward4: 0.5718
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 16 successes, 14 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3664787380914589, 'total_requests': 833.0, 'failed_to_success_ratio': 0.061146496815286625}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36151350518742126, 'total_requests': 699.0, 'failed_to_success_ratio': 0.29684601113172543}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3592598149574701, 'total_requests': 778.0, 'failed_to_success_ratio': 1.4236760124610592}
#   reward4: 0.1490
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 23 successes, 7 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36645247680855103, 'total_requests': 837.0, 'failed_to_success_ratio': 0.060836501901140684}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36174058208998233, 'total_requests': 720.0, 'failed_to_success_ratio': 0.30198915009041594}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3587820392681937, 'total_requests': 783.0, 'failed_to_success_ratio': 1.401840490797546}
#   reward4: 0.5296
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3670722806185231, 'total_requests': 858.0, 'failed_to_success_ratio': 0.05925925925925926}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3617914283078992, 'total_requests': 725.0, 'failed_to_success_ratio': 0.2992831541218638}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3587182990945593, 'total_requests': 787.0, 'failed_to_success_ratio': 1.3848484848484848}
#   reward4: 0.6196
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36718057641440305, 'total_requests': 862.0, 'failed_to_success_ratio': 0.05896805896805897}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3604578335008001, 'total_requests': 746.0, 'failed_to_success_ratio': 0.3019197207678883}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578435125392375, 'total_requests': 792.0, 'failed_to_success_ratio': 1.364179104477612}
#   reward4: 0.5302
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 9 successes, 21 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36696590574726934, 'total_requests': 866.0, 'failed_to_success_ratio': 0.05867970660146699}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3605717678129783, 'total_requests': 751.0, 'failed_to_success_ratio': 0.29930795847750863}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578435125392375, 'total_requests': 813.0, 'failed_to_success_ratio': 1.4268656716417911}
#   reward4: 0.1666
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3665177351631406, 'total_requests': 887.0, 'failed_to_success_ratio': 0.057210965435041714}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36047075368027887, 'total_requests': 756.0, 'failed_to_success_ratio': 0.2967409948542024}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3580110784679113, 'total_requests': 817.0, 'failed_to_success_ratio': 1.4100294985250736}
#   reward4: 0.6345
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3663592995287707, 'total_requests': 893.0, 'failed_to_success_ratio': 0.05680473372781065}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3602805936783743, 'total_requests': 759.0, 'failed_to_success_ratio': 0.295221843003413}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3580118782636102, 'total_requests': 838.0, 'failed_to_success_ratio': 1.4289855072463769}
#   reward4: 0.1660
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3661087616943217, 'total_requests': 899.0, 'failed_to_success_ratio': 0.0564042303172738}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3601619639988919, 'total_requests': 762.0, 'failed_to_success_ratio': 0.2937181663837012}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3572230545744034, 'total_requests': 859.0, 'failed_to_success_ratio': 1.4542857142857142}
#   reward4: 0.1584
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36599100922025707, 'total_requests': 905.0, 'failed_to_success_ratio': 0.056009334889148193}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3600635532017583, 'total_requests': 765.0, 'failed_to_success_ratio': 0.2922297297297297}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3567452036651035, 'total_requests': 880.0, 'failed_to_success_ratio': 1.4788732394366197}
#   reward4: 0.1187
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36587446946585617, 'total_requests': 906.0, 'failed_to_success_ratio': 0.055944055944055944}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36000060649200655, 'total_requests': 773.0, 'failed_to_success_ratio': 0.28833333333333333}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35656297111353424, 'total_requests': 901.0, 'failed_to_success_ratio': 1.5027777777777778}
#   reward4: 0.0682
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 20 successes, 10 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36555794413681775, 'total_requests': 909.0, 'failed_to_success_ratio': 0.05574912891986063}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35978488250806, 'total_requests': 794.0, 'failed_to_success_ratio': 0.2973856209150327}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3562959361681077, 'total_requests': 907.0, 'failed_to_success_ratio': 1.484931506849315}
#   reward4: 0.5322
# ...
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36022589499194313, 'total_requests': 4681.0, 'failed_to_success_ratio': 0.30208623087621694}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35822102222230434, 'total_requests': 4563.0, 'failed_to_success_ratio': 1.3915094339622642}
#   reward4: 0.5302
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621719995651209, 'total_requests': 4830.0, 'failed_to_success_ratio': 0.051371353939921635}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36021117012374276, 'total_requests': 4702.0, 'failed_to_success_ratio': 0.3042995839112344}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35828702477811286, 'total_requests': 4568.0, 'failed_to_success_ratio': 1.3878724516466283}
#   reward4: 0.5294
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3621655109647726, 'total_requests': 4851.0, 'failed_to_success_ratio': 0.05113759479956663}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36020906051422397, 'total_requests': 4706.0, 'failed_to_success_ratio': 0.30396231643114435}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3582629483320378, 'total_requests': 4573.0, 'failed_to_success_ratio': 1.3842544316996872}
#   reward4: 0.6393
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362206905161392, 'total_requests': 4872.0, 'failed_to_success_ratio': 0.05204059598358886}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3601892530018376, 'total_requests': 4710.0, 'failed_to_success_ratio': 0.30362579573761417}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3583545825797464, 'total_requests': 4578.0, 'failed_to_success_ratio': 1.3806552262090483}
#   reward4: 0.6389
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36223312271899566, 'total_requests': 4876.0, 'failed_to_success_ratio': 0.05199568500539374}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3602239020440224, 'total_requests': 4715.0, 'failed_to_success_ratio': 0.30320619126589277}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3584364268716024, 'total_requests': 4599.0, 'failed_to_success_ratio': 1.3903326403326404}
#   reward4: 0.1590
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622715171052461, 'total_requests': 4883.0, 'failed_to_success_ratio': 0.05191727703576045}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36009106105030714, 'total_requests': 4736.0, 'failed_to_success_ratio': 0.3036058353977429}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3585073182247879, 'total_requests': 4601.0, 'failed_to_success_ratio': 1.3888888888888888}
#   reward4: 0.5435
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36223817721572327, 'total_requests': 4904.0, 'failed_to_success_ratio': 0.05213473503540013}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36009510775038345, 'total_requests': 4741.0, 'failed_to_success_ratio': 0.30318856514568443}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.358600289741449, 'total_requests': 4605.0, 'failed_to_success_ratio': 1.3860103626943006}
#   reward4: 0.6388
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622549908336601, 'total_requests': 4912.0, 'failed_to_success_ratio': 0.05204540586849432}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3600933503410163, 'total_requests': 4762.0, 'failed_to_success_ratio': 0.3035860936216808}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3586342737965135, 'total_requests': 4606.0, 'failed_to_success_ratio': 1.3852925945106163}
#   reward4: 0.4826
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622454776712463, 'total_requests': 4914.0, 'failed_to_success_ratio': 0.05202312138728324}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3601204728949408, 'total_requests': 4769.0, 'failed_to_success_ratio': 0.30300546448087434}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3584383047944338, 'total_requests': 4627.0, 'failed_to_success_ratio': 1.3850515463917525}
#   reward4: 0.1468
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36227312686683777, 'total_requests': 4918.0, 'failed_to_success_ratio': 0.05197860962566845}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3600367224055654, 'total_requests': 4790.0, 'failed_to_success_ratio': 0.3041110808603322}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3585355962474608, 'total_requests': 4632.0, 'failed_to_success_ratio': 1.3814910025706941}
#   reward4: 0.5295
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36212691316069534, 'total_requests': 4939.0, 'failed_to_success_ratio': 0.05174616695059625}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35995655313665004, 'total_requests': 4798.0, 'failed_to_success_ratio': 0.3034501494159196}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3585130737415818, 'total_requests': 4633.0, 'failed_to_success_ratio': 1.380781089414183}
#   reward4: 0.6391
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 20 successes, 10 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36216153788098293, 'total_requests': 4942.0, 'failed_to_success_ratio': 0.05171313045328793}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35998208451014435, 'total_requests': 4819.0, 'failed_to_success_ratio': 0.3049011643650149}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3582101145571624, 'total_requests': 4639.0, 'failed_to_success_ratio': 1.3777549974372116}
#   reward4: 0.5431
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36218928651695437, 'total_requests': 4945.0, 'failed_to_success_ratio': 0.05168013611229264}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3599582579519571, 'total_requests': 4840.0, 'failed_to_success_ratio': 0.307048339184445}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3580721056755158, 'total_requests': 4645.0, 'failed_to_success_ratio': 1.3747443762781186}
#   reward4: 0.5284
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36229882646048667, 'total_requests': 4952.0, 'failed_to_success_ratio': 0.05160331280526651}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35998365782278297, 'total_requests': 4861.0, 'failed_to_success_ratio': 0.3091839482897926}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35797833396391554, 'total_requests': 4647.0, 'failed_to_success_ratio': 1.3733401430030643}
#   reward4: 0.4843
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 17 successes, 13 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36223113598606715, 'total_requests': 4956.0, 'failed_to_success_ratio': 0.051559516231699555}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36004102173098024, 'total_requests': 4866.0, 'failed_to_success_ratio': 0.3087681549220011}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3580244825031402, 'total_requests': 4668.0, 'failed_to_success_ratio': 1.3743641912512716}
#   reward4: 0.1067
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36211595061308116, 'total_requests': 4977.0, 'failed_to_success_ratio': 0.051330798479087454}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3601546633715899, 'total_requests': 4872.0, 'failed_to_success_ratio': 0.3082706766917293}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3581103995434586, 'total_requests': 4671.0, 'failed_to_success_ratio': 1.372270187912646}
#   reward4: 0.6254
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 16 successes, 14 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36207676556280327, 'total_requests': 4982.0, 'failed_to_success_ratio': 0.051276640641485544}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36019286786373694, 'total_requests': 4876.0, 'failed_to_success_ratio': 0.30793991416309013}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3581467150308254, 'total_requests': 4692.0, 'failed_to_success_ratio': 1.374493927125506}
#   reward4: 0.1500
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3620581110623252, 'total_requests': 4989.0, 'failed_to_success_ratio': 0.05120101137800253}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3601296419059135, 'total_requests': 4897.0, 'failed_to_success_ratio': 0.3079594017094017}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3581465668355974, 'total_requests': 4694.0, 'failed_to_success_ratio': 1.3731041456016178}
#   reward4: 0.5280
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3620100819941118, 'total_requests': 5010.0, 'failed_to_success_ratio': 0.05141657922350472}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3601507410073351, 'total_requests': 4901.0, 'failed_to_success_ratio': 0.3076307363927428}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35801753782187234, 'total_requests': 4699.0, 'failed_to_success_ratio': 1.3696419566313667}
#   reward4: 0.6255
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36202834877381784, 'total_requests': 5014.0, 'failed_to_success_ratio': 0.05137345355420424}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3601656377246365, 'total_requests': 4922.0, 'failed_to_success_ratio': 0.30765143464399575}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3579622708756188, 'total_requests': 4704.0, 'failed_to_success_ratio': 1.3661971830985915}
#   reward4: 0.5281
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36210383994608786, 'total_requests': 5019.0, 'failed_to_success_ratio': 0.051319648093841645}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3601250228923402, 'total_requests': 4943.0, 'failed_to_success_ratio': 0.3097509273979862}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3580077588858586, 'total_requests': 4708.0, 'failed_to_success_ratio': 1.3634538152610443}
#   reward4: 0.4840
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36206577247492944, 'total_requests': 5026.0, 'failed_to_success_ratio': 0.05124450951683748}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36004518834453414, 'total_requests': 4964.0, 'failed_to_success_ratio': 0.3118393234672304}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.358049518505925, 'total_requests': 4710.0, 'failed_to_success_ratio': 1.362086258776329}
#   reward4: 0.4832
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36207384881977084, 'total_requests': 5030.0, 'failed_to_success_ratio': 0.051201671891327065}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3600908723236619, 'total_requests': 4985.0, 'failed_to_success_ratio': 0.3139167105956774}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3580275243626914, 'total_requests': 4715.0, 'failed_to_success_ratio': 1.358679339669835}
#   reward4: 0.4824
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362107174045226, 'total_requests': 5034.0, 'failed_to_success_ratio': 0.051158905825850906}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3599836399042284, 'total_requests': 5006.0, 'failed_to_success_ratio': 0.3159831756046267}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3580898742520059, 'total_requests': 4720.0, 'failed_to_success_ratio': 1.3552894211576847}
#   reward4: 0.4817
# [Model4] Routing → http://127.0.0.1:8001
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36212660807648595, 'total_requests': 5037.0, 'failed_to_success_ratio': 0.051126878130217025}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35996848093762096, 'total_requests': 5027.0, 'failed_to_success_ratio': 0.31803880440482435}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35814454315627536, 'total_requests': 4726.0, 'failed_to_success_ratio': 1.3524141363862618}
#   reward4: 0.3998
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36197433706659166, 'total_requests': 5058.0, 'failed_to_success_ratio': 0.050903802202368585}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3600107396216243, 'total_requests': 5029.0, 'failed_to_success_ratio': 0.31787211740041926}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35797029602826436, 'total_requests': 4733.0, 'failed_to_success_ratio': 1.3500496524329693}
#   reward4: 0.5012
# [Model4] Routing → http://127.0.0.1:8002
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3619405546307214, 'total_requests': 5061.0, 'failed_to_success_ratio': 0.050872093023255814}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36004381200841085, 'total_requests': 5035.0, 'failed_to_success_ratio': 0.3173731030873888}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35804184858604027, 'total_requests': 4754.0, 'failed_to_success_ratio': 1.359305210918114}
#   reward4: 0.0301
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3618840249537854, 'total_requests': 5082.0, 'failed_to_success_ratio': 0.05065123010130246}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36001916092418096, 'total_requests': 5039.0, 'failed_to_success_ratio': 0.31704129639309986}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3581115526733874, 'total_requests': 4759.0, 'failed_to_success_ratio': 1.355940594059406}
#   reward4: 0.5539
# [Model4] Routing → http://127.0.0.1:8000
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3618658098705284, 'total_requests': 5103.0, 'failed_to_success_ratio': 0.051514527096641255}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35998302713391894, 'total_requests': 5042.0, 'failed_to_success_ratio': 0.3167928963175764}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3582097908645224, 'total_requests': 4765.0, 'failed_to_success_ratio': 1.3530864197530865}
#   reward4: 0.5536
# Replay buffer ready.

# %%
 #new claude code for training

import matplotlib.pyplot as plt
import os
import numpy as np
from IPython.display import clear_output

plot_dir = "training_plots"
os.makedirs(plot_dir, exist_ok=True)

# ---------------------------------------------------------------------------
# 4. Training the Agent with Visualization
# ---------------------------------------------------------------------------

num_iterations = 1000
train_loss_history = []
eval_returns_history = []       # NEW
eval_steps_history = []         # NEW: x-axis points for reward curve

eval_interval = 200              # NEW: evaluate every 50 steps
num_eval_episodes = 1         # NEW: average over 5 episodes for stability

def evaluate_agent(env, policy, num_episodes, max_eval_steps=20):
    """Run greedy policy for num_episodes, return average return."""
    total_return = 0.0
    for _ in range(num_episodes):
        time_step = env.reset()
        episode_return = 0.0
        step_count = 0.0
        while not time_step.is_last() and step_count < max_eval_steps:
            action_step = policy.action(time_step)
            time_step = env.step(action_step.action)
            episode_return += time_step.reward.numpy()[0]
            step_count += 1
        total_return += episode_return
    return total_return / num_episodes

consecutive_increase_count = 0
max_consecutive_increases = 5

plt.ion()

for step in range(num_iterations):
    collect_step(train_env, collect_policy, replay_buffer4)

    experience, unused_info = next(iterator4)
    train_loss = agent.train(experience).loss.numpy()

    train_loss_history.append(train_loss)
    train_step_counter.assign_add(1)

    # --- NEW: Evaluate every eval_interval steps ---
    current_step = train_step_counter.numpy()
    if current_step % eval_interval == 0:
        avg_return = evaluate_agent(eval_tf_env, agent.policy, num_eval_episodes)
        eval_returns_history.append(avg_return)
        eval_steps_history.append(current_step)
        print(f'Step = {current_step}: Loss = {train_loss:.4f} | Avg Return = {avg_return:.4f}')

    # Early stopping checks
    if len(train_loss_history) > 1 and train_loss > train_loss_history[-2]:
        consecutive_increase_count += 1
    else:
        consecutive_increase_count = 0

    if np.isnan(train_loss) or train_loss > 100.0:
        print("Stopping: Loss has diverged.")
        break

    # --- MODIFIED: Plot both curves every 100 steps ---
    if current_step % 100 == 0:
        clear_output(wait=True)

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))  # side-by-side

        # Loss curve
        ax1.plot(train_loss_history, color="blue", label="Training Loss")
        ax1.set_xlabel("Training Steps")
        ax1.set_ylabel("Loss")
        ax1.set_title("Training Loss Over Time")
        ax1.legend()
        ax1.grid(True)

        # Reward curve
        if eval_returns_history:
            ax2.plot(eval_steps_history, eval_returns_history,
                     color="green", marker="o", label="Avg Eval Return")
            # Smoothed trend line
            if len(eval_returns_history) >= 5:
                smoothed = np.convolve(eval_returns_history,
                                       np.ones(5)/5, mode='valid')
                ax2.plot(eval_steps_history[4:], smoothed,
                         color="orange", linestyle="--", label="Smoothed (window=5)")
        ax2.set_xlabel("Training Steps")
        ax2.set_ylabel("Average Return")
        ax2.set_title("Evaluation Return Over Training")
        ax2.legend()
        ax2.grid(True)

        plt.tight_layout()
        plt.show()

        step_num = int(current_step // 10)
        fig.savefig(os.path.join(plot_dir, f"Output_{step_num}.png"))
        plt.close(fig)

plt.ioff()
print("Training completed successfully.")

# ---------------------------------------------------------------------------
# Final standalone reward plot (for paper)
# ---------------------------------------------------------------------------
plt.figure(figsize=(8, 5))
plt.plot(eval_steps_history, eval_returns_history,
         color="green", marker="o", label="Avg Eval Return")
if len(eval_returns_history) >= 5:
    smoothed = np.convolve(eval_returns_history, np.ones(5)/5, mode='valid')
    plt.plot(eval_steps_history[4:], smoothed,
             color="orange", linestyle="--", label="Smoothed (window=5)")
plt.xlabel("Training Steps")
plt.ylabel("Average Return")
plt.title("Evaluation Return Over Training (HAMR Agent)")
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(plot_dir, "eval_return_final.png"), dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Training completed successfully.

# %%
# ---------------------------------------------------------------------------
# Save trained policy
# ---------------------------------------------------------------------------
policy_dir4 = "loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model5"
os.makedirs(policy_dir4, exist_ok=True)

class ExportablePolicy(tf.Module):
    def __init__(self, policy):
        super().__init__()
        self.policy = policy

    @tf.function(input_signature=[
        ts.TimeStep(
            step_type   = tf.TensorSpec(shape=(1,), dtype=tf.int32,   name="step_type"),
            reward      = tf.TensorSpec(shape=(1,), dtype=tf.float32, name="reward"),
            discount    = tf.TensorSpec(shape=(1,), dtype=tf.float32, name="discount"),
            observation = tf.TensorSpec(shape=(1, 9), dtype=tf.float32)
        )
    ])
    def action(self, time_step):
        return self.policy.action(time_step).action

exportable5 = ExportablePolicy(agent.policy)
tf.saved_model.save(exportable5, policy_dir4)

# Verify
loaded4 = tf.saved_model.load(policy_dir4)
print("Policy saved to:", policy_dir4)
print("Signatures:", list(loaded4.signatures.keys()))
# Out:
# INFO:tensorflow:Assets written to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model5\assets
# INFO:tensorflow:Assets written to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model5\assets
# Policy saved to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model5
# Signatures: ['serving_default']
