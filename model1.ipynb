# %%
# %pip install tf-agents --no-deps
# Out:
# Collecting tf-agents
#   Using cached tf_agents-0.19.0-py3-none-any.whl.metadata (12 kB)
# Using cached tf_agents-0.19.0-py3-none-any.whl (1.4 MB)
# Installing collected packages: tf-agents
# Successfully installed tf-agents-0.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
# %pip install gin-config
# %pip install tensorflow-probability
# %pip install absl-py
# %pip install gym==0.23.0
# %pip install matplot
# Out:
# Requirement already satisfied: gin-config in e:\loadbalancer\venv\lib\site-packages (0.5.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: tensorflow-probability in e:\loadbalancer\venv\lib\site-packages (0.23.0)
# Requirement already satisfied: gast>=0.3.2 in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (0.7.0)
# Requirement already satisfied: absl-py in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (2.4.0)
# Requirement already satisfied: numpy>=1.13.3 in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (1.26.4)
# Requirement already satisfied: six>=1.10.0 in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (1.17.0)
# Requirement already satisfied: decorator in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (5.2.1)
# Requirement already satisfied: cloudpickle>=1.3 in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (3.1.2)
# Requirement already satisfied: dm-tree in e:\loadbalancer\venv\lib\site-packages (from tensorflow-probability) (0.1.9)
# Requirement already satisfied: wrapt>=1.11.2 in e:\loadbalancer\venv\lib\site-packages (from dm-tree->tensorflow-probability) (1.14.2)
# Requirement already satisfied: attrs>=18.2.0 in e:\loadbalancer\venv\lib\site-packages (from dm-tree->tensorflow-probability) (26.1.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: absl-py in e:\loadbalancer\venv\lib\site-packages (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: gym==0.23.0 in e:\loadbalancer\venv\lib\site-packages (0.23.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (3.1.2)
# Requirement already satisfied: numpy>=1.18.0 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (1.26.4)
# Requirement already satisfied: gym_notices>=0.0.4 in e:\loadbalancer\venv\lib\site-packages (from gym==0.23.0) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: matplot in e:\loadbalancer\venv\lib\site-packages (0.1.9)
# Requirement already satisfied: matplotlib>=3.1.1 in e:\loadbalancer\venv\lib\site-packages (from matplot) (3.10.8)
# Requirement already satisfied: pyloco>=0.0.134 in e:\loadbalancer\venv\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.62.1)
# Requirement already satisfied: pyparsing>=3 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.3.2)
# Requirement already satisfied: numpy>=1.23 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (26.0)
# Requirement already satisfied: pillow>=8 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (12.1.1)
# Requirement already satisfied: cycler>=0.10 in e:\loadbalancer\venv\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: SimpleWebSocketServer in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: ushlex in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: websocket-client in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (1.9.0)
# Requirement already satisfied: twine in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (6.2.0)
# Requirement already satisfied: typing in e:\loadbalancer\venv\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in e:\loadbalancer\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.17.0)
# Requirement already satisfied: requests>=2.20 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Requirement already satisfied: id in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.6.1)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: readme-renderer>=35.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (44.0)
# Requirement already satisfied: urllib3>=1.26.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.6.3)
# Requirement already satisfied: keyring>=21.2.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (25.7.0)
# Requirement already satisfied: rich>=12.0.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.9.4)
# Requirement already satisfied: rfc3986>=1.4.0 in e:\loadbalancer\venv\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (0.2.3)
# Requirement already satisfied: importlib_metadata>=4.11.4 in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (9.0.0)
# Requirement already satisfied: jaraco.classes in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: jaraco.context in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (6.1.1)
# Requirement already satisfied: jaraco.functools in e:\loadbalancer\venv\lib\site-packages (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (4.4.0)
# Requirement already satisfied: nh3>=0.2.14 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.3.3)
# Requirement already satisfied: docutils>=0.21.2 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.22.4)
# Requirement already satisfied: Pygments>=2.5.1 in e:\loadbalancer\venv\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in e:\loadbalancer\venv\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2026.2.25)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\loadbalancer\venv\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.0.0)
# Requirement already satisfied: zipp>=3.20 in e:\loadbalancer\venv\lib\site-packages (from importlib_metadata>=4.11.4->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in e:\loadbalancer\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: more-itertools in e:\loadbalancer\venv\lib\site-packages (from jaraco.classes->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (10.8.0)
# Requirement already satisfied: backports.tarfile in e:\loadbalancer\venv\lib\site-packages (from jaraco.context->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import re
from concurrent.futures import ThreadPoolExecutor, as_completed
import tensorflow as tf
import numpy as np 
import numpy as np
import requests 
import time

# TF‑Agents imports  
from tf_agents.environments import tf_py_environment  
from tf_agents.trajectories import trajectory
from tf_agents.networks import q_network
from tf_agents.agents.dqn import dqn_agent
from tf_agents.utils import common
from tf_agents.replay_buffers import tf_uniform_replay_buffer 
from tf_agents.policies import epsilon_greedy_policy

from tf_agents.environments import py_environment
from tf_agents.specs import array_spec
from tf_agents.trajectories import time_step as ts
# Out:
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
#
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_agents\typing\types.py:114: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
def getResponseFromServer():
    url = 'http://localhost:8005'

    try:
        response = requests.get(url)

        if response.status_code == 200:
            print("Successfully received response from load balancer")
            return
        else:
            print('Error:', response.status_code)
            return None
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
getResponseFromServer()
# Out:
# Successfully received response from load balancer

# %%
SERVER_METRICS_URL = "http://localhost:8005" + "/server-metrics"
global SERVERS
SERVERS = [
    "http://127.0.0.1:8000",
    "http://127.0.0.1:8001",
    "http://127.0.0.1:8002"
]

# %%
def _parse_prometheus_metrics(metrics_text: str) -> dict:
    """Extract aggregated metrics from Prometheus text format."""
    failed_count_match = re.search(
        r'flask_http_request_total\{method="GET",status="429"\}\s+([\d.]+)', metrics_text)
    failed_count = float(failed_count_match.group(1)) if failed_count_match else 0.0

    success_count_match = re.search(
        r'flask_http_request_total\{method="GET",status="200"\}\s+([\d.]+)', metrics_text)
    success_count = float(success_count_match.group(1)) if success_count_match else 0.0

    total_requests = failed_count + success_count

    success_sum_match = re.search(
        r'flask_http_request_duration_seconds_sum\{method="GET",path="/heavy-task",status="200"\}\s+([\d.]+)', metrics_text)
    success_sum = float(success_sum_match.group(1)) if success_sum_match else 0.0

    success_time_count_match = re.search(
        r'flask_http_request_duration_seconds_count\{method="GET",path="/heavy-task",status="200"\}\s+([\d.]+)', metrics_text)
    success_time_count = float(success_time_count_match.group(1)) if success_time_count_match else 0.0

    avg_success_response = success_sum / success_time_count if success_time_count > 0 else 0.0

    failed_to_success_ratio = failed_count / success_count if success_count > 0 else (float('inf') if total_requests > 0 else 0.5)

    return {
        "avg_successful_response_time": avg_success_response,
        "total_requests": total_requests,
        "failed_to_success_ratio": failed_to_success_ratio
    }

# %%
def generate_state(serverUrl):
    latency = []
    requests_handled = []
    failed_to_success_ratio = []

    for server in SERVERS:
        try:
            response = requests.get(f"{server}/metrics", timeout=2)
            response.raise_for_status()
            backend_metrics = _parse_prometheus_metrics(response.text)

            print(f"{server}: {backend_metrics}")

            raw_latency = backend_metrics.get("avg_successful_response_time", 0.0)
            latency.append(min(raw_latency / 5.0, 1.0))
            raw_requests = backend_metrics.get("total_requests", 0.0)
            requests_handled.append(min(raw_requests / 10000, 1.0))
            failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
        except requests.RequestException as e:
            print(f"Error fetching metrics from {server}: {e}")
            latency.append(1.0)
            requests_handled.append(0.0)
            failed_to_success_ratio.append(0.5)

    state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
    return state.astype(np.float32)

# %%
state = generate_state(SERVER_METRICS_URL)
print("Generated state:\n", state)
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.38679062404669823, 'total_requests': 334.0, 'failed_to_success_ratio': 0.7395833333333334}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35717793500128514, 'total_requests': 334.0, 'failed_to_success_ratio': 0.4713656387665198}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.37067112534617386, 'total_requests': 332.0, 'failed_to_success_ratio': 0.3775933609958506}
# Generated state:
#  [[0.07735813 0.0334     0.7395833 ]
#  [0.07143559 0.0334     0.47136563]
#  [0.07413422 0.0332     0.37759337]]

# %%
def compute_reward_from_state(state_row, alpha=1.0, beta=1.0, gamma=1.0):
    """
    Compute a reward from a state row (NumPy array) representing a server's metrics.
    
    Args:
      state_row (numpy.array): Array with [latency, total_requests, failed_to_success_ratio].
      alpha (float): Weight for latency penalty.
      beta (float): Weight for failure ratio penalty.
      gamma (float): Weight for throughput reward.
      
    Returns:
      float: Computed reward.
    """
    latency = state_row[0]
    total_requests = state_row[1]
    failure_ratio = state_row[2]
    
    # Compute throughput as an example: the effective successful request ratio times total requests.
    throughput = total_requests * (1 - failure_ratio)
    
    # Reward: lower latency and lower failure ratio are good; higher throughput is good.
    reward = - (alpha * latency + beta * failure_ratio) + gamma * throughput
    
    return reward

# %%
class LoadBalancerEnv(py_environment.PyEnvironment):
    MAX_LATENCY   = 5.0     # seconds
    MAX_REQUESTS  = 10000.0
    def __init__(self, serverMetricsUrl, servers):
        """
        Args:
          serverMetricsUrl: URL that returns aggregated server metrics in JSON format.
          servers: List of server URLs 
        """
        super(LoadBalancerEnv, self).__init__()
        self._servers = servers
        self._num_servers = len(servers)
        self._serverMetricsUrl = serverMetricsUrl

        # Observation: For each server, we consider 3 metrics:
        # [avg_successful_response_time (latency), total_requests, failed_to_success_ratio]
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(self._num_servers, 3),
            dtype=np.float32,
            minimum=0.0,
            maximum=1.0,
            name='observation'
        )

        # Action: A single discrete action representing the server index (0 to num_servers-1).
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(),
            dtype=np.int32,
            minimum=0,
            maximum=self._num_servers - 1,
            name='action'
        )

        self._episode_ended = False
        self._step_count = 0
        self._max_steps = 100  # defines the episode length

        # Initialize state by fetching the metrics
        self._state = self._generate_state()

    def _generate_state(self):
        """
        Fetch performance metrics from the aggregated metrics endpoint.
        For each server, extract:
          - avg_successful_response_time (latency)
          - total_requests
          - failed_to_success_ratio
        Returns a (num_servers, 3) numpy array.
        """
        latency = []
        requests_handled = []
        failed_to_success_ratio = []
        
        for server in SERVERS:
            try:
                response = requests.get(f"{server}/metrics", timeout=2)
                response.raise_for_status()
                backend_metrics = _parse_prometheus_metrics(response.text)

                print(f"{server}: {backend_metrics}")

                raw_latency = backend_metrics.get("avg_successful_response_time", 1.0)
                latency.append(min(raw_latency / 5.0, 1.0))
                raw_requests = backend_metrics.get("total_requests", 0.0)
                requests_handled.append(min(raw_requests / 10000, 1.0))
                failed_to_success_ratio.append(backend_metrics.get("failed_to_success_ratio", 0.5))
            except requests.RequestException as e:
                print(f"Error fetching metrics from {server}: {e}")
                latency.append(1.0)
                requests_handled.append(0.0)
                failed_to_success_ratio.append(0.5)
        
        state = np.column_stack([latency, requests_handled, failed_to_success_ratio])
        return state.astype(np.float32)

    def action_spec(self):
        return self._action_spec

    def observation_spec(self):
        return self._observation_spec

    def _reset(self):
        self._episode_ended = False
        self._step_count = 0
        self._state = self._generate_state()
        return ts.restart(self._state)

    def _step(self, action):
        if self._episode_ended:
            return self.reset()

        self._step_count += 1

        # Discrete action: chosen server index (0, 1, or 2)
        chosen_index = int(action)
        chosen_server = self._servers[chosen_index]
        print(f"Routing new traffic to chosen server: {chosen_server}")

        # Define total number of simulated requests
        total_requests = 30
        chosen_requests = int(total_requests * 0.7)  # 70% to chosen server
        remaining_requests = total_requests - chosen_requests  # 30% to others

        # Instead of all at once, send in small batches
        batch_size = 10
        delay_between_batches = 0.1  # 100ms

        # Determine indices of other servers
        other_indices = [i for i in range(self._num_servers) if i != chosen_index]
         
        request_targets = [f"{chosen_server}/heavy-task"] * chosen_requests
         
        for _ in range(remaining_requests):
            random_index = np.random.choice(other_indices)
            request_targets.append(f"{self._servers[random_index]}/heavy-task")
        
        # Send the requests concurrently using ThreadPoolExecutor
        responses = []
        for i in range(0, len(request_targets), batch_size):
            batch = request_targets[i:i + batch_size]
            with ThreadPoolExecutor(max_workers=batch_size) as executor:
                futures = [executor.submit(requests.get, target, timeout=5) for target in batch]
                for future in as_completed(futures):
                    try:
                        resp = future.result()
                        responses.append(resp.status_code)
                    except Exception as e:
                        responses.append(None)
            time.sleep(delay_between_batches)

 
        success_count = sum(1 for r in responses if r == 200)
        failure_count = sum(1 for r in responses if r is None or r != 200)

        print(f"Simulated traffic: {success_count} successes, {failure_count} failures.")
 
        new_state = self._generate_state() 
         
        reward = compute_reward_from_state(new_state[chosen_index])

        print(f"Reward: {reward}")
 
        self._state = new_state

        if self._step_count >= self._max_steps:
            self._episode_ended = True
            return ts.termination(self._state, reward)
        else:
            return ts.transition(self._state, reward=reward, discount=0.99)

# %%
 
loadBalancerEnv = LoadBalancerEnv(SERVER_METRICS_URL, SERVERS)
    
# Reset the environment and print the initial state 
initial_time_step = loadBalancerEnv.reset()
print("Initial state:\n", initial_time_step.observation)
    
# Simulate one step with an example action (e.g., choose server 1)
time_step = loadBalancerEnv._step(1)
print("New state:\n", time_step.observation)
print("Reward:", time_step.reward)
# Out:
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.38679062404669823, 'total_requests': 334.0, 'failed_to_success_ratio': 0.7395833333333334}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35717793500128514, 'total_requests': 334.0, 'failed_to_success_ratio': 0.4713656387665198}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.37067112534617386, 'total_requests': 332.0, 'failed_to_success_ratio': 0.3775933609958506}
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.38679062404669823, 'total_requests': 334.0, 'failed_to_success_ratio': 0.7395833333333334}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35717793500128514, 'total_requests': 334.0, 'failed_to_success_ratio': 0.4713656387665198}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.37067112534617386, 'total_requests': 332.0, 'failed_to_success_ratio': 0.3775933609958506}
# Initial state:
#  [[0.07735813 0.0334     0.7395833 ]
#  [0.07143559 0.0334     0.47136563]
#  [0.07413422 0.0332     0.37759337]]
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.38431822146854494, 'total_requests': 337.0, 'failed_to_success_ratio': 0.7282051282051282}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3600704890503612, 'total_requests': 355.0, 'failed_to_success_ratio': 0.4791666666666667}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.367081983966385, 'total_requests': 338.0, 'failed_to_success_ratio': 0.3684210526315789}
# Reward: -0.5326911732908338
# New state:
#  [[0.07686365 0.0337     0.72820514]
#  [0.0720141  0.0355     0.47916666]
#  [0.0734164  0.0338     0.36842105]]
# Reward: -0.5326912

# %%
GAMMA = 0.99
NEURAL_NETWORK_HIDDEN_UNITS = (64,64)
MAX_BUFFER_SIZE = 10000
LEARNING_RATE = 5e-5

# %%
# -----------------------------------------------------------------------------
# 2. Create the TF-Agents Environment and the DQN Agent
# ----------------------------------------------------------------------------- 
 
train_env = tf_py_environment.TFPyEnvironment(loadBalancerEnv)
 
fc_layer_params = NEURAL_NETWORK_HIDDEN_UNITS
q_net = q_network.QNetwork(
    train_env.observation_spec(),
    train_env.action_spec(),
    fc_layer_params=fc_layer_params)
 
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5, clipnorm=1.0)

# Creating a counter to keep track of the training steps.
train_step_counter = tf.Variable(0)
  
agent = dqn_agent.DqnAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    q_network=q_net,
    optimizer=optimizer,
    gamma = GAMMA,
    target_update_tau = 1,
    target_update_period=100,
    td_errors_loss_fn = common.element_wise_huber_loss,
    train_step_counter=train_step_counter)

agent.initialize()
# Out:
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# ---------------------------------------------------------------------------
# 3. Setup the Replay Buffer and Data Collection for Training
# ---------------------------------------------------------------------------

replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec=agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=MAX_BUFFER_SIZE
)

EPSILON_GREEDY_START = 1.0
EPSILON_GREEDY_END   = 0.1
EPSILON_DECAY_STEPS  = 1000

epsilon = tf.compat.v1.train.polynomial_decay(
    learning_rate=EPSILON_GREEDY_START,
    global_step=train_step_counter,
    decay_steps=EPSILON_DECAY_STEPS,
    end_learning_rate=EPSILON_GREEDY_END
)

collect_policy = epsilon_greedy_policy.EpsilonGreedyPolicy(
    agent.policy, epsilon=epsilon
)

def collect_step(environment, policy, buffer):
    """Collects a single transition and stores it in the replay buffer."""
    time_step = environment.current_time_step()  
    action_step = policy.action(time_step)  
    next_time_step = environment.step(action_step.action)  
    traj = trajectory.from_transition(time_step, action_step, next_time_step)  
    buffer.add_batch(traj)

# Collect initial experience for the agent to learn from
initial_collect_steps = 500   
print(f"Collecting {initial_collect_steps} initial experience steps...")

for _ in range(initial_collect_steps):
    collect_step(train_env, collect_policy, replay_buffer)

# Create a dataset from the replay buffer for training
batch_size = 64  
num_steps = 2   

dataset = replay_buffer.as_dataset(
    sample_batch_size=batch_size,
    num_steps=num_steps
).prefetch(3)

iterator = iter(dataset)
# Out:
# Collecting 500 initial experience steps...
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.38431822146854494, 'total_requests': 337.0, 'failed_to_success_ratio': 0.7282051282051282}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3600704890503612, 'total_requests': 355.0, 'failed_to_success_ratio': 0.4791666666666667}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.367081983966385, 'total_requests': 338.0, 'failed_to_success_ratio': 0.3684210526315789}
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3726723606444218, 'total_requests': 342.0, 'failed_to_success_ratio': 0.71}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.35968883767083, 'total_requests': 359.0, 'failed_to_success_ratio': 0.4713114754098361}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3603979629013188, 'total_requests': 359.0, 'failed_to_success_ratio': 0.3650190114068441}
# Reward: -0.41430279750565613
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37187311392174, 'total_requests': 345.0, 'failed_to_success_ratio': 0.6995073891625616}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3660421958435715, 'total_requests': 380.0, 'failed_to_success_ratio': 0.4448669201520912}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36425000195192553, 'total_requests': 365.0, 'failed_to_success_ratio': 0.35687732342007433}
# Reward: -0.49698030569435525
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 20 successes, 10 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3715928024612367, 'total_requests': 352.0, 'failed_to_success_ratio': 0.6923076923076923}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.37044291468892554, 'total_requests': 401.0, 'failed_to_success_ratio': 0.4528985507246377}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3639720847741479, 'total_requests': 367.0, 'failed_to_success_ratio': 0.35424354243542433}
# Reward: -0.5050483747582937
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3642981369706357, 'total_requests': 357.0, 'failed_to_success_ratio': 0.676056338028169}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3702404477024594, 'total_requests': 422.0, 'failed_to_success_ratio': 0.4208754208754209}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3659406770746984, 'total_requests': 371.0, 'failed_to_success_ratio': 0.3490909090909091}
# Reward: -0.4704844607831653
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35987412293131155, 'total_requests': 359.0, 'failed_to_success_ratio': 0.6697674418604651}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3691999496463822, 'total_requests': 429.0, 'failed_to_success_ratio': 0.41118421052631576}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36781543231963254, 'total_requests': 392.0, 'failed_to_success_ratio': 0.32432432432432434}
# Reward: -0.3714009064632493
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 17 successes, 13 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3571024267959209, 'total_requests': 380.0, 'failed_to_success_ratio': 0.7040358744394619}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3690962872471238, 'total_requests': 433.0, 'failed_to_success_ratio': 0.40584415584415584}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36697388075257614, 'total_requests': 397.0, 'failed_to_success_ratio': 0.31893687707641194}
# Reward: -0.7642097252051392
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35743830834593004, 'total_requests': 384.0, 'failed_to_success_ratio': 0.6916299559471366}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36943955617567703, 'total_requests': 438.0, 'failed_to_success_ratio': 0.3993610223642173}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3645164737245068, 'total_requests': 418.0, 'failed_to_success_ratio': 0.2981366459627329}
# Reward: -0.34170206154984717
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3608625651598259, 'total_requests': 405.0, 'failed_to_success_ratio': 0.7381974248927039}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3679897452805292, 'total_requests': 440.0, 'failed_to_success_ratio': 0.3968253968253968}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3659992067563273, 'total_requests': 425.0, 'failed_to_success_ratio': 0.2917933130699088}
# Reward: -0.7997669574902293
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35725291572245105, 'total_requests': 409.0, 'failed_to_success_ratio': 0.7257383966244726}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3676532732134113, 'total_requests': 445.0, 'failed_to_success_ratio': 0.390625}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3641692164934824, 'total_requests': 446.0, 'failed_to_success_ratio': 0.28160919540229884}
# Reward: -0.3224028224741248
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3590272189294164, 'total_requests': 413.0, 'failed_to_success_ratio': 0.7136929460580913}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3689811519078934, 'total_requests': 450.0, 'failed_to_success_ratio': 0.38461538461538464}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36182054546261866, 'total_requests': 467.0, 'failed_to_success_ratio': 0.28296703296703296}
# Reward: -0.32184569757711756
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36097792338567797, 'total_requests': 416.0, 'failed_to_success_ratio': 0.7049180327868853}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36738261421454477, 'total_requests': 471.0, 'failed_to_success_ratio': 0.37317784256559766}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3612451519687003, 'total_requests': 473.0, 'failed_to_success_ratio': 0.27837837837837837}
# Reward: -0.41713105634286696
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36307470489395555, 'total_requests': 422.0, 'failed_to_success_ratio': 0.6947791164658634}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.367286898891634, 'total_requests': 474.0, 'failed_to_success_ratio': 0.3699421965317919}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3642326763448572, 'total_requests': 494.0, 'failed_to_success_ratio': 0.26666666666666666}
# Reward: -0.30328654516895615
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36169104707317756, 'total_requests': 425.0, 'failed_to_success_ratio': 0.6865079365079365}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3663506849350679, 'total_requests': 495.0, 'failed_to_success_ratio': 0.3524590163934426}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.363926407396186, 'total_requests': 500.0, 'failed_to_success_ratio': 0.26262626262626265}
# Reward: -0.39367586942994204
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36267814001896315, 'total_requests': 430.0, 'failed_to_success_ratio': 0.6731517509727627}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3655421157732257, 'total_requests': 499.0, 'failed_to_success_ratio': 0.34864864864864864}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36630878280475737, 'total_requests': 521.0, 'failed_to_success_ratio': 0.25240384615384615}
# Reward: -0.2867158570788084
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3619880347561679, 'total_requests': 435.0, 'failed_to_success_ratio': 0.6603053435114504}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36590349131403266, 'total_requests': 503.0, 'failed_to_success_ratio': 0.3449197860962567}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3642758725585654, 'total_requests': 542.0, 'failed_to_success_ratio': 0.25462962962962965}
# Reward: -0.28708574210598514
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 9 successes, 21 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3619880347561679, 'total_requests': 456.0, 'failed_to_success_ratio': 0.7404580152671756}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36664307642649013, 'total_requests': 508.0, 'failed_to_success_ratio': 0.3403693931398417}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36399216074237806, 'total_requests': 546.0, 'failed_to_success_ratio': 0.25229357798165136}
# Reward: -0.8010205013425296
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.360115612263088, 'total_requests': 459.0, 'failed_to_success_ratio': 0.7320754716981132}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3681116596687697, 'total_requests': 529.0, 'failed_to_success_ratio': 0.3225}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3635302449279613, 'total_requests': 552.0, 'failed_to_success_ratio': 0.248868778280543}
# Reward: -0.3602825700289607
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627609738071892, 'total_requests': 465.0, 'failed_to_success_ratio': 0.7222222222222222}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3677817826392129, 'total_requests': 532.0, 'failed_to_success_ratio': 0.3200992555831266}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3609207439192294, 'total_requests': 573.0, 'failed_to_success_ratio': 0.24025974025974026}
# Reward: -0.268910764093639
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36023326205839923, 'total_requests': 471.0, 'failed_to_success_ratio': 0.7127272727272728}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36724471680736315, 'total_requests': 553.0, 'failed_to_success_ratio': 0.3073286052009456}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36067857491677896, 'total_requests': 576.0, 'failed_to_success_ratio': 0.23870967741935484}
# Reward: -0.34247282421527603
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3620646375202341, 'total_requests': 475.0, 'failed_to_success_ratio': 0.7025089605734767}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36618299554638756, 'total_requests': 574.0, 'failed_to_success_ratio': 0.3165137614678899}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36086986611802496, 'total_requests': 581.0, 'failed_to_success_ratio': 0.23617021276595745}
# Reward: -0.35051823606193067
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36263546527371254, 'total_requests': 496.0, 'failed_to_success_ratio': 0.7403508771929824}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3666085645829661, 'total_requests': 576.0, 'failed_to_success_ratio': 0.3150684931506849}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36138115948443433, 'total_requests': 588.0, 'failed_to_success_ratio': 0.23270440251572327}
# Reward: -0.7999994021293155
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35973237643995115, 'total_requests': 517.0, 'failed_to_success_ratio': 0.7827586206896552}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3668194757423514, 'total_requests': 577.0, 'failed_to_success_ratio': 0.3143507972665148}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3600163830708432, 'total_requests': 596.0, 'failed_to_success_ratio': 0.2288659793814433}
# Reward: -0.8434736848366877
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35877425157923426, 'total_requests': 522.0, 'failed_to_success_ratio': 0.7694915254237288}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36720949693729166, 'total_requests': 598.0, 'failed_to_success_ratio': 0.3}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36042913126877446, 'total_requests': 600.0, 'failed_to_success_ratio': 0.22699386503067484}
# Reward: -0.33158191364765166
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 20 successes, 10 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36058159926521094, 'total_requests': 529.0, 'failed_to_success_ratio': 0.7633333333333333}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3669584336686039, 'total_requests': 619.0, 'failed_to_success_ratio': 0.3086680761099366}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36008476030654635, 'total_requests': 602.0, 'failed_to_success_ratio': 0.22606924643584522}
# Reward: -0.3392663136528864
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 9 successes, 21 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36058159926521094, 'total_requests': 550.0, 'failed_to_success_ratio': 0.8333333333333334}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3666572209074794, 'total_requests': 624.0, 'failed_to_success_ratio': 0.3054393305439331}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3587817218845376, 'total_requests': 606.0, 'failed_to_success_ratio': 0.22424242424242424}
# Reward: -0.8962829685707887
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36082565810476597, 'total_requests': 553.0, 'failed_to_success_ratio': 0.8250825082508251}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3673758909148587, 'total_requests': 645.0, 'failed_to_success_ratio': 0.2977867203219316}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35907185014907217, 'total_requests': 612.0, 'failed_to_success_ratio': 0.2215568862275449}
# Reward: -0.3259691326037739
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.360099995728316, 'total_requests': 557.0, 'failed_to_success_ratio': 0.8143322475570033}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3676010411152611, 'total_requests': 666.0, 'failed_to_success_ratio': 0.3058823529411765}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35889143558794306, 'total_requests': 617.0, 'failed_to_success_ratio': 0.21936758893280633}
# Reward: -0.3331743342728475
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35965668828997377, 'total_requests': 562.0, 'failed_to_success_ratio': 0.8012820512820513}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36670428530986743, 'total_requests': 670.0, 'failed_to_success_ratio': 0.3035019455252918}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36061278061033164, 'total_requests': 638.0, 'failed_to_success_ratio': 0.21062618595825428}
# Reward: -0.23238669476380158
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3584921146789566, 'total_requests': 567.0, 'failed_to_success_ratio': 0.7886435331230284}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36658761738613777, 'total_requests': 674.0, 'failed_to_success_ratio': 0.30115830115830117}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3598779366068809, 'total_requests': 659.0, 'failed_to_success_ratio': 0.2136279926335175}
# Reward: -0.23378166928000432
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3584921146789566, 'total_requests': 567.0, 'failed_to_success_ratio': 0.7886435331230284}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36451798784483624, 'total_requests': 695.0, 'failed_to_success_ratio': 0.2942271880819367}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35954978342295907, 'total_requests': 668.0, 'failed_to_success_ratio': 0.21014492753623187}
# Reward: -0.3180795684438511
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35805197975147834, 'total_requests': 570.0, 'failed_to_success_ratio': 0.78125}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36412565640293004, 'total_requests': 716.0, 'failed_to_success_ratio': 0.3018181818181818}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3594112199011297, 'total_requests': 674.0, 'failed_to_success_ratio': 0.2078853046594982}
# Reward: -0.3246535100427974
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3599907164682952, 'total_requests': 575.0, 'failed_to_success_ratio': 0.7692307692307693}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.363759910897006, 'total_requests': 737.0, 'failed_to_success_ratio': 0.29071803852889666}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35928657045764284, 'total_requests': 678.0, 'failed_to_success_ratio': 0.20640569395017794}
# Reward: -0.3111959506495039
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3599285176228849, 'total_requests': 596.0, 'failed_to_success_ratio': 0.8282208588957055}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3632093475550623, 'total_requests': 741.0, 'failed_to_success_ratio': 0.288695652173913}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35888513815740214, 'total_requests': 683.0, 'failed_to_success_ratio': 0.20458553791887124}
# Reward: -0.8899685133878439
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3593716398948648, 'total_requests': 617.0, 'failed_to_success_ratio': 0.8417910447761194}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36265560580363526, 'total_requests': 747.0, 'failed_to_success_ratio': 0.2857142857142857}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3583669287151436, 'total_requests': 686.0, 'failed_to_success_ratio': 0.20350877192982456}
# Reward: -0.9039038682694933
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35833534013160484, 'total_requests': 621.0, 'failed_to_success_ratio': 0.831858407079646}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36278498353912253, 'total_requests': 752.0, 'failed_to_success_ratio': 0.2832764505119454}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3574120910597198, 'total_requests': 707.0, 'failed_to_success_ratio': 0.19627749576988154}
# Reward: -0.21093674057316658
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3585719486019748, 'total_requests': 626.0, 'failed_to_success_ratio': 0.8197674418604651}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36271607048822313, 'total_requests': 773.0, 'failed_to_success_ratio': 0.27980132450331124}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35730500489642675, 'total_requests': 711.0, 'failed_to_success_ratio': 0.1949579831932773}
# Reward: -0.29667319569917305
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35945183242886114, 'total_requests': 631.0, 'failed_to_success_ratio': 0.8080229226361032}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36229957211625397, 'total_requests': 777.0, 'failed_to_success_ratio': 0.2779605263157895}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35746895688948116, 'total_requests': 732.0, 'failed_to_success_ratio': 0.18831168831168832}
# Reward: -0.20038988388815482
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35891233225190206, 'total_requests': 652.0, 'failed_to_success_ratio': 0.8628571428571429}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.362476144401532, 'total_requests': 782.0, 'failed_to_success_ratio': 0.27569331158238175}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3573266011011471, 'total_requests': 736.0, 'failed_to_success_ratio': 0.1870967741935484}
# Reward: -0.9256979195890427
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 26 successes, 4 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35801776224484744, 'total_requests': 658.0, 'failed_to_success_ratio': 0.8535211267605634}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36291095215961705, 'total_requests': 803.0, 'failed_to_success_ratio': 0.27258320126782887}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35731949037169175, 'total_requests': 739.0, 'failed_to_success_ratio': 0.18619582664526485}
# Reward: -0.2867538068381901
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.357434501597983, 'total_requests': 659.0, 'failed_to_success_ratio': 0.851123595505618}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.363269302939344, 'total_requests': 824.0, 'failed_to_success_ratio': 0.2795031055900621}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578449617220109, 'total_requests': 747.0, 'failed_to_success_ratio': 0.1838351822503962}
# Reward: -0.29278802180497543
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3585679618660937, 'total_requests': 666.0, 'failed_to_success_ratio': 0.8448753462603878}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36376948914799784, 'total_requests': 826.0, 'failed_to_success_ratio': 0.2786377708978328}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3579578561087449, 'total_requests': 768.0, 'failed_to_success_ratio': 0.18335901386748846}
# Reward: -0.19223255212435553
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35948212425379705, 'total_requests': 670.0, 'failed_to_success_ratio': 0.8356164383561644}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36379841760359705, 'total_requests': 847.0, 'failed_to_success_ratio': 0.2698650674662669}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35770762868924066, 'total_requests': 773.0, 'failed_to_success_ratio': 0.1819571865443425}
# Reward: -0.2807823149525288
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35860651079451156, 'total_requests': 691.0, 'failed_to_success_ratio': 0.862533692722372}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36415573777667953, 'total_requests': 850.0, 'failed_to_success_ratio': 0.26865671641791045}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3566387714573035, 'total_requests': 779.0, 'failed_to_success_ratio': 0.1803030303030303}
# Reward: -0.9247560669113684
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35860813125887386, 'total_requests': 695.0, 'failed_to_success_ratio': 0.8533333333333334}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36361521338584546, 'total_requests': 871.0, 'failed_to_success_ratio': 0.26231884057971017}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35678673727402394, 'total_requests': 784.0, 'failed_to_success_ratio': 0.17894736842105263}
# Reward: -0.27078986790373705
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3578519528382458, 'total_requests': 699.0, 'failed_to_success_ratio': 0.8443271767810027}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3640650156260509, 'total_requests': 892.0, 'failed_to_success_ratio': 0.2545710267229255}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35707904444360694, 'total_requests': 789.0, 'failed_to_success_ratio': 0.17761194029850746}
# Reward: -0.2608917617712678
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35784381574787266, 'total_requests': 703.0, 'failed_to_success_ratio': 0.835509138381201}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36283455942581866, 'total_requests': 913.0, 'failed_to_success_ratio': 0.2610497237569061}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35754951296560833, 'total_requests': 794.0, 'failed_to_success_ratio': 0.17629629629629628}
# Reward: -0.26615046607845394
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3592837235376205, 'total_requests': 708.0, 'failed_to_success_ratio': 0.8247422680412371}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3632285099820219, 'total_requests': 917.0, 'failed_to_success_ratio': 0.25961538461538464}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35696027414996245, 'total_requests': 815.0, 'failed_to_success_ratio': 0.17097701149425287}
# Reward: -0.17480368858370288
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 26 successes, 4 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.35954788540782556, 'total_requests': 715.0, 'failed_to_success_ratio': 0.8193384223918575}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36336203879347584, 'total_requests': 938.0, 'failed_to_success_ratio': 0.2556894243641232}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35699648872066875, 'total_requests': 817.0, 'failed_to_success_ratio': 0.17048710601719197}
# Reward: -0.25854548295323787
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3609716482693329, 'total_requests': 719.0, 'failed_to_success_ratio': 0.8110831234256927}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36374224097865304, 'total_requests': 959.0, 'failed_to_success_ratio': 0.2618421052631579}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35903404674057465, 'total_requests': 822.0, 'failed_to_success_ratio': 0.16927453769559034}
# Reward: -0.2638012049841567
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3622545139919335, 'total_requests': 740.0, 'failed_to_success_ratio': 0.8362282878411911}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36330506655529304, 'total_requests': 964.0, 'failed_to_success_ratio': 0.2601307189542484}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3593217826236638, 'total_requests': 826.0, 'failed_to_success_ratio': 0.16831683168316833}
# Reward: -0.8965601119625362
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.361653464089851, 'total_requests': 761.0, 'failed_to_success_ratio': 0.8470873786407767}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36343338073113707, 'total_requests': 968.0, 'failed_to_success_ratio': 0.258777633289987}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35942938186624, 'total_requests': 831.0, 'failed_to_success_ratio': 0.16713483146067415}
# Reward: -0.9077814241723239
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36012674201000483, 'total_requests': 767.0, 'failed_to_success_ratio': 0.8393285371702638}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3634798047937114, 'total_requests': 971.0, 'failed_to_success_ratio': 0.25777202072538863}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3590286763662528, 'total_requests': 852.0, 'failed_to_success_ratio': 0.16234652114597545}
# Reward: -0.16278419164795666
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3604962278522697, 'total_requests': 788.0, 'failed_to_success_ratio': 0.8672985781990521}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3633010430220967, 'total_requests': 975.0, 'failed_to_success_ratio': 0.25644329896907214}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3587367501744017, 'total_requests': 857.0, 'failed_to_success_ratio': 0.16124661246612465}
# Reward: -0.9289409790302905
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3639510079339709, 'total_requests': 809.0, 'failed_to_success_ratio': 0.8726851851851852}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3631845982033863, 'total_requests': 978.0, 'failed_to_success_ratio': 0.2554557124518614}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3587324429060909, 'total_requests': 863.0, 'failed_to_success_ratio': 0.15994623655913978}
# Reward: -0.9351756244246054
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3644755392688913, 'total_requests': 830.0, 'failed_to_success_ratio': 0.8993135011441648}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36284422568761726, 'total_requests': 985.0, 'failed_to_success_ratio': 0.25318066157760816}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3587705520688203, 'total_requests': 865.0, 'failed_to_success_ratio': 0.15951742627345844}
# Reward: -0.963851640721344
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 24 successes, 6 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36416314182803033, 'total_requests': 836.0, 'failed_to_success_ratio': 0.8914027149321267}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.362915505041317, 'total_requests': 1006.0, 'failed_to_success_ratio': 0.2543640897755611}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3591766660373281, 'total_requests': 868.0, 'failed_to_success_ratio': 0.1588785046728972}
# Reward: -0.2519362359649968
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36446223696660035, 'total_requests': 857.0, 'failed_to_success_ratio': 0.9345372460496614}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36217274640839603, 'total_requests': 1011.0, 'failed_to_success_ratio': 0.2527881040892193}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35908434735896666, 'total_requests': 872.0, 'failed_to_success_ratio': 0.15803452855245684}
# Reward: -1.001819522635326
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.366915276878119, 'total_requests': 862.0, 'failed_to_success_ratio': 0.9241071428571429}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3629457068411594, 'total_requests': 1032.0, 'failed_to_success_ratio': 0.2509090909090909}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35927932419579367, 'total_requests': 876.0, 'failed_to_success_ratio': 0.1571994715984148}
# Reward: -0.24619204961976138
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36726102168619684, 'total_requests': 883.0, 'failed_to_success_ratio': 0.9492273730684326}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3627283823550686, 'total_requests': 1037.0, 'failed_to_success_ratio': 0.2493975903614458}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35948679142850726, 'total_requests': 880.0, 'failed_to_success_ratio': 0.15637319316688567}
# Reward: -1.0181963760570842
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3669097622083596, 'total_requests': 904.0, 'failed_to_success_ratio': 0.9737991266375546}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36250737751345397, 'total_requests': 1041.0, 'failed_to_success_ratio': 0.24820143884892087}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35961319016641935, 'total_requests': 885.0, 'failed_to_success_ratio': 0.15535248041775457}
# Reward: -1.0448125018195293
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3662311544003141, 'total_requests': 910.0, 'failed_to_success_ratio': 0.9654427645788337}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36297608313651114, 'total_requests': 1044.0, 'failed_to_success_ratio': 0.24731182795698925}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3594666109502843, 'total_requests': 906.0, 'failed_to_success_ratio': 0.15120711562897077}
# Reward: -0.14619980470754745
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3663481940280188, 'total_requests': 918.0, 'failed_to_success_ratio': 0.9615384615384616}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3631634234000364, 'total_requests': 1045.0, 'failed_to_success_ratio': 0.24701670644391407}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3592029781781833, 'total_requests': 927.0, 'failed_to_success_ratio': 0.15442092154420922}
# Reward: -0.1478763487238831
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 19 successes, 11 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3689498344115865, 'total_requests': 939.0, 'failed_to_success_ratio': 0.9644351464435147}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3631304405670458, 'total_requests': 1047.0, 'failed_to_success_ratio': 0.24642857142857144}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3589614954956385, 'total_requests': 934.0, 'failed_to_success_ratio': 0.15308641975308643}
# Reward: -1.034885590695437
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3692141560192185, 'total_requests': 945.0, 'failed_to_success_ratio': 0.9565217391304348}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3629962461108143, 'total_requests': 1068.0, 'failed_to_success_ratio': 0.24041811846689895}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3587901987620504, 'total_requests': 937.0, 'failed_to_success_ratio': 0.15252152521525214}
# Reward: -0.2318940256458334
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.369909506238202, 'total_requests': 966.0, 'failed_to_success_ratio': 0.9795081967213115}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36306280600978263, 'total_requests': 1073.0, 'failed_to_success_ratio': 0.2390300230946882}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3593485433162661, 'total_requests': 941.0, 'failed_to_success_ratio': 0.15177478580171358}
# Reward: -1.0515106187333338
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3698609630842335, 'total_requests': 970.0, 'failed_to_success_ratio': 0.9715447154471545}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3630779555410713, 'total_requests': 1078.0, 'failed_to_success_ratio': 0.23765786452353616}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35929774211156956, 'total_requests': 962.0, 'failed_to_success_ratio': 0.14797136038186157}
# Reward: -0.13786575564622594
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3694549717396883, 'total_requests': 974.0, 'failed_to_success_ratio': 0.9637096774193549}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3631861187604339, 'total_requests': 1083.0, 'failed_to_success_ratio': 0.2363013698630137}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35920446147016033, 'total_requests': 983.0, 'failed_to_success_ratio': 0.14435389988358557}
# Reward: -0.13208477199326363
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36895512276075354, 'total_requests': 979.0, 'failed_to_success_ratio': 0.9540918163672655}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36286595075787076, 'total_requests': 1104.0, 'failed_to_success_ratio': 0.2348993288590604}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35884675193495164, 'total_requests': 987.0, 'failed_to_success_ratio': 0.1436848203939745}
# Reward: -0.22300540627081122
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.368957928492403, 'total_requests': 982.0, 'failed_to_success_ratio': 0.9484126984126984}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3631744675693807, 'total_requests': 1125.0, 'failed_to_success_ratio': 0.24035281146637266}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3584460772383179, 'total_requests': 993.0, 'failed_to_success_ratio': 0.142692750287687}
# Reward: -0.22752739342941997
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 16 successes, 14 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36992778518063907, 'total_requests': 1003.0, 'failed_to_success_ratio': 0.9628180039138943}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3628478280934555, 'total_requests': 1129.0, 'failed_to_success_ratio': 0.23929747530186607}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35888436511106325, 'total_requests': 998.0, 'failed_to_success_ratio': 0.14187643020594964}
# Reward: -1.0330742289155896
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 26 successes, 4 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37176740745597525, 'total_requests': 1010.0, 'failed_to_success_ratio': 0.9573643410852714}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3635847482328007, 'total_requests': 1150.0, 'failed_to_success_ratio': 0.23655913978494625}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3591823868997867, 'total_requests': 1000.0, 'failed_to_success_ratio': 0.1415525114155251}
# Reward: -0.22148038831529437
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 21 successes, 9 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37191911187025556, 'total_requests': 1016.0, 'failed_to_success_ratio': 0.9500959692898272}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36538777255378757, 'total_requests': 1171.0, 'failed_to_success_ratio': 0.2417815482502651}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35904836619754815, 'total_requests': 1003.0, 'failed_to_success_ratio': 0.1410693970420933}
# Reward: -0.2260717186285497
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37183649832962923, 'total_requests': 1020.0, 'failed_to_success_ratio': 0.9428571428571428}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36544786261397005, 'total_requests': 1176.0, 'failed_to_success_ratio': 0.24050632911392406}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35813379127878636, 'total_requests': 1024.0, 'failed_to_success_ratio': 0.13777777777777778}
# Reward: -0.12111298203590182
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37231893912432384, 'total_requests': 1025.0, 'failed_to_success_ratio': 0.9339622641509434}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3653450356704438, 'total_requests': 1180.0, 'failed_to_success_ratio': 0.23949579831932774}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3578649441304927, 'total_requests': 1045.0, 'failed_to_success_ratio': 0.1408296943231441}
# Reward: -0.12261938712531173
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3727402097884687, 'total_requests': 1030.0, 'failed_to_success_ratio': 0.9252336448598131}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36455180547466565, 'total_requests': 1201.0, 'failed_to_success_ratio': 0.2368692070030896}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35784054800790216, 'total_requests': 1049.0, 'failed_to_success_ratio': 0.14021739130434782}
# Reward: -0.21812755385893412
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3725930793080679, 'total_requests': 1034.0, 'failed_to_success_ratio': 0.9183673469387755}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36554268400269474, 'total_requests': 1222.0, 'failed_to_success_ratio': 0.2318548387096774}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.35813517377856624, 'total_requests': 1054.0, 'failed_to_success_ratio': 0.13945945945945945}
# Reward: -0.21109604375184543
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37183719735335685, 'total_requests': 1039.0, 'failed_to_success_ratio': 0.9099264705882353}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36527338496666084, 'total_requests': 1243.0, 'failed_to_success_ratio': 0.23681592039800994}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3577714947547866, 'total_requests': 1058.0, 'failed_to_success_ratio': 0.13885898815931108}
# Reward: -0.21500680909454672
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37217832644560245, 'total_requests': 1045.0, 'failed_to_success_ratio': 0.9034608378870674}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3651340934625128, 'total_requests': 1246.0, 'failed_to_success_ratio': 0.2361111111111111}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3574065340540909, 'total_requests': 1079.0, 'failed_to_success_ratio': 0.13578947368421052}
# Reward: -0.11402246145014072
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37176893799065175, 'total_requests': 1050.0, 'failed_to_success_ratio': 0.8953068592057761}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3657221465761493, 'total_requests': 1267.0, 'failed_to_success_ratio': 0.23249027237354086}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3572208634500869, 'total_requests': 1083.0, 'failed_to_success_ratio': 0.13522012578616352}
# Reward: -0.20839121792621418
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37163219107813866, 'total_requests': 1071.0, 'failed_to_success_ratio': 0.9159212880143113}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36542411491576304, 'total_requests': 1271.0, 'failed_to_success_ratio': 0.2315891472868217}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3581679143739129, 'total_requests': 1088.0, 'failed_to_success_ratio': 0.13451511991657977}
# Reward: -0.9812428794395411
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3714131413779321, 'total_requests': 1073.0, 'failed_to_success_ratio': 0.9126559714795008}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3652848194778636, 'total_requests': 1292.0, 'failed_to_success_ratio': 0.23636363636363636}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3581944306229707, 'total_requests': 1095.0, 'failed_to_success_ratio': 0.13354037267080746}
# Reward: -0.21075878471016884
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.37181175427906793, 'total_requests': 1077.0, 'failed_to_success_ratio': 0.9061946902654867}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36545933203774816, 'total_requests': 1313.0, 'failed_to_success_ratio': 0.23170731707317074}
# ...
# Simulated traffic: 16 successes, 14 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36268186492922216, 'total_requests': 4697.0, 'failed_to_success_ratio': 1.1545871559633027}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.362103159770926, 'total_requests': 5133.0, 'failed_to_success_ratio': 0.15478065241844768}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36261089089194853, 'total_requests': 5300.0, 'failed_to_success_ratio': 0.0746147607461476}
# Reward: -1.2997331067791116
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3626343985147012, 'total_requests': 4718.0, 'failed_to_success_ratio': 1.1592677345537759}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.362048132508741, 'total_requests': 5140.0, 'failed_to_success_ratio': 0.1545372866127583}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3625909053672581, 'total_requests': 5302.0, 'failed_to_success_ratio': 0.07458451560599919}
# Reward: -1.3069372027873065
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 14 successes, 16 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3627572492847115, 'total_requests': 4739.0, 'failed_to_success_ratio': 1.1639269406392694}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3619841381995643, 'total_requests': 5143.0, 'failed_to_success_ratio': 0.15443322109988777}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3625747538104893, 'total_requests': 5308.0, 'failed_to_success_ratio': 0.07449392712550608}
# Reward: -1.3141633949624456
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 29 successes, 1 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36279911712868834, 'total_requests': 4742.0, 'failed_to_success_ratio': 1.1623347013223895}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3620347654867508, 'total_requests': 5149.0, 'failed_to_success_ratio': 0.15422550997534185}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36256192751163924, 'total_requests': 5329.0, 'failed_to_success_ratio': 0.07439516129032259}
# Reward: 0.34634724115486115
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36289118851790686, 'total_requests': 4745.0, 'failed_to_success_ratio': 1.1607468123861566}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3620679922558389, 'total_requests': 5155.0, 'failed_to_success_ratio': 0.15401835683904186}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3624729129917563, 'total_requests': 5350.0, 'failed_to_success_ratio': 0.07516077170418006}
# Reward: 0.3471336584943092
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362769380335457, 'total_requests': 4751.0, 'failed_to_success_ratio': 1.1585642889595638}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3620903255502187, 'total_requests': 5176.0, 'failed_to_success_ratio': 0.1543264942016057}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3625400818596249, 'total_requests': 5353.0, 'failed_to_success_ratio': 0.07511548503715605}
# Reward: 0.2109760419039084
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 20 successes, 10 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36290863820611097, 'total_requests': 4758.0, 'failed_to_success_ratio': 1.156844968268359}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36203885815239684, 'total_requests': 5197.0, 'failed_to_success_ratio': 0.15565932844118302}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36255180238632956, 'total_requests': 5355.0, 'failed_to_success_ratio': 0.07508532423208192}
# Reward: 0.2107367293973761
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36294114931484267, 'total_requests': 4759.0, 'failed_to_success_ratio': 1.1563207974626188}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36198659296712826, 'total_requests': 5218.0, 'failed_to_success_ratio': 0.15493581230633025}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36247927250469764, 'total_requests': 5363.0, 'failed_to_success_ratio': 0.0749649228302265}
# Reward: 0.21362135190631015
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 18 successes, 12 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36290759887871743, 'total_requests': 4780.0, 'failed_to_success_ratio': 1.1570397111913358}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3619647502411054, 'total_requests': 5222.0, 'failed_to_success_ratio': 0.15479876160990713}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36245153837831684, 'total_requests': 5368.0, 'failed_to_success_ratio': 0.07488986784140969}
# Reward: -1.3046862874063336
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628432070187404, 'total_requests': 4783.0, 'failed_to_success_ratio': 1.1554754393871114}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3619115199130599, 'total_requests': 5243.0, 'failed_to_success_ratio': 0.15459149966967628}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36246009066832524, 'total_requests': 5374.0, 'failed_to_success_ratio': 0.0748}
# Reward: 0.21627385672459098
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 22 successes, 8 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3629885451154178, 'total_requests': 4788.0, 'failed_to_success_ratio': 1.1528776978417266}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3620003119671192, 'total_requests': 5264.0, 'failed_to_success_ratio': 0.15590689503732982}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3625225953473534, 'total_requests': 5378.0, 'failed_to_success_ratio': 0.07474020783373302}
# Reward: 0.2160236684334711
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3630896490797803, 'total_requests': 4793.0, 'failed_to_success_ratio': 1.1502916105877075}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3620760778129247, 'total_requests': 5285.0, 'failed_to_success_ratio': 0.1551912568306011}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36254300233184406, 'total_requests': 5382.0, 'failed_to_success_ratio': 0.07468051118210862}
# Reward: 0.2188749623292212
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3630850887718761, 'total_requests': 4797.0, 'failed_to_success_ratio': 1.1482310792655621}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3621139881484833, 'total_requests': 5290.0, 'failed_to_success_ratio': 0.15502183406113537}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36277662430405955, 'total_requests': 5403.0, 'failed_to_success_ratio': 0.07436866176178167}
# Reward: 0.3531946330216966
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36291356896869226, 'total_requests': 4818.0, 'failed_to_success_ratio': 1.1518535060294774}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3622207076712481, 'total_requests': 5296.0, 'failed_to_success_ratio': 0.15481901439162668}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3627278462167277, 'total_requests': 5406.0, 'failed_to_success_ratio': 0.07432432432432433}
# Reward: -1.2975993200163316
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628904138674684, 'total_requests': 4823.0, 'failed_to_success_ratio': 1.1492869875222815}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3622988661104895, 'total_requests': 5317.0, 'failed_to_success_ratio': 0.1553672316384181}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3627959013327065, 'total_requests': 5410.0, 'failed_to_success_ratio': 0.07426528991262907}
# Reward: 0.2212642613394955
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3629089841435197, 'total_requests': 4827.0, 'failed_to_success_ratio': 1.1472419928825623}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36229259707206685, 'total_requests': 5322.0, 'failed_to_success_ratio': 0.1551986108096375}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36277158656518393, 'total_requests': 5431.0, 'failed_to_success_ratio': 0.07395689143761124}
# Reward: 0.35642279949098743
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 23 successes, 7 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36299316510192026, 'total_requests': 4834.0, 'failed_to_success_ratio': 1.145583666222814}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3622536520260956, 'total_requests': 5324.0, 'failed_to_success_ratio': 0.15513126491646778}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36271803017933624, 'total_requests': 5452.0, 'failed_to_success_ratio': 0.07470924502266903}
# Reward: 0.3572156608964532
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 10 successes, 20 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3629250850037158, 'total_requests': 4855.0, 'failed_to_success_ratio': 1.1539485359361137}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3622282094938138, 'total_requests': 5327.0, 'failed_to_success_ratio': 0.15503035559410233}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3627126584957516, 'total_requests': 5458.0, 'failed_to_success_ratio': 0.07462098838354006}
# Reward: -1.3012755819750552
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 27 successes, 3 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.362769134800541, 'total_requests': 4862.0, 'failed_to_success_ratio': 1.1522797698096503}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36220291771974994, 'total_requests': 5329.0, 'failed_to_success_ratio': 0.15496315561335067}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3626929896392518, 'total_requests': 5479.0, 'failed_to_success_ratio': 0.07452441655226515}
# Reward: 0.3600050742550591
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 25 successes, 5 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3628149862064444, 'total_requests': 4865.0, 'failed_to_success_ratio': 1.1507515473032714}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36223816135186093, 'total_requests': 5335.0, 'failed_to_success_ratio': 0.15476190476190477}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36275766728442876, 'total_requests': 5500.0, 'failed_to_success_ratio': 0.07526881720430108}
# Reward: 0.360781806555166
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 26 successes, 4 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36292870552778217, 'total_requests': 4869.0, 'failed_to_success_ratio': 1.148720211827008}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36227558574934077, 'total_requests': 5356.0, 'failed_to_success_ratio': 0.15505714901876214}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36277167954993295, 'total_requests': 5505.0, 'failed_to_success_ratio': 0.0751953125}
# Reward: 0.22503913478742188
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3630439926344085, 'total_requests': 4874.0, 'failed_to_success_ratio': 1.1461911052399825}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3622593486588532, 'total_requests': 5360.0, 'failed_to_success_ratio': 0.15492350786468434}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36299714313366044, 'total_requests': 5526.0, 'failed_to_success_ratio': 0.0748881540556312}
# Reward: 0.36372924901956516
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3630090758077, 'total_requests': 4878.0, 'failed_to_success_ratio': 1.1441758241758242}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3623402477631745, 'total_requests': 5381.0, 'failed_to_success_ratio': 0.15472103004291846}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3629751062028608, 'total_requests': 5531.0, 'failed_to_success_ratio': 0.07481539059463661}
# Reward: 0.22765552739993566
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.3629165794713601, 'total_requests': 4899.0, 'failed_to_success_ratio': 1.1477422183252959}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3623885904603023, 'total_requests': 5385.0, 'failed_to_success_ratio': 0.15458833619210977}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3629600304092487, 'total_requests': 5536.0, 'failed_to_success_ratio': 0.07474276839448651}
# Reward: -1.2927045269076416
# Routing new traffic to chosen server: http://127.0.0.1:8001
# Simulated traffic: 28 successes, 2 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36269329641277287, 'total_requests': 4903.0, 'failed_to_success_ratio': 1.1457330415754923}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.36247714450839613, 'total_requests': 5406.0, 'failed_to_success_ratio': 0.15438821268417682}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.3629009345271074, 'total_requests': 5541.0, 'failed_to_success_ratio': 0.07467028704422032}
# Reward: 0.2302540804509281
# Routing new traffic to chosen server: http://127.0.0.1:8000
# Simulated traffic: 15 successes, 15 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36283214133813374, 'total_requests': 4924.0, 'failed_to_success_ratio': 1.1492797904845047}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3625087986503979, 'total_requests': 5410.0, 'failed_to_success_ratio': 0.15425645402176233}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36298852117925146, 'total_requests': 5546.0, 'failed_to_success_ratio': 0.07459794613447006}
# Reward: -1.2953516484113976
# Routing new traffic to chosen server: http://127.0.0.1:8002
# Simulated traffic: 30 successes, 0 failures.
# http://127.0.0.1:8000: {'avg_successful_response_time': 0.36285248796519487, 'total_requests': 4927.0, 'failed_to_success_ratio': 1.1477768090671316}
# http://127.0.0.1:8001: {'avg_successful_response_time': 0.3625049034688211, 'total_requests': 5416.0, 'failed_to_success_ratio': 0.15405923716173023}
# http://127.0.0.1:8002: {'avg_successful_response_time': 0.36283283213512196, 'total_requests': 5567.0, 'failed_to_success_ratio': 0.07429563874951756}
# Reward: 0.3684774002514075
# WARNING:tensorflow:From e:\LoadBalancer\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.

# %%
#new claude code for training

import matplotlib.pyplot as plt
import os
import numpy as np
from IPython.display import clear_output

plot_dir = "training_plots"
os.makedirs(plot_dir, exist_ok=True)

# ---------------------------------------------------------------------------
# 4. Training the Agent with Visualization
# ---------------------------------------------------------------------------

num_iterations = 1000
train_loss_history = []
eval_returns_history = []       # NEW
eval_steps_history = []         # NEW: x-axis points for reward curve

eval_interval = 200              # NEW: evaluate every 50 steps
num_eval_episodes = 1         # NEW: average over 5 episodes for stability

def evaluate_agent(env, policy, num_episodes, max_eval_steps=20):
    """Run greedy policy for num_episodes, return average return."""
    total_return = 0.0
    for _ in range(num_episodes):
        time_step = env.reset()
        episode_return = 0.0
        step_count = 0.0
        while not time_step.is_last() and step_count < max_eval_steps:
            action_step = policy.action(time_step)
            time_step = env.step(action_step.action)
            episode_return += time_step.reward.numpy()[0]
            step_count += 1
        total_return += episode_return
    return total_return / num_episodes

consecutive_increase_count = 0
max_consecutive_increases = 5

plt.ion()

for step in range(num_iterations):
    collect_step(train_env, collect_policy, replay_buffer)

    experience, unused_info = next(iterator)
    train_loss = agent.train(experience).loss.numpy()

    train_loss_history.append(train_loss)
    train_step_counter.assign_add(1)

    # --- NEW: Evaluate every eval_interval steps ---
    current_step = train_step_counter.numpy()
    if current_step % eval_interval == 0:
        avg_return = evaluate_agent(train_env, agent.policy, num_eval_episodes)
        eval_returns_history.append(avg_return)
        eval_steps_history.append(current_step)
        print(f'Step = {current_step}: Loss = {train_loss:.4f} | Avg Return = {avg_return:.4f}')

    # Early stopping checks
    if len(train_loss_history) > 1 and train_loss > train_loss_history[-2]:
        consecutive_increase_count += 1
    else:
        consecutive_increase_count = 0

    if np.isnan(train_loss) or train_loss > 100.0:
        print("Stopping: Loss has diverged.")
        break

    # --- MODIFIED: Plot both curves every 100 steps ---
    if current_step % 100 == 0:
        clear_output(wait=True)

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))  # side-by-side

        # Loss curve
        ax1.plot(train_loss_history, color="blue", label="Training Loss")
        ax1.set_xlabel("Training Steps")
        ax1.set_ylabel("Loss")
        ax1.set_title("Training Loss Over Time")
        ax1.legend()
        ax1.grid(True)

        # Reward curve
        if eval_returns_history:
            ax2.plot(eval_steps_history, eval_returns_history,
                     color="green", marker="o", label="Avg Eval Return")
            # Smoothed trend line
            if len(eval_returns_history) >= 5:
                smoothed = np.convolve(eval_returns_history,
                                       np.ones(5)/5, mode='valid')
                ax2.plot(eval_steps_history[4:], smoothed,
                         color="orange", linestyle="--", label="Smoothed (window=5)")
        ax2.set_xlabel("Training Steps")
        ax2.set_ylabel("Average Return")
        ax2.set_title("Evaluation Return Over Training")
        ax2.legend()
        ax2.grid(True)

        plt.tight_layout()
        plt.show()

        step_num = int(current_step // 10)
        fig.savefig(os.path.join(plot_dir, f"Output_{step_num}.png"))
        plt.close(fig)

plt.ioff()
print("Training completed successfully.")

# ---------------------------------------------------------------------------
# Final standalone reward plot (for paper)
# ---------------------------------------------------------------------------
plt.figure(figsize=(8, 5))
plt.plot(eval_steps_history, eval_returns_history,
         color="green", marker="o", label="Avg Eval Return")
if len(eval_returns_history) >= 5:
    smoothed = np.convolve(eval_returns_history, np.ones(5)/5, mode='valid')
    plt.plot(eval_steps_history[4:], smoothed,
             color="orange", linestyle="--", label="Smoothed (window=5)")
plt.xlabel("Training Steps")
plt.ylabel("Average Return")
plt.title("Evaluation Return Over Training (HAMR Agent)")
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(plot_dir, "eval_return_final.png"), dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Training completed successfully.

# %%
import tensorflow as tf
from tf_agents.trajectories import time_step as ts
import os

policy_dir = "loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model1"
os.makedirs(policy_dir, exist_ok=True)

class ExportablePolicy(tf.Module):
    def __init__(self, policy):
        super().__init__()
        self.policy = policy

    @tf.function(input_signature=[
        ts.TimeStep(
            step_type=tf.TensorSpec(shape=(1,), dtype=tf.int32, name="step_type"),
            reward=tf.TensorSpec(shape=(1,), dtype=tf.float32, name="reward"),
            discount=tf.TensorSpec(shape=(1,), dtype=tf.float32, name="discount"),
            observation=tf.TensorSpec(shape=(1, 3, 3), dtype=tf.float32, name="observation")
        )
    ])
    def action(self, time_step):
        action_step = self.policy.action(time_step)
        return action_step.action  # returns tensor of shape (1,), dtype int32

exportable = ExportablePolicy(agent.policy)
tf.saved_model.save(exportable, policy_dir)

# Verify
loaded = tf.saved_model.load(policy_dir)
print("Signatures:", list(loaded.signatures.keys()))
print("Success!" if loaded.signatures else "FAILED - still empty")
# Out:
# C:\Users\hp\AppData\Local\Temp\__autograph_generated_file8rryof_j.py:14: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   retval_ = ag__.and_(lambda : ag__.ld(state) is not None, lambda : ag__.and_(lambda : ag__.ld(state) is not (), lambda : ag__.ld(state) is not []))
# C:\Users\hp\AppData\Local\Temp\__autograph_generated_file68kijz1t.py:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   ag__.if_stmt(ag__.ld(policy_state) is (), if_body_2, else_body_2, get_state_2, set_state_2, ('do_return', 'retval_'), 2)
# INFO:tensorflow:Assets written to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model1\assets
# INFO:tensorflow:Assets written to: loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model1\assets
# Signatures: ['serving_default']
# Success!

# %%
# Test loading
loaded_policy = tf.compat.v2.saved_model.load(policy_dir)
print("Policy loaded successfully")
# Out:
# Policy loaded successfully

# %%
policy_dir = "loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model1"

for root, dirs, files in os.walk(policy_dir):
    for file in files:
        print(os.path.join(root, file))
# Out:
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model1\fingerprint.pb
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model1\saved_model.pb
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model1\variables\variables.data-00000-of-00001
# loadBalancingAlgorithms/saved_policies/load_balancing_trained_policy_model1\variables\variables.index
